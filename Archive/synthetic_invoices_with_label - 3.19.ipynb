# %%
import json
import random
import re
from datetime import datetime, timedelta
import numpy as np
from faker import Faker
import uuid
from collections import defaultdict
import copy

# Set up the Faker generator with a fixed seed for reproducibility
fake = Faker(['en_US'])

with open('synthetic_data_configs.json','r') as f:
    synthetic_data_configs = json.load(f)

def merchant_name_generator(merchant_types,company_suffixes):
            # Company Name Generator

    name_prefix = random.choice([
        fake.last_name(),
        fake.last_name() + " & " + fake.last_name(),
        fake.last_name() + "-" + fake.last_name(),
        fake.word().capitalize(),
        fake.word().capitalize() + fake.word().capitalize(),
    ])
    
    merchant_type = random.choice(merchant_types)
    suffix = random.choice(company_suffixes)
    
    merchant_name = [name_prefix]
    if random.random() >= 0.7:
        merchant_name.append(merchant_type)
    if random.random() >= 0.5:
        merchant_name.append(suffix)
    return (' '.join(merchant_name), merchant_type)

def generate_merchant_data(num_merchants=20):
    """
    Generate a diverse set of realistic merchant data
    
    Parameters:
    num_merchants (int): Number of merchants to generate
    
    Returns:
    list: List of merchant dictionaries
    """
    merchant_types = synthetic_data_configs["merchant_types"]
    company_suffixes = synthetic_data_configs["company_suffixes"]
    
    # ------------------------Modiefied------------------------------
    merchants = [{
    "name": "Curtis Instruments, Inc.",
    "merchant": "Curtis Instruments, Inc.",  # Add this line
    "address": "200 Kisco Avenue Mount Kisco NY 10549 USA",
    "city": "Mount Kisco",
    "state": "NY",
    "country": "US",
    "type": "Electronics"
    }]
    # ----------------------------------------------------------------
    
    # Create a set to track unique merchant names
    existing_names = {merchants[0]["name"]}
    
    # Generate additional merchants
    for _ in range(num_merchants - 1):
        country_code = 'US'
        
        fake.seed_instance(random.randint(1, 9999))
            
        # US address
        street = fake.street_address()
        city = fake.city()
        state = fake.state_abbr()
        zip_code = fake.zipcode()
        address = f"{street} {city} {state} {zip_code} USA"
        
        # Merchant Name Generator
        while True:
            merchant_name,merchant_type = merchant_name_generator(merchant_types, company_suffixes)

            # Check for uniqueness
            if merchant_name not in existing_names:
                existing_names.add(merchant_name)
                break
        
        merchants.append({
            "name": merchant_name,
            "address": address,
            "city": city,
            "state": state,
            "country": country_code,
            "type": merchant_type
        })
    
    return merchants

def generate_product_catalog():
    """
    Generate a realistic product catalog with categories and products
    
    Returns:
    dict: Dictionary mapping categories to lists of products
    """
    categories = synthetic_data_configs["categories"]
    
    # Generate product catalog
    catalog = {}
    
    for category, product_types in categories.items():
        catalog[category] = []
        
        # Generate 15-30 products per category
        for _ in range(random.randint(15, 30)):
            product_type = random.choice(product_types)
            
            # Generate model number
            model_prefix = ''.join(random.choice('ABCDEFGHJKLMNPQRSTUVWXYZ') for _ in range(random.randint(1, 3)))
            model_suffix = ''.join(random.choice('0123456789') for _ in range(random.randint(3, 5)))
            model = f"{model_prefix}-{model_suffix}"
            
            # Generate specification
            specs = [
                "Standard", "Premium", "Industrial", "Commercial", "Professional",
                "Heavy Duty", "Lightweight", "Compact", "Extended", "High Performance",
                "Economy", "Deluxe", "Ultimate", "Basic", "Advanced"
            ]
            spec = random.choice(specs)
            
            # Generate description
            description = f"{model} {spec} {product_type}"
            
            # Generate price based on category and specification
            base_price = {
                "Electronics": random.uniform(50, 500),
                "Industrial": random.uniform(100, 1000),
                "Office Supplies": random.uniform(10, 200),
                "Manufacturing": random.uniform(50, 800),
                "Automotive": random.uniform(30, 600),
                "Medical": random.uniform(100, 2000),
                "Construction": random.uniform(20, 500),
                "Technology": random.uniform(100, 3000),
                "Laboratory": random.uniform(50, 1500),
                "Engineering": random.uniform(100, 2000),
                "Aerospace": random.uniform(500, 5000),
                "Telecommunications": random.uniform(200, 2500)
            }[category]
            
            # Adjust price based on specification
            spec_multiplier = {
                "Standard": 1.0,
                "Premium": 1.5,
                "Industrial": 1.3,
                "Commercial": 1.2,
                "Professional": 1.4,
                "Heavy Duty": 1.3,
                "Lightweight": 0.9,
                "Compact": 0.85,
                "Extended": 1.25,
                "High Performance": 1.6,
                "Economy": 0.7,
                "Deluxe": 1.35,
                "Ultimate": 1.8,
                "Basic": 0.6,
                "Advanced": 1.5
            }[spec]
            
            unit_price = round(base_price * spec_multiplier, 2)
            
            catalog[category].append({
                "description": description,
                "unit_price": unit_price,
                "model": model,
                "spec": spec,
                "type": product_type
            })
    
    return catalog

def generate_synthetic_invoice(num_invoices=1, num_merchants=10, anomaly_rate=0.05):
    """
    Generate synthetic invoice data based on the provided schema
    
    Parameters:
    num_invoices (int): Number of synthetic invoices to generate
    num_invoices (int): Number of synthetic merchants to generate
    anomaly_rate (float): Rate at which to introduce data anomalies
    
    Returns:
    list: List of invoice dictionaries following the extraction schema
    """
    invoices = []
    
    # Generate merchant data
    merchants = generate_merchant_data(num_merchants)
    
    # Generate product catalog
    product_catalog = generate_product_catalog()
    
    # Define payment terms with weighted probabilities
    payment_terms = [
        ("NET 30 DAYS", 0.4),
        ("NET 45 DAYS", 0.2),
        ("NET 60 DAYS", 0.1),
        ("DUE ON RECEIPT", 0.15),
        ("2/10 NET 30", 0.05),
        ("COD", 0.05),
        ("NET 15 DAYS", 0.05)
    ]
    
    # Define payment methods
    payment_methods = {
        "shipping": ["UPS Ground", "FedEx Express", "FedEx Ground", "USPS Priority", "DHL Express"],
        "payment": ["Credit Card", "Wire Transfer", "ACH", "Check", "PayPal", "Net Banking"]
    }
    
    # Define currencies with correct format
    currencies = {
        "US": "USD",
    }
    
    # Define tax rates by state
    tax_rates = synthetic_data_configs["tax_rates"]
    
    # Customer data generation
    customers = []
    num_customers = min(num_invoices // 5, 50)  # Create a reasonable number of customers
    for _ in range(max(1, num_customers)):  # Ensure at least one customer
        customer = {
            "name": fake.company(),
            "customer_id": f"CUST-{random.randint(10000, 99999)}",
            "address": fake.address().replace('\n', ', '),
            "contact_person": fake.name(),
            "email": fake.company_email(),
            "phone": fake.phone_number()
        }
        customers.append(customer)
    
    # Create a distribution of invoices where some merchants and customers appear more often
    # This mimics real world patterns where certain suppliers are used more frequently
    merchant_weights = np.random.exponential(scale=1.0, size=len(merchants))
    merchant_weights = merchant_weights / np.sum(merchant_weights)
    
    customer_weights = np.random.exponential(scale=1.0, size=len(customers))
    customer_weights = customer_weights / np.sum(customer_weights)
    
    # Track merchant-customer relationships to create realistic patterns
    merchant_customers = defaultdict(list)
    
    # Track invoice numbers by merchant
    merchant_invoice_counters = {m["name"]: 1 for m in merchants}
    
    # po_records = {} ####
    
    # Generate invoice data
    for invoice_idx in range(num_invoices):
        # Select merchant with weighted probability
        merchant = np.random.choice(merchants, p=merchant_weights)
        merchant_name = merchant["name"]
        merchant_address = merchant["address"]
        merchant_type = merchant["type"]
        city = merchant["city"]
        state = merchant["state"]
        country = merchant["country"]
        currency = currencies[country]
        
        # Generate realistic invoice number
        invoice_prefix = ''.join(random.choice(merchant_name.split()[0:1]).upper()[0:3])
        invoice_year = datetime.now().year
        invoice_num = merchant_invoice_counters[merchant_name]
        merchant_invoice_counters[merchant_name] += 1
        invoice_number = f"{invoice_prefix}{invoice_year}-{invoice_num:05d}"
        
        # Generate invoice date (weighted toward recent dates)
        days_ago = int(np.random.exponential(scale=60))  # Mostly recent invoices
        days_ago = min(days_ago, 365)  # Cap at 1 year
        invoice_date = datetime.now() - timedelta(days=days_ago)
        
        # Format date according to country conventions
        if country in ['US', 'CA']:
            invoice_date_str = invoice_date.strftime("%m/%d/%Y")
        else:
            invoice_date_str = invoice_date.strftime("%d/%m/%Y")
        
        # Select payment term with weighted probability
        payment_term = random.choices([term[0] for term in payment_terms], 
                                     weights=[term[1] for term in payment_terms])[0]
        
        # Calculate due date based on payment terms
        
        
        if "30" in payment_term:
            due_days = random.choices([30,15,0], weights = [10, 1, 1], k = 1)[0] ### MODIFIED FOR PAYMENT DATE ANOMALY
            if due_days == 30:
                payment_label = 0
            else:
                payment_label = 1
        elif "45" in payment_term:
            due_days = random.choices([45,15,0], weights = [10, 1, 1], k = 1)[0] ### MODIFIED
            if due_days == 40:
                payment_label=0
            else:
                payment_label=1
        elif "60" in payment_term:
            due_days = 60
            payment_label=0
        elif "15" in payment_term:
            due_days = 15
            payment_label=0
        elif "RECEIPT" in payment_term or "COD" in payment_term:
            due_days = 0
            payment_label=0
        else:  # Default for 2/10 NET 30 or other formats
            due_days = 30
            payment_label=0
            
        due_date = invoice_date + timedelta(days=due_days)

        # For anomalies, occasionally introduce incorrect due_date
        # ----------------------Modified---------------------------------
        if random.random() < anomaly_rate:
            due_days_anomaly = round(due_days * random.uniform(0.5, 1.5))  
            due_date = invoice_date + timedelta(days=due_days_anomaly)
        # ---------------------------------------------------------------
        
        # Format due date according to country conventions
        #if country in ['US', 'CA']:
        #    due_date_str = due_date.strftime("%m/%d/%Y")
        #else:
        #    due_date_str = due_date.strftime("%d/%m/%Y")
        #
        # Select or create a customer relationship
        if merchant_name in merchant_customers and random.random() < 0.8:
            # 80% chance to use an existing customer for this merchant
            customer = random.choice(merchant_customers[merchant_name])
        else: 
            # Either new merchant or 20% chance to add a new customer
            customer = np.random.choice(customers, p=customer_weights)
            merchant_customers[merchant_name].append(customer)
        
        # Generate PO number with several realistic formats
        po_formats = [
            f"{random.randint(10000, 99999)}-{random.randint(100, 999)}",
            f"PO-{random.randint(10000, 99999)}",
            f"{customer['customer_id']}-{random.randint(1000, 9999)}",
            f"{datetime.now().strftime('%y%m')}-{random.randint(1000, 9999)}",
            f"{random.randint(100000, 999999)}",
            f"{random.choice('ABCDEFGHJKLMNPQRSTUVWXYZ')}{random.randint(10000, 99999)}"
        ]
        po_number = random.choice(po_formats)
        
        # Determine payment method based on merchant type and customer patterns
        if random.random() < 0.7:  # 70% chance it's a shipping method
            payment_method = random.choice(payment_methods["shipping"])
        else:  # 30% chance it's an actual payment method
            payment_method = random.choice(payment_methods["payment"])
        
        # Generate line items
        line_items = []
        
        # Number of items follows a distribution centered on 3-4 items
        num_items_distribution = [0.1, 0.2, 0.3, 0.2, 0.1, 0.05, 0.03, 0.02]
        num_items = np.random.choice(range(1, len(num_items_distribution) + 1), 
                                    p=num_items_distribution)
        
        # For some merchants, force at least 2 line items to mimic bundled purchases
        if random.random() < 0.3 and num_items == 1:
            num_items = 2
        
        # Select products from appropriate category for merchant type
        available_products = product_catalog.get(merchant_type, [])
        if not available_products:  # Fallback if category doesn't match
            available_products = random.choice(list(product_catalog.values()))
        
        # Select products without replacement if possible
        selected_products = random.sample(available_products, 
                                         min(num_items, len(available_products)))
        
        # If we need more products than unique ones available, allow repeats
        if num_items > len(selected_products):
            additional_products = [random.choice(available_products) 
                                  for _ in range(num_items - len(selected_products))]
            selected_products.extend(additional_products)
        
        # Calculate tax rates based on country and region
        tax_rate = tax_rates.get(state, 0.0)
        
        # Handle special case for shipping
        shipping_cost = 0
        if random.random() < 0.4:  # 40% chance of separate shipping charge
            shipping_cost = round(random.uniform(5, 50), 2)
        
        subtotal = 0
        total_tax = 0
        
        # Collect line details in the expected format
        formatted_line_details = []
        
        # Generate each line item
        for i, product in enumerate(selected_products, 1):
            description = product["description"]
            unit_price = product["unit_price"]
            
            # Generate quantity with realistic distribution
            qty_distribution = {
                1: 0.3,   # 30% chance of qty 1
                2: 0.2,   # 20% chance of qty 2
                3: 0.1,   # 10% chance of qty 3
                4: 0.05,  # 5% chance of qty 4
                5: 0.05,  # 5% chance of qty 5
                10: 0.1,  # 10% chance of qty 10
                12: 0.05, # 5% chance of qty 12
                24: 0.05, # 5% chance of qty 24
                50: 0.05, # 5% chance of qty 50
                100: 0.05 # 5% chance of qty 100
            }
            
            qty = random.choices(list(qty_distribution.keys()), 
                               weights=list(qty_distribution.values()))[0]
            
            # Calculate line total with realistic price adjustments
            # Occasionally apply discounts for bulk purchases
            discount = 1.0
            if qty >= 10:
                discount = random.uniform(0.85, 0.95)
            elif qty >= 50:
                discount = random.uniform(0.75, 0.85)
            
            # Apply slight random variance to unit price
            adjusted_unit_price = unit_price * random.uniform(0.98, 1.02) * discount
            line_total = round(adjusted_unit_price * qty, 2)
            
            # Calculate line tax
            line_tax = round(line_total * tax_rate, 2) if tax_rate > 0 else 0.0
            
            # ------------------------Modiefied------------------------------
            # Added
            def apply_variations(line_details):
                for line in line_details:
                    if "line_description" not in line:  # Add key check
                        continue
                        
                    base_product = next(
                        (k for k, v in synthetic_data_configs["product_variations"].items()
                        if line["line_description"].startswith(k)  # Key fix
                    ), None)
                    
                    if base_product:
                        variation = random.choice(
                            synthetic_data_configs["product_variations"][base_product]
                        )
                        line["line_description"] = variation + " " + line["line_description"].split(" ", 1)[-1]
                return line_details        
            
            label = 0 ### added
            # For anomalies, occasionally introduce incorrect calculations
            if random.random() < anomaly_rate * 0.3:  # 30% of anomalies
                duplicated_product = random.choice(selected_products)
                selected_products.insert(i, duplicated_product)
                label = 1 ### added
                
            # For anomalies, occasionally introduce duplicate varied wordings
            if random.random() < anomaly_rate * 0.3:  # 30% of anomalies
                # Get all invoices from the same merchant
                merchant_invoices = [
                    inv for inv in invoices 
                    if any(ext["field"] == "merchant" and ext["value"] == merchant_name 
                        for ext in inv["extractions"])
                ]
                
                if merchant_invoices:
                    base_invoice = random.choice(merchant_invoices)
                    duplicate_invoice = copy.deepcopy(base_invoice)
                    original_date = datetime.strptime(
                        duplicate_invoice["invoice_date"], "%m/%d/%Y")
                    new_date = original_date + timedelta(days=random.randint(1, 30))
                    duplicate_invoice["invoice_date"] = new_date.strftime("%m/%d/%Y")
                    
                    # Modify line item descriptions
                    duplicate_invoice["line_details"] = apply_variations(
                        duplicate_invoice["line_details"]
                    )
                    invoices.append(duplicate_invoice)
                label = 1 ### added
                
            if random.random() < anomaly_rate:
                anomaly_type = random.choice(['tax_calc', 'line_total', 'skip_tax', 'negative_qty', 'price_mismatch'])
                if anomaly_type == 'tax_calc':
                    line_tax = round(line_total * random.uniform(0.05, 0.25), 2)
                elif anomaly_type == 'line_total':
                    # Slightly off multiplication
                    line_total = round(adjusted_unit_price * qty * random.uniform(0.9, 1.1), 2)
                elif anomaly_type == 'skip_tax':
                    line_tax = 0.0
                elif anomaly_type == 'negative_qty':
                    qty = -abs(qty)
                elif anomaly_type == 'price_mismatch':
                    catalog_price = product["unit_price"]
                    deviation = random.uniform(0.5, 2.0)
                    adjusted_unit_price = catalog_price * deviation
                label = 1 ### added
            
            # Add line details to our formatted output
            formatted_line_details.append({
                "line_count": str(i),
                "line_description": description,
                "line_qty": str(qty),
                "line_tax": "{:.2f}".format(line_tax),
                "line_total": "{:.2f}".format(line_total),
                "model": product["model"]  # Add this line
            })
            # ---------------------------------------------------------------
            
            # Add to running totals
            subtotal += line_total
            total_tax += line_tax
        
        # Calculate grand total
        grand_total = subtotal + total_tax + shipping_cost
        
        # State label => 1 if state not in the dictionary or country != "US"
        if (state not in tax_rates) or (country != "US"):
            state_label = 1
        else:
            state_label = 0
        
        # ------------------------Modiefied------------------------------    
        # Create formatted invoice following the schema
        formatted_invoice = {
            "invoice_id": f"INV-{uuid.uuid4().hex[:8].upper()}",
            "invoice_date": invoice_date_str,  # Added this
            "extractions": [
                {"field": "merchant", "value": merchant_name},
                {"field": "invoice_date", "value": invoice_date_str},
                {"field": "merchant_branch", "value": merchant_name},  # Using same value as merchant
                {"field": "merchant_chain", "value": merchant_name},   # Using same value as merchant
                {"field": "due_date", "value": due_date_str},
                {"field": "payment_terms", "value": payment_term},
                {"field": "grand_total", "value": "{:.2f}".format(grand_total)},
                {"field": "tax", "value": "{:.2f}".format(total_tax)},
                {"field": "po_number", "value": po_number},
                {"field": "merchant_address", "value": merchant_address.replace(',', '')},
                {"field": "payment_method", "value": payment_method},
                {'field': "payment_label", "value": payment_label}, ### identify payment anomaly
                {"field": "country", "value": country},
                {"field": "currency", "value": currency},
                {'field': 'tax_label', 'value': label}, ### identify tax anomaly
                {"field": "line_details", "value": formatted_line_details},
                {"field": "state_label", "value": state_label}  ### state anomaly feature
            ],
            "line_details": formatted_line_details
        }
        # --------------------------------------------------------------
        
        invoices.append(formatted_invoice)
    
    # po_records[po_number].append({"merchant": merchant_name, "grand_total": grand_total})
    
    return invoices

def analyze_synthetic_data(invoices):
    """
    Analyze the generated synthetic data
    
    Parameters:
    invoices (list): List of invoice dictionaries
    """
    # Count merchants
    merchants = set()
    countries = set()
    total_value = 0
    line_items_count = 0
    
    for invoice in invoices:
        extractions = {item["field"]: item["value"] for item in invoice["extractions"]}
        
        if "merchant" in extractions:
            merchants.add(extractions["merchant"])
        
        if "country" in extractions:
            countries.add(extractions["country"])
        
        if "grand_total" in extractions:
            try:
                total_value += float(extractions["grand_total"])
            except ValueError:
                pass
        
        if "line_details" in extractions:
            line_items = extractions["line_details"]
            if isinstance(line_items, list):
                line_items_count += len(line_items)
    
    print(f"Analysis of {len(invoices)} invoices:")
    print(f"- Unique merchants: {len(merchants)}")
    print(f"- Total line items: {line_items_count}")
    print(f"- Average line items per invoice: {line_items_count/len(invoices):.2f}")
    
    # Count frequency of fields
    field_counts = defaultdict(int)
    for invoice in invoices:
        for item in invoice["extractions"]:
            field_counts[item["field"]] += 1
    
    print("\nField frequency:")
    for field, count in sorted(field_counts.items(), key=lambda x: x[1], reverse=True):
        percentage = count / len(invoices) * 100
        print(f"- {field}: {count} ({percentage:.1f}%)")

def save_synthetic_data(invoices, base_filename="synthetic_invoices2"): #change filename here ###
    """   
    Parameters:
    invoices (list): List of invoice dictionaries
    base_filename (str): Base filename without extension
    """
    # Save all invoices to one file
    all_filename = f"{base_filename}.json"
    with open(all_filename, 'w') as f:
        json.dump(invoices, f, indent=2)
    
    print(f"Generated {len(invoices)} synthetic invoices and saved to {all_filename}")
    
    # Save in JSONL format as well (one invoice per line, no indentation)
    jsonl_filename = f"{base_filename}.jsonl"
    with open(jsonl_filename, 'w') as f:
        for invoice in invoices:
            f.write(json.dumps(invoice) + '\n')
    
    print(f"Saved invoices in JSONL format to {jsonl_filename}")

# Main function to generate invoices
def generate_dataset(num_invoices=100, num_merchants=1000, anomaly_rate=0.05, seed=42):
    """
    Generate a complete synthetic invoice dataset
    
    Parameters:
    num_invoices (int): Number of invoices to generate
    anomaly_rate (float): Rate of anomalies to introduce
    seed (int): Random seed for reproducibility
    
    Returns:
    list: Generated invoices
    """
    # Set random seeds
    random.seed(seed)
    np.random.seed(seed)
    Faker.seed(seed)
    
    print(f"Generating {num_invoices} synthetic invoices across a set of {num_merchants} merchants (anomaly rate: {anomaly_rate:.1%})...")
    invoices = generate_synthetic_invoice(num_invoices, num_merchants, anomaly_rate)
    
    # Analyze the generated data
    analyze_synthetic_data(invoices)
    
    # Save the data
    save_synthetic_data(invoices)
    
    return invoices

# %%
# Generate invoices when run directly

generate_dataset(num_invoices=10,num_merchants=100)
# Out:
# Generating 10 synthetic invoices across a set of 100 merchants (anomaly rate: 5.0%)...
# Analysis of 10 invoices:
# - Unique merchants: 8
# - Total line items: 32
# - Average line items per invoice: 3.20
#
# Field frequency:
# - merchant: 10 (100.0%)
# - invoice_date: 10 (100.0%)
# - merchant_branch: 10 (100.0%)
# - merchant_chain: 10 (100.0%)
# - due_date: 10 (100.0%)
# - payment_terms: 10 (100.0%)
# - grand_total: 10 (100.0%)
# - tax: 10 (100.0%)
# - po_number: 10 (100.0%)
# - merchant_address: 10 (100.0%)
# - payment_method: 10 (100.0%)
# - payment_label: 10 (100.0%)
# - country: 10 (100.0%)
# - currency: 10 (100.0%)
# - tax_label: 10 (100.0%)
# - line_details: 10 (100.0%)
# - state_label: 10 (100.0%)
# Generated 10 synthetic invoices and saved to synthetic_invoices2.json
# Saved invoices in JSONL format to synthetic_invoices2.jsonl
# [{'invoice_id': 'INV-43E2319E',
#   'invoice_date': '02/03/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '02/03/2025'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '04/04/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '379032.20'},
#    {'field': 'tax', 'value': '14577.10'},
#    {'field': 'po_number', 'value': '2503-3344'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'A-6368 Deluxe Structural Component',
#       'line_qty': '100',
#       'line_tax': '14366.87',
#       'line_total': '359171.74',
#       'model': 'A-6368'},
#      {'line_count': '2',
#       'line_description': 'FD-0317 Extended Safety Mechanism',
#       'line_qty': '1',
#       'line_tax': '210.23',
#       'line_total': '5255.87',
#       'model': 'FD-0317'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'A-6368 Deluxe Structural Component',
#     'line_qty': '100',
#     'line_tax': '14366.87',
#     'line_total': '359171.74',
#     'model': 'A-6368'},
#    {'line_count': '2',
#     'line_description': 'FD-0317 Extended Safety Mechanism',
#     'line_qty': '1',
#     'line_tax': '210.23',
#     'line_total': '5255.87',
#     'model': 'FD-0317'}]},
#  {'invoice_id': 'INV-D8E559C5',
#   'invoice_date': '12/23/2024',
#   'extractions': [{'field': 'merchant',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'invoice_date', 'value': '12/23/2024'},
#    {'field': 'merchant_branch',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'merchant_chain',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'due_date', 'value': '02/06/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '272.87'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': '2503-2846'},
#    {'field': 'merchant_address',
#     'value': '2245 Sims Manor Apt. 417 Port Patricia PW 50796 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'UH-06868 Economy Hardware',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '251.48',
#       'model': 'UH-06868'}]},
#    {'field': 'state_label', 'value': 1}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'UH-06868 Economy Hardware',
#     'line_qty': '1',
#     'line_tax': '0.00',
#     'line_total': '251.48',
#     'model': 'UH-06868'}]},
#  {'invoice_id': 'INV-2D627554',
#   'invoice_date': '03/07/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'invoice_date', 'value': '03/07/2025'},
#    {'field': 'merchant_branch', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'merchant_chain', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'due_date', 'value': '03/07/2025'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '130892.87'},
#    {'field': 'tax', 'value': '8136.12'},
#    {'field': 'po_number', 'value': 'PO-30715'},
#    {'field': 'merchant_address',
#     'value': '5744 Gonzalez Knoll Larsonbury NJ 46878 USA'},
#    {'field': 'payment_method', 'value': 'PayPal'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'HVB-84700 Compact Gauge',
#       'line_qty': '2',
#       'line_tax': '53.64',
#       'line_total': '808.98',
#       'model': 'HVB-84700'},
#      {'line_count': '2',
#       'line_description': 'NJA-09743 High Performance Valve',
#       'line_qty': '1',
#       'line_tax': '31.48',
#       'line_total': '474.82',
#       'model': 'NJA-09743'},
#      {'line_count': '3',
#       'line_description': 'K-7005 Basic Compressor',
#       'line_qty': '50',
#       'line_tax': '1206.08',
#       'line_total': '18191.20',
#       'model': 'K-7005'},
#      {'line_count': '4',
#       'line_description': 'NSC-4535 Ultimate Conveyor Belt',
#       'line_qty': '100',
#       'line_tax': '5723.20',
#       'line_total': '86322.83',
#       'model': 'NSC-4535'},
#      {'line_count': '5',
#       'line_description': 'T-473 Heavy Duty Gauge',
#       'line_qty': '24',
#       'line_tax': '1121.72',
#       'line_total': '16918.87',
#       'model': 'T-473'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'HVB-84700 Compact Gauge',
#     'line_qty': '2',
#     'line_tax': '53.64',
#     'line_total': '808.98',
#     'model': 'HVB-84700'},
#    {'line_count': '2',
#     'line_description': 'NJA-09743 High Performance Valve',
#     'line_qty': '1',
#     'line_tax': '31.48',
#     'line_total': '474.82',
#     'model': 'NJA-09743'},
#    {'line_count': '3',
#     'line_description': 'K-7005 Basic Compressor',
#     'line_qty': '50',
#     'line_tax': '1206.08',
#     'line_total': '18191.20',
#     'model': 'K-7005'},
#    {'line_count': '4',
#     'line_description': 'NSC-4535 Ultimate Conveyor Belt',
#     'line_qty': '100',
#     'line_tax': '5723.20',
#     'line_total': '86322.83',
#     'model': 'NSC-4535'},
#    {'line_count': '5',
#     'line_description': 'T-473 Heavy Duty Gauge',
#     'line_qty': '24',
#     'line_tax': '1121.72',
#     'line_total': '16918.87',
#     'model': 'T-473'}]},
#  {'invoice_id': 'INV-78FD3A43',
#   'invoice_date': '11/14/2024',
#   'extractions': [{'field': 'merchant', 'value': 'Taylor Automotive Co.'},
#    {'field': 'invoice_date', 'value': '11/14/2024'},
#    {'field': 'merchant_branch', 'value': 'Taylor Automotive Co.'},
#    {'field': 'merchant_chain', 'value': 'Taylor Automotive Co.'},
#    {'field': 'due_date', 'value': '12/29/2024'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '9597.15'},
#    {'field': 'tax', 'value': '411.93'},
#    {'field': 'po_number', 'value': '2503-9015'},
#    {'field': 'merchant_address',
#     'value': '82198 Wilson Harbors Suite 932 Millerstad OK 82021 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'VWC-352 Economy Diagnostic Tool',
#       'line_qty': '24',
#       'line_tax': '393.79',
#       'line_total': '8750.98',
#       'model': 'VWC-352'},
#      {'line_count': '2',
#       'line_description': 'CW-4152 Standard Transmission Part',
#       'line_qty': '1',
#       'line_tax': '18.14',
#       'line_total': '403.16',
#       'model': 'CW-4152'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'VWC-352 Economy Diagnostic Tool',
#     'line_qty': '24',
#     'line_tax': '393.79',
#     'line_total': '8750.98',
#     'model': 'VWC-352'},
#    {'line_count': '2',
#     'line_description': 'CW-4152 Standard Transmission Part',
#     'line_qty': '1',
#     'line_tax': '18.14',
#     'line_total': '403.16',
#     'model': 'CW-4152'}]},
#  {'invoice_id': 'INV-B9AA1F29',
#   'invoice_date': '01/30/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Manage Aerospace Systems'},
#    {'field': 'invoice_date', 'value': '01/30/2025'},
#    {'field': 'merchant_branch', 'value': 'Manage Aerospace Systems'},
#    {'field': 'merchant_chain', 'value': 'Manage Aerospace Systems'},
#    {'field': 'due_date', 'value': '01/30/2025'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '62845.62'},
#    {'field': 'tax', 'value': '4489.97'},
#    {'field': 'po_number', 'value': 'PO-74918'},
#    {'field': 'merchant_address',
#     'value': '116 Joel Vista Suite 990 Susantown OK 95058 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'FAM-55438 Professional Cabin Equipment',
#       'line_qty': '3',
#       'line_tax': '655.41',
#       'line_total': '14564.59',
#       'model': 'FAM-55438'},
#      {'line_count': '2',
#       'line_description': 'VZ-069 Advanced Safety Mechanism',
#       'line_qty': '10',
#       'line_tax': '2888.96',
#       'line_total': '22752.08',
#       'model': 'VZ-069'},
#      {'line_count': '3',
#       'line_description': 'FV-430 Premium Cabin Equipment',
#       'line_qty': '5',
#       'line_tax': '186.14',
#       'line_total': '4136.41',
#       'model': 'FV-430'},
#      {'line_count': '4',
#       'line_description': 'GG-4857 Economy Communication Device',
#       'line_qty': '4',
#       'line_tax': '463.76',
#       'line_total': '10305.76',
#       'model': 'GG-4857'},
#      {'line_count': '5',
#       'line_description': 'U-82665 Compact Navigation System',
#       'line_qty': '2',
#       'line_tax': '295.70',
#       'line_total': '6571.14',
#       'model': 'U-82665'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'FAM-55438 Professional Cabin Equipment',
#     'line_qty': '3',
#     'line_tax': '655.41',
#     'line_total': '14564.59',
#     'model': 'FAM-55438'},
#    {'line_count': '2',
#     'line_description': 'VZ-069 Advanced Safety Mechanism',
#     'line_qty': '10',
#     'line_tax': '2888.96',
#     'line_total': '22752.08',
#     'model': 'VZ-069'},
#    {'line_count': '3',
#     'line_description': 'FV-430 Premium Cabin Equipment',
#     'line_qty': '5',
#     'line_tax': '186.14',
#     'line_total': '4136.41',
#     'model': 'FV-430'},
#    {'line_count': '4',
#     'line_description': 'GG-4857 Economy Communication Device',
#     'line_qty': '4',
#     'line_tax': '463.76',
#     'line_total': '10305.76',
#     'model': 'GG-4857'},
#    {'line_count': '5',
#     'line_description': 'U-82665 Compact Navigation System',
#     'line_qty': '2',
#     'line_tax': '295.70',
#     'line_total': '6571.14',
#     'model': 'U-82665'}]},
#  {'invoice_id': 'INV-DC6D2091',
#   'invoice_date': '03/11/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '03/11/2025'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '04/10/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '7746.40'},
#    {'field': 'tax', 'value': '296.45'},
#    {'field': 'po_number', 'value': '245129'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'L-8299 Lightweight Structural Component',
#       'line_qty': '1',
#       'line_tax': '151.47',
#       'line_total': '3786.86',
#       'model': 'L-8299'},
#      {'line_count': '2',
#       'line_description': 'C-9587 Standard Communication Device',
#       'line_qty': '1',
#       'line_tax': '144.98',
#       'line_total': '3624.56',
#       'model': 'C-9587'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'L-8299 Lightweight Structural Component',
#     'line_qty': '1',
#     'line_tax': '151.47',
#     'line_total': '3786.86',
#     'model': 'L-8299'},
#    {'line_count': '2',
#     'line_description': 'C-9587 Standard Communication Device',
#     'line_qty': '1',
#     'line_tax': '144.98',
#     'line_total': '3624.56',
#     'model': 'C-9587'}]},
#  {'invoice_id': 'INV-93738171',
#   'invoice_date': '12/05/2024',
#   'extractions': [{'field': 'merchant', 'value': 'Such LLC'},
#    {'field': 'invoice_date', 'value': '12/05/2024'},
#    {'field': 'merchant_branch', 'value': 'Such LLC'},
#    {'field': 'merchant_chain', 'value': 'Such LLC'},
#    {'field': 'due_date', 'value': '01/19/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '19311.06'},
#    {'field': 'tax', 'value': '831.58'},
#    {'field': 'po_number', 'value': 'PO-18601'},
#    {'field': 'merchant_address',
#     'value': '98751 Ryan Plains East Derrick OK 20437 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'GV-7312 Basic Label Maker',
#       'line_qty': '2',
#       'line_tax': '7.98',
#       'line_total': '177.26',
#       'model': 'GV-7312'},
#      {'line_count': '2',
#       'line_description': 'U-52058 Heavy Duty Label Maker',
#       'line_qty': '100',
#       'line_tax': '823.60',
#       'line_total': '18302.22',
#       'model': 'U-52058'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'GV-7312 Basic Label Maker',
#     'line_qty': '2',
#     'line_tax': '7.98',
#     'line_total': '177.26',
#     'model': 'GV-7312'},
#    {'line_count': '2',
#     'line_description': 'U-52058 Heavy Duty Label Maker',
#     'line_qty': '100',
#     'line_tax': '823.60',
#     'line_total': '18302.22',
#     'model': 'U-52058'}]},
#  {'invoice_id': 'INV-168A3224',
#   'invoice_date': '02/13/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Anderson-Perry Inc.'},
#    {'field': 'invoice_date', 'value': '02/13/2025'},
#    {'field': 'merchant_branch', 'value': 'Anderson-Perry Inc.'},
#    {'field': 'merchant_chain', 'value': 'Anderson-Perry Inc.'},
#    {'field': 'due_date', 'value': '03/15/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '1398.77'},
#    {'field': 'tax', 'value': '38.01'},
#    {'field': 'po_number', 'value': 'L95951'},
#    {'field': 'merchant_address',
#     'value': '213 Holland Shoal Suite 525 Wrightstad OK 87218 USA'},
#    {'field': 'payment_method', 'value': 'Check'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 1},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'CFW-7997 Economy Motor',
#       'line_qty': '2',
#       'line_tax': '38.01',
#       'line_total': '844.59',
#       'model': 'CFW-7997'},
#      {'line_count': '2',
#       'line_description': 'KMD-83273 Basic Bearing',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '516.17',
#       'model': 'KMD-83273'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'CFW-7997 Economy Motor',
#     'line_qty': '2',
#     'line_tax': '38.01',
#     'line_total': '844.59',
#     'model': 'CFW-7997'},
#    {'line_count': '2',
#     'line_description': 'KMD-83273 Basic Bearing',
#     'line_qty': '1',
#     'line_tax': '0.00',
#     'line_total': '516.17',
#     'model': 'KMD-83273'}]},
#  {'invoice_id': 'INV-90DAF137',
#   'invoice_date': '09/27/2024',
#   'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '09/27/2024'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '11/11/2024'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '398572.85'},
#    {'field': 'tax', 'value': '15328.31'},
#    {'field': 'po_number', 'value': '80165-392'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'PayPal'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'NZB-68034 Compact Safety Mechanism',
#       'line_qty': '5',
#       'line_tax': '438.78',
#       'line_total': '10969.56',
#       'model': 'NZB-68034'},
#      {'line_count': '2',
#       'line_description': 'WF-230 High Performance Cabin Equipment',
#       'line_qty': '3',
#       'line_tax': '470.55',
#       'line_total': '11763.66',
#       'model': 'WF-230'},
#      {'line_count': '3',
#       'line_description': 'G-220 Ultimate Structural Component',
#       'line_qty': '50',
#       'line_tax': '14418.98',
#       'line_total': '360474.50',
#       'model': 'G-220'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'NZB-68034 Compact Safety Mechanism',
#     'line_qty': '5',
#     'line_tax': '438.78',
#     'line_total': '10969.56',
#     'model': 'NZB-68034'},
#    {'line_count': '2',
#     'line_description': 'WF-230 High Performance Cabin Equipment',
#     'line_qty': '3',
#     'line_tax': '470.55',
#     'line_total': '11763.66',
#     'model': 'WF-230'},
#    {'line_count': '3',
#     'line_description': 'G-220 Ultimate Structural Component',
#     'line_qty': '50',
#     'line_tax': '14418.98',
#     'line_total': '360474.50',
#     'model': 'G-220'}]},
#  {'invoice_id': 'INV-EDA8753A',
#   'invoice_date': '02/18/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Martinez'},
#    {'field': 'invoice_date', 'value': '02/18/2025'},
#    {'field': 'merchant_branch', 'value': 'Martinez'},
#    {'field': 'merchant_chain', 'value': 'Martinez'},
#    {'field': 'due_date', 'value': '04/04/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '34245.45'},
#    {'field': 'tax', 'value': '2088.04'},
#    {'field': 'po_number', 'value': '85199-782'},
#    {'field': 'merchant_address',
#     'value': '79463 Patrick Lodge Barnesville KS 32663 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'U-8562 Ultimate Fluid',
#       'line_qty': '3',
#       'line_tax': '21.04',
#       'line_total': '323.63',
#       'model': 'U-8562'},
#      {'line_count': '2',
#       'line_description': 'ESN-9296 Lightweight Brake System',
#       'line_qty': '5',
#       'line_tax': '178.70',
#       'line_total': '2749.17',
#       'model': 'ESN-9296'},
#      {'line_count': '3',
#       'line_description': 'VWC-352 Economy Diagnostic Tool',
#       'line_qty': '4',
#       'line_tax': '105.81',
#       'line_total': '1627.79',
#       'model': 'VWC-352'},
#      {'line_count': '4',
#       'line_description': 'SDU-485 Extended Electrical Component',
#       'line_qty': '10',
#       'line_tax': '429.03',
#       'line_total': '6600.53',
#       'model': 'SDU-485'},
#      {'line_count': '5',
#       'line_description': 'VWC-352 Economy Diagnostic Tool',
#       'line_qty': '24',
#       'line_tax': '549.89',
#       'line_total': '8459.83',
#       'model': 'VWC-352'},
#      {'line_count': '6',
#       'line_description': 'RSW-9696 High Performance Brake System',
#       'line_qty': '1',
#       'line_tax': '43.58',
#       'line_total': '670.41',
#       'model': 'RSW-9696'},
#      {'line_count': '7',
#       'line_description': 'JQR-586 Lightweight Engine Component',
#       'line_qty': '1',
#       'line_tax': '11.64',
#       'line_total': '179.15',
#       'model': 'JQR-586'},
#      {'line_count': '8',
#       'line_description': 'LK-79356 Professional Transmission Part',
#       'line_qty': '24',
#       'line_tax': '748.35',
#       'line_total': '11513.04',
#       'model': 'LK-79356'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'U-8562 Ultimate Fluid',
#     'line_qty': '3',
#     'line_tax': '21.04',
#     'line_total': '323.63',
#     'model': 'U-8562'},
#    {'line_count': '2',
#     'line_description': 'ESN-9296 Lightweight Brake System',
#     'line_qty': '5',
#     'line_tax': '178.70',
#     'line_total': '2749.17',
#     'model': 'ESN-9296'},
#    {'line_count': '3',
#     'line_description': 'VWC-352 Economy Diagnostic Tool',
#     'line_qty': '4',
#     'line_tax': '105.81',
#     'line_total': '1627.79',
#     'model': 'VWC-352'},
#    {'line_count': '4',
#     'line_description': 'SDU-485 Extended Electrical Component',
#     'line_qty': '10',
#     'line_tax': '429.03',
#     'line_total': '6600.53',
#     'model': 'SDU-485'},
#    {'line_count': '5',
#     'line_description': 'VWC-352 Economy Diagnostic Tool',
#     'line_qty': '24',
#     'line_tax': '549.89',
#     'line_total': '8459.83',
#     'model': 'VWC-352'},
#    {'line_count': '6',
#     'line_description': 'RSW-9696 High Performance Brake System',
#     'line_qty': '1',
#     'line_tax': '43.58',
#     'line_total': '670.41',
#     'model': 'RSW-9696'},
#    {'line_count': '7',
#     'line_description': 'JQR-586 Lightweight Engine Component',
#     'line_qty': '1',
#     'line_tax': '11.64',
#     'line_total': '179.15',
#     'model': 'JQR-586'},
#    {'line_count': '8',
#     'line_description': 'LK-79356 Professional Transmission Part',
#     'line_qty': '24',
#     'line_tax': '748.35',
#     'line_total': '11513.04',
#     'model': 'LK-79356'}]}]

# %%
generate_dataset(num_invoices=100,num_merchants=50)
# Out:
# Generating 100 synthetic invoices across a set of 50 merchants (anomaly rate: 5.0%)...
# Analysis of 102 invoices:
# - Unique merchants: 30
# - Total line items: 375
# - Average line items per invoice: 3.68
#
# Field frequency:
# - merchant: 102 (100.0%)
# - invoice_date: 102 (100.0%)
# - merchant_branch: 102 (100.0%)
# - merchant_chain: 102 (100.0%)
# - due_date: 102 (100.0%)
# - payment_terms: 102 (100.0%)
# - grand_total: 102 (100.0%)
# - tax: 102 (100.0%)
# - po_number: 102 (100.0%)
# - merchant_address: 102 (100.0%)
# - payment_method: 102 (100.0%)
# - payment_label: 102 (100.0%)
# - country: 102 (100.0%)
# - currency: 102 (100.0%)
# - tax_label: 102 (100.0%)
# - line_details: 102 (100.0%)
# - state_label: 102 (100.0%)
# Generated 102 synthetic invoices and saved to synthetic_invoices2.json
# Saved invoices in JSONL format to synthetic_invoices2.jsonl
# [{'invoice_id': 'INV-DE1F199F',
#   'invoice_date': '03/04/2025',
#   'extractions': [{'field': 'merchant',
#     'value': 'EnterOfficer Technology LLC'},
#    {'field': 'invoice_date', 'value': '03/04/2025'},
#    {'field': 'merchant_branch', 'value': 'EnterOfficer Technology LLC'},
#    {'field': 'merchant_chain', 'value': 'EnterOfficer Technology LLC'},
#    {'field': 'due_date', 'value': '03/04/2025'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '83459.57'},
#    {'field': 'tax', 'value': '3593.09'},
#    {'field': 'po_number', 'value': '612997'},
#    {'field': 'merchant_address',
#     'value': '07878 Paula Points Boydland OK 51912 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'F-90878 Premium Network Device',
#       'line_qty': '10',
#       'line_tax': '1188.90',
#       'line_total': '26419.94',
#       'model': 'F-90878'},
#      {'line_count': '2',
#       'line_description': 'TED-099 Lightweight Server',
#       'line_qty': '24',
#       'line_tax': '1749.88',
#       'line_total': '38886.20',
#       'model': 'TED-099'},
#      {'line_count': '3',
#       'line_description': 'N-99586 Lightweight Network Device',
#       'line_qty': '2',
#       'line_tax': '38.67',
#       'line_total': '859.34',
#       'model': 'N-99586'},
#      {'line_count': '4',
#       'line_description': 'YF-752 Heavy Duty Network Device',
#       'line_qty': '4',
#       'line_tax': '531.04',
#       'line_total': '11800.86',
#       'model': 'YF-752'},
#      {'line_count': '5',
#       'line_description': 'AB-35058 Commercial Cable',
#       'line_qty': '1',
#       'line_tax': '84.60',
#       'line_total': '1879.94',
#       'model': 'AB-35058'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'F-90878 Premium Network Device',
#     'line_qty': '10',
#     'line_tax': '1188.90',
#     'line_total': '26419.94',
#     'model': 'F-90878'},
#    {'line_count': '2',
#     'line_description': 'TED-099 Lightweight Server',
#     'line_qty': '24',
#     'line_tax': '1749.88',
#     'line_total': '38886.20',
#     'model': 'TED-099'},
#    {'line_count': '3',
#     'line_description': 'N-99586 Lightweight Network Device',
#     'line_qty': '2',
#     'line_tax': '38.67',
#     'line_total': '859.34',
#     'model': 'N-99586'},
#    {'line_count': '4',
#     'line_description': 'YF-752 Heavy Duty Network Device',
#     'line_qty': '4',
#     'line_tax': '531.04',
#     'line_total': '11800.86',
#     'model': 'YF-752'},
#    {'line_count': '5',
#     'line_description': 'AB-35058 Commercial Cable',
#     'line_qty': '1',
#     'line_tax': '84.60',
#     'line_total': '1879.94',
#     'model': 'AB-35058'}]},
#  {'invoice_id': 'INV-040E0B3F',
#   'invoice_date': '12/29/2024',
#   'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '12/29/2024'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '02/12/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '9019.64'},
#    {'field': 'tax', 'value': '346.91'},
#    {'field': 'po_number', 'value': '2503-6527'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'LQH-6096 Deluxe Cabin Equipment',
#       'line_qty': '10',
#       'line_tax': '346.91',
#       'line_total': '8672.73',
#       'model': 'LQH-6096'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'LQH-6096 Deluxe Cabin Equipment',
#     'line_qty': '10',
#     'line_tax': '346.91',
#     'line_total': '8672.73',
#     'model': 'LQH-6096'}]},
#  {'invoice_id': 'INV-625F38AE',
#   'invoice_date': '03/10/2025',
#   'extractions': [{'field': 'merchant', 'value': 'WorryAdult'},
#    {'field': 'invoice_date', 'value': '03/10/2025'},
#    {'field': 'merchant_branch', 'value': 'WorryAdult'},
#    {'field': 'merchant_chain', 'value': 'WorryAdult'},
#    {'field': 'due_date', 'value': '04/09/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '44527.36'},
#    {'field': 'tax', 'value': '2913.00'},
#    {'field': 'po_number', 'value': '2503-3185'},
#    {'field': 'merchant_address',
#     'value': '23616 Blackburn Field Sergiochester TN 56955 USA'},
#    {'field': 'payment_method', 'value': 'Credit Card'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'EQB-352 Ultimate Cabin Equipment',
#       'line_qty': '10',
#       'line_tax': '2127.57',
#       'line_total': '30393.92',
#       'model': 'EQB-352'},
#      {'line_count': '2',
#       'line_description': 'KN-251 Compact Communication Device',
#       'line_qty': '1',
#       'line_tax': '201.47',
#       'line_total': '2878.16',
#       'model': 'KN-251'},
#      {'line_count': '3',
#       'line_description': 'T-9830 Industrial Navigation System',
#       'line_qty': '1',
#       'line_tax': '119.40',
#       'line_total': '1705.73',
#       'model': 'T-9830'},
#      {'line_count': '4',
#       'line_description': 'YYV-82795 Advanced Safety Mechanism',
#       'line_qty': '1',
#       'line_tax': '464.56',
#       'line_total': '6636.55',
#       'model': 'YYV-82795'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'EQB-352 Ultimate Cabin Equipment',
#     'line_qty': '10',
#     'line_tax': '2127.57',
#     'line_total': '30393.92',
#     'model': 'EQB-352'},
#    {'line_count': '2',
#     'line_description': 'KN-251 Compact Communication Device',
#     'line_qty': '1',
#     'line_tax': '201.47',
#     'line_total': '2878.16',
#     'model': 'KN-251'},
#    {'line_count': '3',
#     'line_description': 'T-9830 Industrial Navigation System',
#     'line_qty': '1',
#     'line_tax': '119.40',
#     'line_total': '1705.73',
#     'model': 'T-9830'},
#    {'line_count': '4',
#     'line_description': 'YYV-82795 Advanced Safety Mechanism',
#     'line_qty': '1',
#     'line_tax': '464.56',
#     'line_total': '6636.55',
#     'model': 'YYV-82795'}]},
#  {'invoice_id': 'INV-B2E1B795',
#   'invoice_date': '03/14/2025',
#   'extractions': [{'field': 'merchant', 'value': 'WorryAdult'},
#    {'field': 'invoice_date', 'value': '03/14/2025'},
#    {'field': 'merchant_branch', 'value': 'WorryAdult'},
#    {'field': 'merchant_chain', 'value': 'WorryAdult'},
#    {'field': 'due_date', 'value': '04/13/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '153692.78'},
#    {'field': 'tax', 'value': '10051.62'},
#    {'field': 'po_number', 'value': '80742-619'},
#    {'field': 'merchant_address',
#     'value': '23616 Blackburn Field Sergiochester TN 56955 USA'},
#    {'field': 'payment_method', 'value': 'Net Banking'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'T-9830 Industrial Navigation System',
#       'line_qty': '1',
#       'line_tax': '117.85',
#       'line_total': '1683.55',
#       'model': 'T-9830'},
#      {'line_count': '2',
#       'line_description': 'YYV-82795 Advanced Safety Mechanism',
#       'line_qty': '24',
#       'line_tax': '9697.63',
#       'line_total': '138537.62',
#       'model': 'YYV-82795'},
#      {'line_count': '3',
#       'line_description': 'EQB-352 Ultimate Cabin Equipment',
#       'line_qty': '1',
#       'line_tax': '236.14',
#       'line_total': '3373.47',
#       'model': 'EQB-352'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'T-9830 Industrial Navigation System',
#     'line_qty': '1',
#     'line_tax': '117.85',
#     'line_total': '1683.55',
#     'model': 'T-9830'},
#    {'line_count': '2',
#     'line_description': 'YYV-82795 Advanced Safety Mechanism',
#     'line_qty': '24',
#     'line_tax': '9697.63',
#     'line_total': '138537.62',
#     'model': 'YYV-82795'},
#    {'line_count': '3',
#     'line_description': 'EQB-352 Ultimate Cabin Equipment',
#     'line_qty': '1',
#     'line_tax': '236.14',
#     'line_total': '3373.47',
#     'model': 'EQB-352'}]},
#  {'invoice_id': 'INV-03FA4C34',
#   'invoice_date': '12/29/2024',
#   'extractions': [{'field': 'merchant', 'value': 'Jones & Wilson'},
#    {'field': 'invoice_date', 'value': '12/29/2024'},
#    {'field': 'merchant_branch', 'value': 'Jones & Wilson'},
#    {'field': 'merchant_chain', 'value': 'Jones & Wilson'},
#    {'field': 'due_date', 'value': '02/12/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '16773.61'},
#    {'field': 'tax', 'value': '1021.76'},
#    {'field': 'po_number', 'value': 'PO-24435'},
#    {'field': 'merchant_address',
#     'value': '1910 Booth Roads Suite 855 Lake Andrea WA 92917 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'U-5223 High Performance Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '79.49',
#       'line_total': '1222.89',
#       'model': 'U-5223'},
#      {'line_count': '2',
#       'line_description': 'DB-0296 Basic Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '70.74',
#       'line_total': '1088.28',
#       'model': 'DB-0296'},
#      {'line_count': '3',
#       'line_description': 'P-27136 Premium Monitor',
#       'line_qty': '1',
#       'line_tax': '152.82',
#       'line_total': '2351.11',
#       'model': 'P-27136'},
#      {'line_count': '4',
#       'line_description': 'F-49035 Industrial Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '49.53',
#       'line_total': '762.00',
#       'model': 'F-49035'},
#      {'line_count': '5',
#       'line_description': 'EN-65827 Ultimate Monitor',
#       'line_qty': '3',
#       'line_tax': '669.18',
#       'line_total': '10295.15',
#       'model': 'EN-65827'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'U-5223 High Performance Surgical Instrument',
#     'line_qty': '1',
#     'line_tax': '79.49',
#     'line_total': '1222.89',
#     'model': 'U-5223'},
#    {'line_count': '2',
#     'line_description': 'DB-0296 Basic Surgical Instrument',
#     'line_qty': '1',
#     'line_tax': '70.74',
#     'line_total': '1088.28',
#     'model': 'DB-0296'},
#    {'line_count': '3',
#     'line_description': 'P-27136 Premium Monitor',
#     'line_qty': '1',
#     'line_tax': '152.82',
#     'line_total': '2351.11',
#     'model': 'P-27136'},
#    {'line_count': '4',
#     'line_description': 'F-49035 Industrial Surgical Instrument',
#     'line_qty': '1',
#     'line_tax': '49.53',
#     'line_total': '762.00',
#     'model': 'F-49035'},
#    {'line_count': '5',
#     'line_description': 'EN-65827 Ultimate Monitor',
#     'line_qty': '3',
#     'line_tax': '669.18',
#     'line_total': '10295.15',
#     'model': 'EN-65827'}]},
#  {'invoice_id': 'INV-4B127212',
#   'invoice_date': '03/10/2025',
#   'extractions': [{'field': 'merchant',
#     'value': 'EveryoneOther Office Supplies Systems'},
#    {'field': 'invoice_date', 'value': '03/10/2025'},
#    {'field': 'merchant_branch',
#     'value': 'EveryoneOther Office Supplies Systems'},
#    {'field': 'merchant_chain',
#     'value': 'EveryoneOther Office Supplies Systems'},
#    {'field': 'due_date', 'value': '03/25/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '543.99'},
#    {'field': 'tax', 'value': '15.34'},
#    {'field': 'po_number', 'value': 'PO-66113'},
#    {'field': 'merchant_address',
#     'value': '98133 Glover Common North Markborough CO 80347 USA'},
#    {'field': 'payment_method', 'value': 'PayPal'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'VE-62229 Ultimate Label Maker',
#       'line_qty': '10',
#       'line_tax': '8.58',
#       'line_total': '295.72',
#       'model': 'VE-62229'},
#      {'line_count': '2',
#       'line_description': 'TL-27722 Premium Paper',
#       'line_qty': '1',
#       'line_tax': '0.74',
#       'line_total': '25.54',
#       'model': 'TL-27722'},
#      {'line_count': '3',
#       'line_description': 'BAC-943 Ultimate Ink Cartridge',
#       'line_qty': '2',
#       'line_tax': '1.63',
#       'line_total': '56.08',
#       'model': 'BAC-943'},
#      {'line_count': '4',
#       'line_description': 'UC-517 Compact Document Scanner',
#       'line_qty': '1',
#       'line_tax': '4.39',
#       'line_total': '151.31',
#       'model': 'UC-517'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'VE-62229 Ultimate Label Maker',
#     'line_qty': '10',
#     'line_tax': '8.58',
#     'line_total': '295.72',
#     'model': 'VE-62229'},
#    {'line_count': '2',
#     'line_description': 'TL-27722 Premium Paper',
#     'line_qty': '1',
#     'line_tax': '0.74',
#     'line_total': '25.54',
#     'model': 'TL-27722'},
#    {'line_count': '3',
#     'line_description': 'BAC-943 Ultimate Ink Cartridge',
#     'line_qty': '2',
#     'line_tax': '1.63',
#     'line_total': '56.08',
#     'model': 'BAC-943'},
#    {'line_count': '4',
#     'line_description': 'UC-517 Compact Document Scanner',
#     'line_qty': '1',
#     'line_tax': '4.39',
#     'line_total': '151.31',
#     'model': 'UC-517'}]},
#  {'invoice_id': 'INV-851B066D',
#   'invoice_date': '12/19/2024',
#   'extractions': [{'field': 'merchant',
#     'value': 'Villanueva & Rice Technologies'},
#    {'field': 'invoice_date', 'value': '12/19/2024'},
#    {'field': 'merchant_branch', 'value': 'Villanueva & Rice Technologies'},
#    {'field': 'merchant_chain', 'value': 'Villanueva & Rice Technologies'},
#    {'field': 'due_date', 'value': '01/03/2025'},
#    {'field': 'payment_terms', 'value': 'NET 15 DAYS'},
#    {'field': 'grand_total', 'value': '1832.80'},
#    {'field': 'tax', 'value': '70.24'},
#    {'field': 'po_number', 'value': '2503-4030'},
#    {'field': 'merchant_address',
#     'value': '61116 Jason Lock Apt. 925 Hayeschester GA 10048 USA'},
#    {'field': 'payment_method', 'value': 'Credit Card'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'F-7826 Premium Ink Cartridge',
#       'line_qty': '2',
#       'line_tax': '11.38',
#       'line_total': '284.50',
#       'model': 'F-7826'},
#      {'line_count': '2',
#       'line_description': 'TL-27722 Premium Paper',
#       'line_qty': '10',
#       'line_tax': '8.90',
#       'line_total': '222.50',
#       'model': 'TL-27722'},
#      {'line_count': '3',
#       'line_description': 'D-172 Advanced Binding Equipment',
#       'line_qty': '5',
#       'line_tax': '49.96',
#       'line_total': '1249.09',
#       'model': 'D-172'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'F-7826 Premium Ink Cartridge',
#     'line_qty': '2',
#     'line_tax': '11.38',
#     'line_total': '284.50',
#     'model': 'F-7826'},
#    {'line_count': '2',
#     'line_description': 'TL-27722 Premium Paper',
#     'line_qty': '10',
#     'line_tax': '8.90',
#     'line_total': '222.50',
#     'model': 'TL-27722'},
#    {'line_count': '3',
#     'line_description': 'D-172 Advanced Binding Equipment',
#     'line_qty': '5',
#     'line_tax': '49.96',
#     'line_total': '1249.09',
#     'model': 'D-172'}]},
#  {'invoice_id': 'INV-11DCD558',
#   'invoice_date': '03/16/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Reyes & King Aerospace'},
#    {'field': 'invoice_date', 'value': '03/16/2025'},
#    {'field': 'merchant_branch', 'value': 'Reyes & King Aerospace'},
#    {'field': 'merchant_chain', 'value': 'Reyes & King Aerospace'},
#    {'field': 'due_date', 'value': '04/15/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '16022.11'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'T24884'},
#    {'field': 'merchant_address',
#     'value': '1209 Solis Ranch Apt. 304 Laurachester PW 15796 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'JHE-6216 Extended Navigation System',
#       'line_qty': '10',
#       'line_tax': '0.00',
#       'line_total': '16022.11',
#       'model': 'JHE-6216'}]},
#    {'field': 'state_label', 'value': 1}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'JHE-6216 Extended Navigation System',
#     'line_qty': '10',
#     'line_tax': '0.00',
#     'line_total': '16022.11',
#     'model': 'JHE-6216'}]},
#  {'invoice_id': 'INV-D6F7C45E',
#   'invoice_date': '02/23/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'invoice_date', 'value': '02/23/2025'},
#    {'field': 'merchant_branch', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'merchant_chain', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'due_date', 'value': '03/25/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '7203.89'},
#    {'field': 'tax', 'value': '444.94'},
#    {'field': 'po_number', 'value': '2503-9714'},
#    {'field': 'merchant_address',
#     'value': '5744 Gonzalez Knoll Larsonbury NJ 46878 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'WLC-1864 Professional Valve',
#       'line_qty': '1',
#       'line_tax': '63.56',
#       'line_total': '958.60',
#       'model': 'WLC-1864'},
#      {'line_count': '2',
#       'line_description': 'WVA-532 Ultimate Filter',
#       'line_qty': '3',
#       'line_tax': '58.20',
#       'line_total': '877.90',
#       'model': 'WVA-532'},
#      {'line_count': '3',
#       'line_description': 'ATP-317 Premium Bearing',
#       'line_qty': '1',
#       'line_tax': '23.58',
#       'line_total': '355.67',
#       'model': 'ATP-317'},
#      {'line_count': '4',
#       'line_description': 'VR-20715 Deluxe Filter',
#       'line_qty': '1',
#       'line_tax': '61.91',
#       'line_total': '933.72',
#       'model': 'VR-20715'},
#      {'line_count': '5',
#       'line_description': 'QYK-61200 Professional Pump',
#       'line_qty': '2',
#       'line_tax': '37.73',
#       'line_total': '569.02',
#       'model': 'QYK-61200'},
#      {'line_count': '6',
#       'line_description': 'EPW-174 Heavy Duty Valve',
#       'line_qty': '5',
#       'line_tax': '199.96',
#       'line_total': '3015.99',
#       'model': 'EPW-174'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'WLC-1864 Professional Valve',
#     'line_qty': '1',
#     'line_tax': '63.56',
#     'line_total': '958.60',
#     'model': 'WLC-1864'},
#    {'line_count': '2',
#     'line_description': 'WVA-532 Ultimate Filter',
#     'line_qty': '3',
#     'line_tax': '58.20',
#     'line_total': '877.90',
#     'model': 'WVA-532'},
#    {'line_count': '3',
#     'line_description': 'ATP-317 Premium Bearing',
#     'line_qty': '1',
#     'line_tax': '23.58',
#     'line_total': '355.67',
#     'model': 'ATP-317'},
#    {'line_count': '4',
#     'line_description': 'VR-20715 Deluxe Filter',
#     'line_qty': '1',
#     'line_tax': '61.91',
#     'line_total': '933.72',
#     'model': 'VR-20715'},
#    {'line_count': '5',
#     'line_description': 'QYK-61200 Professional Pump',
#     'line_qty': '2',
#     'line_tax': '37.73',
#     'line_total': '569.02',
#     'model': 'QYK-61200'},
#    {'line_count': '6',
#     'line_description': 'EPW-174 Heavy Duty Valve',
#     'line_qty': '5',
#     'line_tax': '199.96',
#     'line_total': '3015.99',
#     'model': 'EPW-174'}]},
#  {'invoice_id': 'INV-8D22D93A',
#   'invoice_date': '02/14/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Jones & Wilson'},
#    {'field': 'invoice_date', 'value': '02/14/2025'},
#    {'field': 'merchant_branch', 'value': 'Jones & Wilson'},
#    {'field': 'merchant_chain', 'value': 'Jones & Wilson'},
#    {'field': 'due_date', 'value': '03/16/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '237995.25'},
#    {'field': 'tax', 'value': '14317.35'},
#    {'field': 'po_number', 'value': 'V31075'},
#    {'field': 'merchant_address',
#     'value': '1910 Booth Roads Suite 855 Lake Andrea WA 92917 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'EN-65827 Ultimate Monitor',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '3391.67',
#       'model': 'EN-65827'},
#      {'line_count': '2',
#       'line_description': 'VEJ-418 Advanced Laboratory Supply',
#       'line_qty': '100',
#       'line_tax': '14183.23',
#       'line_total': '218203.57',
#       'model': 'VEJ-418'},
#      {'line_count': '3',
#       'line_description': 'PJ-14917 Compact Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '88.20',
#       'line_total': '1356.93',
#       'model': 'PJ-14917'},
#      {'line_count': '4',
#       'line_description': 'ZVK-04389 Extended Laboratory Supply',
#       'line_qty': '1',
#       'line_tax': '45.92',
#       'line_total': '706.48',
#       'model': 'ZVK-04389'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'EN-65827 Ultimate Monitor',
#     'line_qty': '1',
#     'line_tax': '0.00',
#     'line_total': '3391.67',
#     'model': 'EN-65827'},
#    {'line_count': '2',
#     'line_description': 'VEJ-418 Advanced Laboratory Supply',
#     'line_qty': '100',
#     'line_tax': '14183.23',
#     'line_total': '218203.57',
#     'model': 'VEJ-418'},
#    {'line_count': '3',
#     'line_description': 'PJ-14917 Compact Surgical Instrument',
#     'line_qty': '1',
#     'line_tax': '88.20',
#     'line_total': '1356.93',
#     'model': 'PJ-14917'},
#    {'line_count': '4',
#     'line_description': 'ZVK-04389 Extended Laboratory Supply',
#     'line_qty': '1',
#     'line_tax': '45.92',
#     'line_total': '706.48',
#     'model': 'ZVK-04389'}]},
#  {'invoice_id': 'INV-50834F50',
#   'invoice_date': '03/13/2025',
#   'extractions': [{'field': 'merchant', 'value': 'EightTruth Enterprises'},
#    {'field': 'invoice_date', 'value': '03/13/2025'},
#    {'field': 'merchant_branch', 'value': 'EightTruth Enterprises'},
#    {'field': 'merchant_chain', 'value': 'EightTruth Enterprises'},
#    {'field': 'due_date', 'value': '04/27/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '3359.51'},
#    {'field': 'tax', 'value': '159.97'},
#    {'field': 'po_number', 'value': '85199-782'},
#    {'field': 'merchant_address',
#     'value': '1000 Eileen Plaza Suite 691 West Allen WI 20401 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'RQ-592 Heavy Duty Fixture',
#       'line_qty': '1',
#       'line_tax': '19.97',
#       'line_total': '399.45',
#       'model': 'RQ-592'},
#      {'line_count': '2',
#       'line_description': 'N-12275 Advanced Die',
#       'line_qty': '3',
#       'line_tax': '140.00',
#       'line_total': '2800.09',
#       'model': 'N-12275'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'RQ-592 Heavy Duty Fixture',
#     'line_qty': '1',
#     'line_tax': '19.97',
#     'line_total': '399.45',
#     'model': 'RQ-592'},
#    {'line_count': '2',
#     'line_description': 'N-12275 Advanced Die',
#     'line_qty': '3',
#     'line_tax': '140.00',
#     'line_total': '2800.09',
#     'model': 'N-12275'}]},
#  {'invoice_id': 'INV-7342D366',
#   'invoice_date': '12/08/2024',
#   'extractions': [{'field': 'merchant', 'value': 'ChoiceNone'},
#    {'field': 'invoice_date', 'value': '12/08/2024'},
#    {'field': 'merchant_branch', 'value': 'ChoiceNone'},
#    {'field': 'merchant_chain', 'value': 'ChoiceNone'},
#    {'field': 'due_date', 'value': '02/06/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '22691.26'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': '433193'},
#    {'field': 'merchant_address',
#     'value': '92349 Brett Drive Apt. 322 Stevenmouth OR 47591 USA'},
#    {'field': 'payment_method', 'value': 'Net Banking'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'ZHJ-160 Basic Battery',
#       'line_qty': '2',
#       'line_tax': '0.00',
#       'line_total': '320.18',
#       'model': 'ZHJ-160'},
#      {'line_count': '2',
#       'line_description': 'GJX-232 Extended Power Supply',
#       'line_qty': '2',
#       'line_tax': '0.00',
#       'line_total': '213.57',
#       'model': 'GJX-232'},
#      {'line_count': '3',
#       'line_description': 'Q-046 Heavy Duty Battery',
#       'line_qty': '100',
#       'line_tax': '0.00',
#       'line_total': '17117.17',
#       'model': 'Q-046'},
#      {'line_count': '4',
#       'line_description': 'P-5876 Standard Power Supply',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '142.93',
#       'model': 'P-5876'},
#      {'line_count': '5',
#       'line_description': 'ZZT-37346 Compact Battery',
#       'line_qty': '100',
#       'line_tax': '0.00',
#       'line_total': '4879.60',
#       'model': 'ZZT-37346'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'ZHJ-160 Basic Battery',
#     'line_qty': '2',
#     'line_tax': '0.00',
#     'line_total': '320.18',
#     'model': 'ZHJ-160'},
#    {'line_count': '2',
#     'line_description': 'GJX-232 Extended Power Supply',
#     'line_qty': '2',
#     'line_tax': '0.00',
#     'line_total': '213.57',
#     'model': 'GJX-232'},
#    {'line_count': '3',
#     'line_description': 'Q-046 Heavy Duty Battery',
#     'line_qty': '100',
#     'line_tax': '0.00',
#     'line_total': '17117.17',
#     'model': 'Q-046'},
#    {'line_count': '4',
#     'line_description': 'P-5876 Standard Power Supply',
#     'line_qty': '1',
#     'line_tax': '0.00',
#     'line_total': '142.93',
#     'model': 'P-5876'},
#    {'line_count': '5',
#     'line_description': 'ZZT-37346 Compact Battery',
#     'line_qty': '100',
#     'line_tax': '0.00',
#     'line_total': '4879.60',
#     'model': 'ZZT-37346'}]},
#  {'invoice_id': 'INV-F422FC0A',
#   'invoice_date': '03/05/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'invoice_date', 'value': '03/05/2025'},
#    {'field': 'merchant_branch', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'merchant_chain', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'due_date', 'value': '03/05/2025'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '8633.35'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'CUST-92941-7254'},
#    {'field': 'merchant_address',
#     'value': '21837 Douglas Cliffs Suite 259 North Melissaport PR 34622 USA'},
#    {'field': 'payment_method', 'value': 'ACH'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'AQ-596 High Performance Valve',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '1101.53',
#       'model': 'AQ-596'},
#      {'line_count': '2',
#       'line_description': 'WVA-532 Ultimate Filter',
#       'line_qty': '24',
#       'line_tax': '0.00',
#       'line_total': '6228.93',
#       'model': 'WVA-532'},
#      {'line_count': '3',
#       'line_description': 'XHR-23747 Professional Conveyor Belt',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '1297.78',
#       'model': 'XHR-23747'}]},
#    {'field': 'state_label', 'value': 1}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'AQ-596 High Performance Valve',
#     'line_qty': '1',
#     'line_tax': '0.00',
#     'line_total': '1101.53',
#     'model': 'AQ-596'},
#    {'line_count': '2',
#     'line_description': 'WVA-532 Ultimate Filter',
#     'line_qty': '24',
#     'line_tax': '0.00',
#     'line_total': '6228.93',
#     'model': 'WVA-532'},
#    {'line_count': '3',
#     'line_description': 'XHR-23747 Professional Conveyor Belt',
#     'line_qty': '1',
#     'line_tax': '0.00',
#     'line_total': '1297.78',
#     'model': 'XHR-23747'}]},
#  {'invoice_id': 'INV-1AF535A4',
#   'invoice_date': '11/02/2024',
#   'extractions': [{'field': 'merchant', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'invoice_date', 'value': '11/02/2024'},
#    {'field': 'merchant_branch', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'merchant_chain', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'due_date', 'value': '12/02/2024'},
#    {'field': 'payment_terms', 'value': '2/10 NET 30'},
#    {'field': 'grand_total', 'value': '57572.86'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'PO-85400'},
#    {'field': 'merchant_address',
#     'value': '21837 Douglas Cliffs Suite 259 North Melissaport PR 34622 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'PB-859 Ultimate Compressor',
#       'line_qty': '50',
#       'line_tax': '0.00',
#       'line_total': '39346.14',
#       'model': 'PB-859'},
#      {'line_count': '2',
#       'line_description': 'N-1369 Heavy Duty Bearing',
#       'line_qty': '10',
#       'line_tax': '0.00',
#       'line_total': '11032.09',
#       'model': 'N-1369'},
#      {'line_count': '3',
#       'line_description': 'MCN-481 Compact Conveyor Belt',
#       'line_qty': '12',
#       'line_tax': '0.00',
#       'line_total': '7194.63',
#       'model': 'MCN-481'}]},
#    {'field': 'state_label', 'value': 1}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'PB-859 Ultimate Compressor',
#     'line_qty': '50',
#     'line_tax': '0.00',
#     'line_total': '39346.14',
#     'model': 'PB-859'},
#    {'line_count': '2',
#     'line_description': 'N-1369 Heavy Duty Bearing',
#     'line_qty': '10',
#     'line_tax': '0.00',
#     'line_total': '11032.09',
#     'model': 'N-1369'},
#    {'line_count': '3',
#     'line_description': 'MCN-481 Compact Conveyor Belt',
#     'line_qty': '12',
#     'line_tax': '0.00',
#     'line_total': '7194.63',
#     'model': 'MCN-481'}]},
#  {'invoice_id': 'INV-B9D2A519',
#   'invoice_date': '03/02/2025',
#   'extractions': [{'field': 'merchant', 'value': 'MatterSouthern'},
#    {'field': 'invoice_date', 'value': '03/02/2025'},
#    {'field': 'merchant_branch', 'value': 'MatterSouthern'},
#    {'field': 'merchant_chain', 'value': 'MatterSouthern'},
#    {'field': 'due_date', 'value': '03/02/2025'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '49481.41'},
#    {'field': 'tax', 'value': '2800.83'},
#    {'field': 'po_number', 'value': 'CUST-94907-5610'},
#    {'field': 'merchant_address',
#     'value': '48515 Jay Islands Apt. 470 West Emily MI 80341 USA'},
#    {'field': 'payment_method', 'value': 'Wire Transfer'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'NHP-576 Lightweight Filter',
#       'line_qty': '3',
#       'line_tax': '132.73',
#       'line_total': '2212.18',
#       'model': 'NHP-576'},
#      {'line_count': '2',
#       'line_description': 'XSK-0076 Lightweight Valve',
#       'line_qty': '10',
#       'line_tax': '270.99',
#       'line_total': '4516.49',
#       'model': 'XSK-0076'},
#      {'line_count': '3',
#       'line_description': 'XHR-23747 Professional Conveyor Belt',
#       'line_qty': '1',
#       'line_tax': '75.89',
#       'line_total': '1264.89',
#       'model': 'XHR-23747'},
#      {'line_count': '4',
#       'line_description': 'K-7005 Basic Compressor',
#       'line_qty': '100',
#       'line_tax': '2251.06',
#       'line_total': '37517.64',
#       'model': 'K-7005'},
#      {'line_count': '5',
#       'line_description': 'XKH-16117 Industrial Filter',
#       'line_qty': '1',
#       'line_tax': '70.16',
#       'line_total': '1169.38',
#       'model': 'XKH-16117'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'NHP-576 Lightweight Filter',
#     'line_qty': '3',
#     'line_tax': '132.73',
#     'line_total': '2212.18',
#     'model': 'NHP-576'},
#    {'line_count': '2',
#     'line_description': 'XSK-0076 Lightweight Valve',
#     'line_qty': '10',
#     'line_tax': '270.99',
#     'line_total': '4516.49',
#     'model': 'XSK-0076'},
#    {'line_count': '3',
#     'line_description': 'XHR-23747 Professional Conveyor Belt',
#     'line_qty': '1',
#     'line_tax': '75.89',
#     'line_total': '1264.89',
#     'model': 'XHR-23747'},
#    {'line_count': '4',
#     'line_description': 'K-7005 Basic Compressor',
#     'line_qty': '100',
#     'line_tax': '2251.06',
#     'line_total': '37517.64',
#     'model': 'K-7005'},
#    {'line_count': '5',
#     'line_description': 'XKH-16117 Industrial Filter',
#     'line_qty': '1',
#     'line_tax': '70.16',
#     'line_total': '1169.38',
#     'model': 'XKH-16117'}]},
#  {'invoice_id': 'INV-DD56B7D8',
#   'invoice_date': '03/17/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Scott'},
#    {'field': 'invoice_date', 'value': '03/17/2025'},
#    {'field': 'merchant_branch', 'value': 'Scott'},
#    {'field': 'merchant_chain', 'value': 'Scott'},
#    {'field': 'due_date', 'value': '04/16/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '465.34'},
#    {'field': 'tax', 'value': '25.29'},
#    {'field': 'po_number', 'value': '24643-179'},
#    {'field': 'merchant_address',
#     'value': '288 Michael Brook Johnland VT 70010 USA'},
#    {'field': 'payment_method', 'value': 'PayPal'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'BAC-943 Ultimate Ink Cartridge',
#       'line_qty': '1',
#       'line_tax': '1.67',
#       'line_total': '27.90',
#       'model': 'BAC-943'},
#      {'line_count': '2',
#       'line_description': 'GM-97746 Extended Document Scanner',
#       'line_qty': '1',
#       'line_tax': '12.48',
#       'line_total': '207.92',
#       'model': 'GM-97746'},
#      {'line_count': '3',
#       'line_description': 'DB-697 Premium Toner',
#       'line_qty': '1',
#       'line_tax': '11.14',
#       'line_total': '185.66',
#       'model': 'DB-697'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'BAC-943 Ultimate Ink Cartridge',
#     'line_qty': '1',
#     'line_tax': '1.67',
#     'line_total': '27.90',
#     'model': 'BAC-943'},
#    {'line_count': '2',
#     'line_description': 'GM-97746 Extended Document Scanner',
#     'line_qty': '1',
#     'line_tax': '12.48',
#     'line_total': '207.92',
#     'model': 'GM-97746'},
#    {'line_count': '3',
#     'line_description': 'DB-697 Premium Toner',
#     'line_qty': '1',
#     'line_tax': '11.14',
#     'line_total': '185.66',
#     'model': 'DB-697'}]},
#  {'invoice_id': 'INV-89BB4E61',
#   'invoice_date': '03/10/2025',
#   'extractions': [{'field': 'merchant', 'value': 'EightTruth Enterprises'},
#    {'field': 'invoice_date', 'value': '03/10/2025'},
#    {'field': 'merchant_branch', 'value': 'EightTruth Enterprises'},
#    {'field': 'merchant_chain', 'value': 'EightTruth Enterprises'},
#    {'field': 'due_date', 'value': '04/24/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '25039.92'},
#    {'field': 'tax', 'value': '1192.38'},
#    {'field': 'po_number', 'value': 'T10567'},
#    {'field': 'merchant_address',
#     'value': '1000 Eileen Plaza Suite 691 West Allen WI 20401 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'S-7908 Compact Fixture',
#       'line_qty': '100',
#       'line_tax': '913.99',
#       'line_total': '18279.82',
#       'model': 'S-7908'},
#      {'line_count': '2',
#       'line_description': 'S-4315 Industrial Fixture',
#       'line_qty': '2',
#       'line_tax': '7.88',
#       'line_total': '157.58',
#       'model': 'S-4315'},
#      {'line_count': '3',
#       'line_description': 'UUH-09728 Economy Mold',
#       'line_qty': '10',
#       'line_tax': '200.08',
#       'line_total': '4001.50',
#       'model': 'UUH-09728'},
#      {'line_count': '4',
#       'line_description': 'QSY-1910 Basic Tool Set',
#       'line_qty': '5',
#       'line_tax': '24.69',
#       'line_total': '493.80',
#       'model': 'QSY-1910'},
#      {'line_count': '5',
#       'line_description': 'D-5585 Ultimate Tool Set',
#       'line_qty': '2',
#       'line_tax': '14.64',
#       'line_total': '292.80',
#       'model': 'D-5585'},
#      {'line_count': '6',
#       'line_description': 'RV-74801 Lightweight Raw Material',
#       'line_qty': '2',
#       'line_tax': '31.10',
#       'line_total': '622.04',
#       'model': 'RV-74801'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'S-7908 Compact Fixture',
#     'line_qty': '100',
#     'line_tax': '913.99',
#     'line_total': '18279.82',
#     'model': 'S-7908'},
#    {'line_count': '2',
#     'line_description': 'S-4315 Industrial Fixture',
#     'line_qty': '2',
#     'line_tax': '7.88',
#     'line_total': '157.58',
#     'model': 'S-4315'},
#    {'line_count': '3',
#     'line_description': 'UUH-09728 Economy Mold',
#     'line_qty': '10',
#     'line_tax': '200.08',
#     'line_total': '4001.50',
#     'model': 'UUH-09728'},
#    {'line_count': '4',
#     'line_description': 'QSY-1910 Basic Tool Set',
#     'line_qty': '5',
#     'line_tax': '24.69',
#     'line_total': '493.80',
#     'model': 'QSY-1910'},
#    {'line_count': '5',
#     'line_description': 'D-5585 Ultimate Tool Set',
#     'line_qty': '2',
#     'line_tax': '14.64',
#     'line_total': '292.80',
#     'model': 'D-5585'},
#    {'line_count': '6',
#     'line_description': 'RV-74801 Lightweight Raw Material',
#     'line_qty': '2',
#     'line_tax': '31.10',
#     'line_total': '622.04',
#     'model': 'RV-74801'}]},
#  {'invoice_id': 'INV-8E937C37',
#   'invoice_date': '02/02/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Jones & Wilson'},
#    {'field': 'invoice_date', 'value': '02/02/2025'},
#    {'field': 'merchant_branch', 'value': 'Jones & Wilson'},
#    {'field': 'merchant_chain', 'value': 'Jones & Wilson'},
#    {'field': 'due_date', 'value': '03/04/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '91815.57'},
#    {'field': 'tax', 'value': '5601.63'},
#    {'field': 'po_number', 'value': '32114-166'},
#    {'field': 'merchant_address',
#     'value': '1910 Booth Roads Suite 855 Lake Andrea WA 92917 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'B-5622 Advanced Surgical Instrument',
#       'line_qty': '100',
#       'line_tax': '4873.27',
#       'line_total': '74973.32',
#       'model': 'B-5622'},
#      {'line_count': '2',
#       'line_description': 'U-5223 High Performance Surgical Instrument',
#       'line_qty': '2',
#       'line_tax': '158.06',
#       'line_total': '2431.75',
#       'model': 'U-5223'},
#      {'line_count': '3',
#       'line_description': 'FR-103 High Performance Laboratory Supply',
#       'line_qty': '12',
#       'line_tax': '383.32',
#       'line_total': '5897.22',
#       'model': 'FR-103'},
#      {'line_count': '4',
#       'line_description': 'NY-55743 Premium Monitor',
#       'line_qty': '2',
#       'line_tax': '186.98',
#       'line_total': '2876.65',
#       'model': 'NY-55743'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'B-5622 Advanced Surgical Instrument',
#     'line_qty': '100',
#     'line_tax': '4873.27',
#     'line_total': '74973.32',
#     'model': 'B-5622'},
#    {'line_count': '2',
#     'line_description': 'U-5223 High Performance Surgical Instrument',
#     'line_qty': '2',
#     'line_tax': '158.06',
#     'line_total': '2431.75',
#     'model': 'U-5223'},
#    {'line_count': '3',
#     'line_description': 'FR-103 High Performance Laboratory Supply',
#     'line_qty': '12',
#     'line_tax': '383.32',
#     'line_total': '5897.22',
#     'model': 'FR-103'},
#    {'line_count': '4',
#     'line_description': 'NY-55743 Premium Monitor',
#     'line_qty': '2',
#     'line_tax': '186.98',
#     'line_total': '2876.65',
#     'model': 'NY-55743'}]},
#  {'invoice_id': 'INV-84B44E89',
#   'invoice_date': '08/15/2024',
#   'extractions': [{'field': 'merchant', 'value': 'WorryAdult'},
#    {'field': 'invoice_date', 'value': '08/15/2024'},
#    {'field': 'merchant_branch', 'value': 'WorryAdult'},
#    {'field': 'merchant_chain', 'value': 'WorryAdult'},
#    {'field': 'due_date', 'value': '08/15/2024'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '326656.00'},
#    {'field': 'tax', 'value': '21369.17'},
#    {'field': 'po_number', 'value': '74258-616'},
#    {'field': 'merchant_address',
#     'value': '23616 Blackburn Field Sergiochester TN 56955 USA'},
#    {'field': 'payment_method', 'value': 'Credit Card'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'Z-33884 Extended Structural Component',
#       'line_qty': '5',
#       'line_tax': '1792.27',
#       'line_total': '25603.92',
#       'model': 'Z-33884'},
#      {'line_count': '2',
#       'line_description': 'U-82665 Compact Navigation System',
#       'line_qty': '2',
#       'line_tax': '450.16',
#       'line_total': '6430.80',
#       'model': 'U-82665'},
#      {'line_count': '3',
#       'line_description': 'GEK-82629 Advanced Safety Mechanism',
#       'line_qty': '3',
#       'line_tax': '1522.39',
#       'line_total': '21748.42',
#       'model': 'GEK-82629'},
#      {'line_count': '4',
#       'line_description': 'YAB-845 Compact Cabin Equipment',
#       'line_qty': '1',
#       'line_tax': '262.51',
#       'line_total': '3750.11',
#       'model': 'YAB-845'},
#      {'line_count': '5',
#       'line_description': 'JHE-6216 Extended Navigation System',
#       'line_qty': '10',
#       'line_tax': '1080.18',
#       'line_total': '15431.12',
#       'model': 'JHE-6216'},
#      {'line_count': '6',
#       'line_description': 'WF-230 High Performance Cabin Equipment',
#       'line_qty': '12',
#       'line_tax': '3070.32',
#       'line_total': '43861.77',
#       'model': 'WF-230'},
#      {'line_count': '7',
#       'line_description': 'NZB-68034 Compact Safety Mechanism',
#       'line_qty': '100',
#       'line_tax': '13191.34',
#       'line_total': '188447.73',
#       'model': 'NZB-68034'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'Z-33884 Extended Structural Component',
#     'line_qty': '5',
#     'line_tax': '1792.27',
#     'line_total': '25603.92',
#     'model': 'Z-33884'},
#    {'line_count': '2',
#     'line_description': 'U-82665 Compact Navigation System',
#     'line_qty': '2',
#     'line_tax': '450.16',
#     'line_total': '6430.80',
#     'model': 'U-82665'},
#    {'line_count': '3',
#     'line_description': 'GEK-82629 Advanced Safety Mechanism',
#     'line_qty': '3',
#     'line_tax': '1522.39',
#     'line_total': '21748.42',
#     'model': 'GEK-82629'},
#    {'line_count': '4',
#     'line_description': 'YAB-845 Compact Cabin Equipment',
#     'line_qty': '1',
#     'line_tax': '262.51',
#     'line_total': '3750.11',
#     'model': 'YAB-845'},
#    {'line_count': '5',
#     'line_description': 'JHE-6216 Extended Navigation System',
#     'line_qty': '10',
#     'line_tax': '1080.18',
#     'line_total': '15431.12',
#     'model': 'JHE-6216'},
#    {'line_count': '6',
#     'line_description': 'WF-230 High Performance Cabin Equipment',
#     'line_qty': '12',
#     'line_tax': '3070.32',
#     'line_total': '43861.77',
#     'model': 'WF-230'},
#    {'line_count': '7',
#     'line_description': 'NZB-68034 Compact Safety Mechanism',
#     'line_qty': '100',
#     'line_tax': '13191.34',
#     'line_total': '188447.73',
#     'model': 'NZB-68034'}]},
#  {'invoice_id': 'INV-12D51951',
#   'invoice_date': '02/04/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Jones & Wilson'},
#    {'field': 'invoice_date', 'value': '02/04/2025'},
#    {'field': 'merchant_branch', 'value': 'Jones & Wilson'},
#    {'field': 'merchant_chain', 'value': 'Jones & Wilson'},
#    {'field': 'due_date', 'value': '02/04/2025'},
#    {'field': 'payment_terms', 'value': 'COD'},
#    {'field': 'grand_total', 'value': '14333.56'},
#    {'field': 'tax', 'value': '874.82'},
#    {'field': 'po_number', 'value': 'B70412'},
#    {'field': 'merchant_address',
#     'value': '1910 Booth Roads Suite 855 Lake Andrea WA 92917 USA'},
#    {'field': 'payment_method', 'value': 'PayPal'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
# ...
#     'value': [{'line_count': '1',
#       'line_description': 'WA-645 Basic Navigation System',
#       'line_qty': '50',
#       'line_tax': '0.00',
#       'line_total': '23153.50',
#       'model': 'WA-645'},
#      {'line_count': '2',
#       'line_description': 'LQH-6096 Deluxe Cabin Equipment',
#       'line_qty': '4',
#       'line_tax': '0.00',
#       'line_total': '3799.07',
#       'model': 'LQH-6096'},
#      {'line_count': '3',
#       'line_description': 'YYV-82795 Advanced Safety Mechanism',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '6620.79',
#       'model': 'YYV-82795'},
#      {'line_count': '4',
#       'line_description': 'YAB-845 Compact Cabin Equipment',
#       'line_qty': '24',
#       'line_tax': '0.00',
#       'line_total': '81618.61',
#       'model': 'YAB-845'}]},
#    {'field': 'state_label', 'value': 1}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'WA-645 Basic Navigation System',
#     'line_qty': '50',
#     'line_tax': '0.00',
#     'line_total': '23153.50',
#     'model': 'WA-645'},
#    {'line_count': '2',
#     'line_description': 'LQH-6096 Deluxe Cabin Equipment',
#     'line_qty': '4',
#     'line_tax': '0.00',
#     'line_total': '3799.07',
#     'model': 'LQH-6096'},
#    {'line_count': '3',
#     'line_description': 'YYV-82795 Advanced Safety Mechanism',
#     'line_qty': '1',
#     'line_tax': '0.00',
#     'line_total': '6620.79',
#     'model': 'YYV-82795'},
#    {'line_count': '4',
#     'line_description': 'YAB-845 Compact Cabin Equipment',
#     'line_qty': '24',
#     'line_tax': '0.00',
#     'line_total': '81618.61',
#     'model': 'YAB-845'}]},
#  {'invoice_id': 'INV-6F5BC0EF',
#   'invoice_date': '10/29/2024',
#   'extractions': [{'field': 'merchant', 'value': 'MatterSouthern'},
#    {'field': 'invoice_date', 'value': '10/29/2024'},
#    {'field': 'merchant_branch', 'value': 'MatterSouthern'},
#    {'field': 'merchant_chain', 'value': 'MatterSouthern'},
#    {'field': 'due_date', 'value': '11/28/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '5531.18'},
#    {'field': 'tax', 'value': '431.74'},
#    {'field': 'po_number', 'value': '43809-584'},
#    {'field': 'merchant_address',
#     'value': '48515 Jay Islands Apt. 470 West Emily MI 80341 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'VR-20715 Deluxe Filter',
#       'line_qty': '2',
#       'line_tax': '110.46',
#       'line_total': '1841.00',
#       'model': 'VR-20715'},
#      {'line_count': '2',
#       'line_description': 'E-73158 Heavy Duty Compressor',
#       'line_qty': '2',
#       'line_tax': '180.37',
#       'line_total': '910.02',
#       'model': 'E-73158'},
#      {'line_count': '3',
#       'line_description': 'TN-52816 Extended Pump',
#       'line_qty': '1',
#       'line_tax': '32.39',
#       'line_total': '539.77',
#       'model': 'TN-52816'},
#      {'line_count': '4',
#       'line_description': 'VR-20715 Deluxe Filter',
#       'line_qty': '2',
#       'line_tax': '108.52',
#       'line_total': '1808.65',
#       'model': 'VR-20715'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'VR-20715 Deluxe Filter',
#     'line_qty': '2',
#     'line_tax': '110.46',
#     'line_total': '1841.00',
#     'model': 'VR-20715'},
#    {'line_count': '2',
#     'line_description': 'E-73158 Heavy Duty Compressor',
#     'line_qty': '2',
#     'line_tax': '180.37',
#     'line_total': '910.02',
#     'model': 'E-73158'},
#    {'line_count': '3',
#     'line_description': 'TN-52816 Extended Pump',
#     'line_qty': '1',
#     'line_tax': '32.39',
#     'line_total': '539.77',
#     'model': 'TN-52816'},
#    {'line_count': '4',
#     'line_description': 'VR-20715 Deluxe Filter',
#     'line_qty': '2',
#     'line_tax': '108.52',
#     'line_total': '1808.65',
#     'model': 'VR-20715'}]},
#  {'invoice_id': 'INV-F74D3153',
#   'invoice_date': '02/22/2025',
#   'extractions': [{'field': 'merchant', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'invoice_date', 'value': '02/22/2025'},
#    {'field': 'merchant_branch', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'merchant_chain', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'due_date', 'value': '04/08/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '54981.95'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': '2503-7503'},
#    {'field': 'merchant_address',
#     'value': '21837 Douglas Cliffs Suite 259 North Melissaport PR 34622 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'E-73158 Heavy Duty Compressor',
#       'line_qty': '2',
#       'line_tax': '0.00',
#       'line_total': '903.76',
#       'model': 'E-73158'},
#      {'line_count': '2',
#       'line_description': 'JFD-02053 High Performance Motor',
#       'line_qty': '4',
#       'line_tax': '0.00',
#       'line_total': '1631.82',
#       'model': 'JFD-02053'},
#      {'line_count': '3',
#       'line_description': 'XKH-16117 Industrial Filter',
#       'line_qty': '50',
#       'line_tax': '0.00',
#       'line_total': '52446.37',
#       'model': 'XKH-16117'}]},
#    {'field': 'state_label', 'value': 1}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'E-73158 Heavy Duty Compressor',
#     'line_qty': '2',
#     'line_tax': '0.00',
#     'line_total': '903.76',
#     'model': 'E-73158'},
#    {'line_count': '2',
#     'line_description': 'JFD-02053 High Performance Motor',
#     'line_qty': '4',
#     'line_tax': '0.00',
#     'line_total': '1631.82',
#     'model': 'JFD-02053'},
#    {'line_count': '3',
#     'line_description': 'XKH-16117 Industrial Filter',
#     'line_qty': '50',
#     'line_tax': '0.00',
#     'line_total': '52446.37',
#     'model': 'XKH-16117'}]},
#  {'invoice_id': 'INV-40244D12',
#   'invoice_date': '10/27/2024',
#   'extractions': [{'field': 'merchant', 'value': 'Curtis Instruments, Inc.'},
#    {'field': 'invoice_date', 'value': '10/27/2024'},
#    {'field': 'merchant_branch', 'value': 'Curtis Instruments, Inc.'},
#    {'field': 'merchant_chain', 'value': 'Curtis Instruments, Inc.'},
#    {'field': 'due_date', 'value': '11/26/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '1417.41'},
#    {'field': 'tax', 'value': '53.02'},
#    {'field': 'po_number', 'value': '2503-7636'},
#    {'field': 'merchant_address',
#     'value': '200 Kisco Avenue Mount Kisco NY 10549 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'WSA-84124 Premium Display Unit',
#       'line_qty': '1',
#       'line_tax': '26.86',
#       'line_total': '671.49',
#       'model': 'WSA-84124'},
#      {'line_count': '2',
#       'line_description': 'BA-2427 Extended Battery',
#       'line_qty': '1',
#       'line_tax': '18.52',
#       'line_total': '463.05',
#       'model': 'BA-2427'},
#      {'line_count': '3',
#       'line_description': 'Q-046 Heavy Duty Battery',
#       'line_qty': '1',
#       'line_tax': '7.64',
#       'line_total': '190.96',
#       'model': 'Q-046'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'WSA-84124 Premium Display Unit',
#     'line_qty': '1',
#     'line_tax': '26.86',
#     'line_total': '671.49',
#     'model': 'WSA-84124'},
#    {'line_count': '2',
#     'line_description': 'BA-2427 Extended Battery',
#     'line_qty': '1',
#     'line_tax': '18.52',
#     'line_total': '463.05',
#     'model': 'BA-2427'},
#    {'line_count': '3',
#     'line_description': 'Q-046 Heavy Duty Battery',
#     'line_qty': '1',
#     'line_tax': '7.64',
#     'line_total': '190.96',
#     'model': 'Q-046'}]},
#  {'invoice_id': 'INV-28D6F4A5',
#   'invoice_date': '09/18/2024',
#   'extractions': [{'field': 'merchant', 'value': 'ChoiceNone'},
#    {'field': 'invoice_date', 'value': '09/18/2024'},
#    {'field': 'merchant_branch', 'value': 'ChoiceNone'},
#    {'field': 'merchant_chain', 'value': 'ChoiceNone'},
#    {'field': 'due_date', 'value': '09/18/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '27735.13'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'L24890'},
#    {'field': 'merchant_address',
#     'value': '92349 Brett Drive Apt. 322 Stevenmouth OR 47591 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'BAH-092 Commercial Sensor',
#       'line_qty': '100',
#       'line_tax': '0.00',
#       'line_total': '11453.17',
#       'model': 'BAH-092'},
#      {'line_count': '2',
#       'line_description': 'ZHJ-160 Basic Battery',
#       'line_qty': '100',
#       'line_tax': '0.00',
#       'line_total': '14924.89',
#       'model': 'ZHJ-160'},
#      {'line_count': '3',
#       'line_description': 'EWR-094 Compact Display Unit',
#       'line_qty': '3',
#       'line_tax': '0.00',
#       'line_total': '686.79',
#       'model': 'EWR-094'},
#      {'line_count': '4',
#       'line_description': 'EWR-094 Compact Display Unit',
#       'line_qty': '2',
#       'line_tax': '0.00',
#       'line_total': '448.55',
#       'model': 'EWR-094'},
#      {'line_count': '5',
#       'line_description': 'TH-77701 Professional Battery',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '206.89',
#       'model': 'TH-77701'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'BAH-092 Commercial Sensor',
#     'line_qty': '100',
#     'line_tax': '0.00',
#     'line_total': '11453.17',
#     'model': 'BAH-092'},
#    {'line_count': '2',
#     'line_description': 'ZHJ-160 Basic Battery',
#     'line_qty': '100',
#     'line_tax': '0.00',
#     'line_total': '14924.89',
#     'model': 'ZHJ-160'},
#    {'line_count': '3',
#     'line_description': 'EWR-094 Compact Display Unit',
#     'line_qty': '3',
#     'line_tax': '0.00',
#     'line_total': '686.79',
#     'model': 'EWR-094'},
#    {'line_count': '4',
#     'line_description': 'EWR-094 Compact Display Unit',
#     'line_qty': '2',
#     'line_tax': '0.00',
#     'line_total': '448.55',
#     'model': 'EWR-094'},
#    {'line_count': '5',
#     'line_description': 'TH-77701 Professional Battery',
#     'line_qty': '1',
#     'line_tax': '0.00',
#     'line_total': '206.89',
#     'model': 'TH-77701'}]},
#  {'invoice_id': 'INV-D5795090',
#   'invoice_date': '02/25/2025',
#   'extractions': [{'field': 'merchant',
#     'value': 'Provide Construction Solutions'},
#    {'field': 'invoice_date', 'value': '02/25/2025'},
#    {'field': 'merchant_branch', 'value': 'Provide Construction Solutions'},
#    {'field': 'merchant_chain', 'value': 'Provide Construction Solutions'},
#    {'field': 'due_date', 'value': '03/12/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '17343.48'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'D21749'},
#    {'field': 'merchant_address',
#     'value': '76031 Jessica Summit Suite 832 Ellisland NH 79618 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'payment_label', 'value': 1},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'FX-24172 Deluxe Hardware',
#       'line_qty': '24',
#       'line_tax': '0.00',
#       'line_total': '1794.16',
#       'model': 'FX-24172'},
#      {'line_count': '2',
#       'line_description': 'NDR-32710 Professional Adhesive',
#       'line_qty': '100',
#       'line_tax': '0.00',
#       'line_total': '7020.41',
#       'model': 'NDR-32710'},
#      {'line_count': '3',
#       'line_description': 'EW-903 Professional Fastener',
#       'line_qty': '10',
#       'line_tax': '0.00',
#       'line_total': '5433.79',
#       'model': 'EW-903'},
#      {'line_count': '4',
#       'line_description': 'N-4220 Deluxe Hardware',
#       'line_qty': '5',
#       'line_tax': '0.00',
#       'line_total': '3095.12',
#       'model': 'N-4220'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'FX-24172 Deluxe Hardware',
#     'line_qty': '24',
#     'line_tax': '0.00',
#     'line_total': '1794.16',
#     'model': 'FX-24172'},
#    {'line_count': '2',
#     'line_description': 'NDR-32710 Professional Adhesive',
#     'line_qty': '100',
#     'line_tax': '0.00',
#     'line_total': '7020.41',
#     'model': 'NDR-32710'},
#    {'line_count': '3',
#     'line_description': 'EW-903 Professional Fastener',
#     'line_qty': '10',
#     'line_tax': '0.00',
#     'line_total': '5433.79',
#     'model': 'EW-903'},
#    {'line_count': '4',
#     'line_description': 'N-4220 Deluxe Hardware',
#     'line_qty': '5',
#     'line_tax': '0.00',
#     'line_total': '3095.12',
#     'model': 'N-4220'}]},
#  {'invoice_id': 'INV-179661D5',
#   'invoice_date': '12/13/2024',
#   'extractions': [{'field': 'merchant',
#     'value': 'EnterOfficer Technology LLC'},
#    {'field': 'invoice_date', 'value': '12/13/2024'},
#    {'field': 'merchant_branch', 'value': 'EnterOfficer Technology LLC'},
#    {'field': 'merchant_chain', 'value': 'EnterOfficer Technology LLC'},
#    {'field': 'due_date', 'value': '12/13/2024'},
#    {'field': 'payment_terms', 'value': 'COD'},
#    {'field': 'grand_total', 'value': '79701.47'},
#    {'field': 'tax', 'value': '3432.12'},
#    {'field': 'po_number', 'value': '2503-6201'},
#    {'field': 'merchant_address',
#     'value': '07878 Paula Points Boydland OK 51912 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'payment_label', 'value': 0},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'tax_label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'P-86153 Advanced Storage Solution',
#       'line_qty': '3',
#       'line_tax': '496.48',
#       'line_total': '11032.87',
#       'model': 'P-86153'},
#      {'line_count': '2',
#       'line_description': 'WK-85102 Compact Security System',
#       'line_qty': '50',
#       'line_tax': '2132.06',
#       'line_total': '47379.12',
#       'model': 'WK-85102'},
#      {'line_count': '3',
#       'line_description': 'F-90878 Premium Network Device',
#       'line_qty': '4',
#       'line_tax': '546.38',
#       'line_total': '12141.75',
#       'model': 'F-90878'},
#      {'line_count': '4',
#       'line_description': 'AB-35058 Commercial Cable',
#       'line_qty': '3',
#       'line_tax': '257.20',
#       'line_total': '5715.61',
#       'model': 'AB-35058'}]},
#    {'field': 'state_label', 'value': 0}],
#   'line_details': [{'line_count': '1',
#     'line_description': 'P-86153 Advanced Storage Solution',
#     'line_qty': '3',
#     'line_tax': '496.48',
#     'line_total': '11032.87',
#     'model': 'P-86153'},
#    {'line_count': '2',
#     'line_description': 'WK-85102 Compact Security System',
#     'line_qty': '50',
#     'line_tax': '2132.06',
#     'line_total': '47379.12',
#     'model': 'WK-85102'},
#    {'line_count': '3',
#     'line_description': 'F-90878 Premium Network Device',
#     'line_qty': '4',
#     'line_tax': '546.38',
#     'line_total': '12141.75',
#     'model': 'F-90878'},
#    {'line_count': '4',
#     'line_description': 'AB-35058 Commercial Cable',
#     'line_qty': '3',
#     'line_tax': '257.20',
#     'line_total': '5715.61',
#     'model': 'AB-35058'}]}]
