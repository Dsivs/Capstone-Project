# %%
import json
import random
import re
from datetime import datetime, timedelta
import numpy as np
from faker import Faker
import uuid
from collections import defaultdict

# Set up the Faker generator with a fixed seed for reproducibility
fake = Faker(['en_US'])

with open('synthetic_data_configs.json','r') as f:
    synthetic_data_configs = json.load(f)

def merchant_name_generator(merchant_types,company_suffixes):
            # Company Name Generator

    name_prefix = random.choice([
        fake.last_name(),
        fake.last_name() + " & " + fake.last_name(),
        fake.last_name() + "-" + fake.last_name(),
        fake.word().capitalize(),
        fake.word().capitalize() + fake.word().capitalize(),
    ])
    
    merchant_type = random.choice(merchant_types)
    suffix = random.choice(company_suffixes)
    
    merchant_name = [name_prefix]
    if random.random() >= 0.7:
        merchant_name.append(merchant_type)
    if random.random() >= 0.5:
        merchant_name.append(suffix)
    return (' '.join(merchant_name), merchant_type)

def generate_merchant_data(num_merchants=20):
    """
    Generate a diverse set of realistic merchant data
    
    Parameters:
    num_merchants (int): Number of merchants to generate
    
    Returns:
    list: List of merchant dictionaries
    """
    merchant_types = synthetic_data_configs["merchant_types"]
    company_suffixes = synthetic_data_configs["company_suffixes"]
    
    merchants = [
        {
            "name": "Curtis Instruments, Inc.",
            "address": "200 Kisco Avenue Mount Kisco NY 10549 USA",
            "city": "Mount Kisco",  # Added this
            "state": "NY",          # Added this
            "country": "US",
            "type": "Electronics"
        }
    ]
    
    # Create a set to track unique merchant names
    existing_names = {merchants[0]["name"]}
    
    # Generate additional merchants
    for _ in range(num_merchants - 1):
        country_code = 'US'
        
        fake.seed_instance(random.randint(1, 9999))
            
        # US address
        street = fake.street_address()
        city = fake.city()
        state = fake.state_abbr()
        zip_code = fake.zipcode()
        address = f"{street} {city} {state} {zip_code} USA"
        
        # Merchant Name Generator
        while True:
            merchant_name,merchant_type = merchant_name_generator(merchant_types, company_suffixes)

            # Check for uniqueness
            if merchant_name not in existing_names:
                existing_names.add(merchant_name)
                break
        
        merchants.append({
            "name": merchant_name,
            "address": address,
            "city": city,
            "state": state,
            "country": country_code,
            "type": merchant_type
        })
    
    return merchants

def generate_product_catalog():
    """
    Generate a realistic product catalog with categories and products
    
    Returns:
    dict: Dictionary mapping categories to lists of products
    """
    categories = synthetic_data_configs["categories"]
    
    # Generate product catalog
    catalog = {}
    
    for category, product_types in categories.items():
        catalog[category] = []
        
        # Generate 15-30 products per category
        for _ in range(random.randint(15, 30)):
            product_type = random.choice(product_types)
            
            # Generate model number
            model_prefix = ''.join(random.choice('ABCDEFGHJKLMNPQRSTUVWXYZ') for _ in range(random.randint(1, 3)))
            model_suffix = ''.join(random.choice('0123456789') for _ in range(random.randint(3, 5)))
            model = f"{model_prefix}-{model_suffix}"
            
            # Generate specification
            specs = [
                "Standard", "Premium", "Industrial", "Commercial", "Professional",
                "Heavy Duty", "Lightweight", "Compact", "Extended", "High Performance",
                "Economy", "Deluxe", "Ultimate", "Basic", "Advanced"
            ]
            spec = random.choice(specs)
            
            # Generate description
            description = f"{model} {spec} {product_type}"
            
            # Generate price based on category and specification
            base_price = {
                "Electronics": random.uniform(50, 500),
                "Industrial": random.uniform(100, 1000),
                "Office Supplies": random.uniform(10, 200),
                "Manufacturing": random.uniform(50, 800),
                "Automotive": random.uniform(30, 600),
                "Medical": random.uniform(100, 2000),
                "Construction": random.uniform(20, 500),
                "Technology": random.uniform(100, 3000),
                "Laboratory": random.uniform(50, 1500),
                "Engineering": random.uniform(100, 2000),
                "Aerospace": random.uniform(500, 5000),
                "Telecommunications": random.uniform(200, 2500)
            }[category]
            
            # Adjust price based on specification
            spec_multiplier = {
                "Standard": 1.0,
                "Premium": 1.5,
                "Industrial": 1.3,
                "Commercial": 1.2,
                "Professional": 1.4,
                "Heavy Duty": 1.3,
                "Lightweight": 0.9,
                "Compact": 0.85,
                "Extended": 1.25,
                "High Performance": 1.6,
                "Economy": 0.7,
                "Deluxe": 1.35,
                "Ultimate": 1.8,
                "Basic": 0.6,
                "Advanced": 1.5
            }[spec]
            
            unit_price = round(base_price * spec_multiplier, 2)
            
            catalog[category].append({
                "description": description,
                "unit_price": unit_price,
                "model": model,
                "spec": spec,
                "type": product_type
            })
    
    return catalog

def generate_synthetic_invoice(num_invoices=1, num_merchants=10, anomaly_rate=0.05):
    """
    Generate synthetic invoice data based on the provided schema
    
    Parameters:
    num_invoices (int): Number of synthetic invoices to generate
    num_invoices (int): Number of synthetic merchants to generate
    anomaly_rate (float): Rate at which to introduce data anomalies
    
    Returns:
    list: List of invoice dictionaries following the extraction schema
    """
    invoices = []
    
    # Generate merchant data
    merchants = generate_merchant_data(num_merchants)
    
    # Generate product catalog
    product_catalog = generate_product_catalog()
    
    # Define payment terms with weighted probabilities
    payment_terms = [
        ("NET 30 DAYS", 0.4),
        ("NET 45 DAYS", 0.2),
        ("NET 60 DAYS", 0.1),
        ("DUE ON RECEIPT", 0.15),
        ("2/10 NET 30", 0.05),
        ("COD", 0.05),
        ("NET 15 DAYS", 0.05)
    ]
    
    # Define payment methods
    payment_methods = {
        "shipping": ["UPS Ground", "FedEx Express", "FedEx Ground", "USPS Priority", "DHL Express"],
        "payment": ["Credit Card", "Wire Transfer", "ACH", "Check", "PayPal", "Net Banking"]
    }
    
    # Define currencies with correct format
    currencies = {
        "US": "USD",
    }
    
    # Define tax rates by state
    tax_rates = synthetic_data_configs["tax_rates"]
    
    # Customer data generation
    customers = []
    num_customers = min(num_invoices // 5, 50)  # Create a reasonable number of customers
    for _ in range(max(1, num_customers)):  # Ensure at least one customer
        customer = {
            "name": fake.company(),
            "customer_id": f"CUST-{random.randint(10000, 99999)}",
            "address": fake.address().replace('\n', ', '),
            "contact_person": fake.name(),
            "email": fake.company_email(),
            "phone": fake.phone_number()
        }
        customers.append(customer)
    
    # Create a distribution of invoices where some merchants and customers appear more often
    # This mimics real world patterns where certain suppliers are used more frequently
    merchant_weights = np.random.exponential(scale=1.0, size=len(merchants))
    merchant_weights = merchant_weights / np.sum(merchant_weights)
    
    customer_weights = np.random.exponential(scale=1.0, size=len(customers))
    customer_weights = customer_weights / np.sum(customer_weights)
    
    # Track merchant-customer relationships to create realistic patterns
    merchant_customers = defaultdict(list)
    
    # Track invoice numbers by merchant
    merchant_invoice_counters = {m["name"]: 1 for m in merchants}
    
    # Generate invoice data
    for invoice_idx in range(num_invoices):
        # Select merchant with weighted probability
        merchant = np.random.choice(merchants, p=merchant_weights)
        merchant_name = merchant["name"]
        merchant_address = merchant["address"]
        merchant_type = merchant["type"]
        city = merchant["city"]
        state = merchant["state"]
        country = merchant["country"]
        currency = currencies[country]
        
        # Generate realistic invoice number
        invoice_prefix = ''.join(random.choice(merchant_name.split()[0:1]).upper()[0:3])
        invoice_year = datetime.now().year
        invoice_num = merchant_invoice_counters[merchant_name]
        merchant_invoice_counters[merchant_name] += 1
        invoice_number = f"{invoice_prefix}{invoice_year}-{invoice_num:05d}"
        
        # Generate invoice date (weighted toward recent dates)
        days_ago = int(np.random.exponential(scale=60))  # Mostly recent invoices
        days_ago = min(days_ago, 365)  # Cap at 1 year
        invoice_date = datetime.now() - timedelta(days=days_ago)
        
        # Format date according to country conventions
        if country in ['US', 'CA']:
            invoice_date_str = invoice_date.strftime("%m/%d/%Y")
        else:
            invoice_date_str = invoice_date.strftime("%d/%m/%Y")
        
        # Select payment term with weighted probability
        payment_term = random.choices([term[0] for term in payment_terms], 
                                     weights=[term[1] for term in payment_terms])[0]
        
        # Calculate due date based on payment terms
        if "30" in payment_term:
            due_days = 30
        elif "45" in payment_term:
            due_days = 45
        elif "60" in payment_term:
            due_days = 60
        elif "15" in payment_term:
            due_days = 15
        elif "RECEIPT" in payment_term or "COD" in payment_term:
            due_days = 0
        else:  # Default for 2/10 NET 30 or other formats
            due_days = 30
            
        due_date = invoice_date + timedelta(days=due_days)
        
        # Format due date according to country conventions
        if country in ['US', 'CA']:
            due_date_str = due_date.strftime("%m/%d/%Y")
        else:
            due_date_str = due_date.strftime("%d/%m/%Y")
        
        # Select or create a customer relationship
        if merchant_name in merchant_customers and random.random() < 0.8:
            # 80% chance to use an existing customer for this merchant
            customer = random.choice(merchant_customers[merchant_name])
        else:
            # Either new merchant or 20% chance to add a new customer
            customer = np.random.choice(customers, p=customer_weights)
            merchant_customers[merchant_name].append(customer)
        
        # Generate PO number with several realistic formats
        po_formats = [
            f"{random.randint(10000, 99999)}-{random.randint(100, 999)}",
            f"PO-{random.randint(10000, 99999)}",
            f"{customer['customer_id']}-{random.randint(1000, 9999)}",
            f"{datetime.now().strftime('%y%m')}-{random.randint(1000, 9999)}",
            f"{random.randint(100000, 999999)}",
            f"{random.choice('ABCDEFGHJKLMNPQRSTUVWXYZ')}{random.randint(10000, 99999)}"
        ]
        po_number = random.choice(po_formats)
        
        # Determine payment method based on merchant type and customer patterns
        if random.random() < 0.7:  # 70% chance it's a shipping method
            payment_method = random.choice(payment_methods["shipping"])
        else:  # 30% chance it's an actual payment method
            payment_method = random.choice(payment_methods["payment"])
        
        # Generate line items
        line_items = []
        
        # Number of items follows a distribution centered on 3-4 items
        num_items_distribution = [0.1, 0.2, 0.3, 0.2, 0.1, 0.05, 0.03, 0.02]
        num_items = np.random.choice(range(1, len(num_items_distribution) + 1), 
                                    p=num_items_distribution)
        
        # For some merchants, force at least 2 line items to mimic bundled purchases
        if random.random() < 0.3 and num_items == 1:
            num_items = 2
        
        # Select products from appropriate category for merchant type
        available_products = product_catalog.get(merchant_type, [])
        if not available_products:  # Fallback if category doesn't match
            available_products = random.choice(list(product_catalog.values()))
        
        # Select products without replacement if possible
        selected_products = random.sample(available_products, 
                                         min(num_items, len(available_products)))
        
        # If we need more products than unique ones available, allow repeats
        if num_items > len(selected_products):
            additional_products = [random.choice(available_products) 
                                  for _ in range(num_items - len(selected_products))]
            selected_products.extend(additional_products)
        
        # Calculate tax rates based on country and region
        tax_rate = tax_rates.get(state, 0.0)
        
        # Handle special case for shipping
        shipping_cost = 0
        if random.random() < 0.4:  # 40% chance of separate shipping charge
            shipping_cost = round(random.uniform(5, 50), 2)
        
        subtotal = 0
        total_tax = 0
        
        # Collect line details in the expected format
        formatted_line_details = []
        
        # Generate each line item
        for i, product in enumerate(selected_products, 1):
            description = product["description"]
            unit_price = product["unit_price"]
            
            # Generate quantity with realistic distribution
            qty_distribution = {
                1: 0.3,   # 30% chance of qty 1
                2: 0.2,   # 20% chance of qty 2
                3: 0.1,   # 10% chance of qty 3
                4: 0.05,  # 5% chance of qty 4
                5: 0.05,  # 5% chance of qty 5
                10: 0.1,  # 10% chance of qty 10
                12: 0.05, # 5% chance of qty 12
                24: 0.05, # 5% chance of qty 24
                50: 0.05, # 5% chance of qty 50
                100: 0.05 # 5% chance of qty 100
            }
            
            qty = random.choices(list(qty_distribution.keys()), 
                               weights=list(qty_distribution.values()))[0]
            
            # Calculate line total with realistic price adjustments
            # Occasionally apply discounts for bulk purchases
            discount = 1.0
            if qty >= 10:
                discount = random.uniform(0.85, 0.95)
            elif qty >= 50:
                discount = random.uniform(0.75, 0.85)
            
            # Apply slight random variance to unit price
            adjusted_unit_price = unit_price * random.uniform(0.98, 1.02) * discount
            line_total = round(adjusted_unit_price * qty, 2)
            
            # Calculate line tax
            line_tax = round(line_total * tax_rate, 2) if tax_rate > 0 else 0.0            
            
            label = 0 ### added
            # For anomalies, occasionally introduce incorrect calculations
            if random.random() < anomaly_rate * 0.3:  # 30% of anomalies
                duplicated_product = random.choice(selected_products)
                selected_products.insert(i, duplicated_product)
                label = 1 ### added
                
            if random.random() < anomaly_rate:
                anomaly_type = random.choice(['tax_calc', 'line_total', 'skip_tax', 'negative_qty', 'price_mismatch'])
                if anomaly_type == 'tax_calc':
                    line_tax = round(line_total * random.uniform(0.05, 0.25), 2)
                elif anomaly_type == 'line_total':
                    # Slightly off multiplication
                    line_total = round(adjusted_unit_price * qty * random.uniform(0.9, 1.1), 2)
                elif anomaly_type == 'skip_tax':
                    line_tax = 0.0
                elif anomaly_type == 'negative_qty':
                    qty = -abs(qty)
                elif anomaly_type == 'price_mismatch':
                    catalog_price = product["unit_price"]
                    deviation = random.uniform(0.5, 2.0)
                    adjusted_unit_price = catalog_price * deviation
                label = 1 ### added
            
            # Add line details to our formatted output
            formatted_line_details.append({
                "line_count": str(i),
                "line_description": description,
                "line_qty": str(qty),
                "line_tax": "{:.2f}".format(line_tax),
                "line_total": "{:.2f}".format(line_total)
            })
            
            # Add to running totals
            subtotal += line_total
            total_tax += line_tax
        
        # Calculate grand total
        grand_total = subtotal + total_tax + shipping_cost
        
        # Create formatted invoice following the schema
        formatted_invoice = {
            "extractions": [
                {"field": "merchant", "value": merchant_name},
                {"field": "invoice_date", "value": invoice_date_str},
                {"field": "merchant_branch", "value": merchant_name},  # Using same value as merchant
                {"field": "merchant_chain", "value": merchant_name},   # Using same value as merchant
                {"field": "due_date", "value": due_date_str},
                {"field": "payment_terms", "value": payment_term},
                {"field": "grand_total", "value": "{:.2f}".format(grand_total)},
                {"field": "tax", "value": "{:.2f}".format(total_tax)},
                {"field": "po_number", "value": po_number},
                {"field": "merchant_address", "value": merchant_address.replace(',', '')},
                {"field": "payment_method", "value": payment_method},
                {"field": "country", "value": country},
                {"field": "currency", "value": currency},
                {'field': 'label', 'value': label}, ###
                {"field": "line_details", "value": formatted_line_details}
            ]
        }
        
        invoices.append(formatted_invoice)
    
    return invoices

def analyze_synthetic_data(invoices):
    """
    Analyze the generated synthetic data
    
    Parameters:
    invoices (list): List of invoice dictionaries
    """
    # Count merchants
    merchants = set()
    countries = set()
    total_value = 0
    line_items_count = 0
    
    for invoice in invoices:
        extractions = {item["field"]: item["value"] for item in invoice["extractions"]}
        
        if "merchant" in extractions:
            merchants.add(extractions["merchant"])
        
        if "country" in extractions:
            countries.add(extractions["country"])
        
        if "grand_total" in extractions:
            try:
                total_value += float(extractions["grand_total"])
            except ValueError:
                pass
        
        if "line_details" in extractions:
            line_items = extractions["line_details"]
            if isinstance(line_items, list):
                line_items_count += len(line_items)
    
    print(f"Analysis of {len(invoices)} invoices:")
    print(f"- Unique merchants: {len(merchants)}")
    print(f"- Total line items: {line_items_count}")
    print(f"- Average line items per invoice: {line_items_count/len(invoices):.2f}")
    
    # Count frequency of fields
    field_counts = defaultdict(int)
    for invoice in invoices:
        for item in invoice["extractions"]:
            field_counts[item["field"]] += 1
    
    print("\nField frequency:")
    for field, count in sorted(field_counts.items(), key=lambda x: x[1], reverse=True):
        percentage = count / len(invoices) * 100
        print(f"- {field}: {count} ({percentage:.1f}%)")

def save_synthetic_data(invoices, base_filename="synthetic_invoices3"): #change filename here
    """   
    Parameters:
    invoices (list): List of invoice dictionaries
    base_filename (str): Base filename without extension
    """
    # Save all invoices to one file
    all_filename = f"{base_filename}.json"
    with open(all_filename, 'w') as f:
        json.dump(invoices, f, indent=2)
    
    print(f"Generated {len(invoices)} synthetic invoices and saved to {all_filename}")
    
    # Save in JSONL format as well (one invoice per line, no indentation)
    jsonl_filename = f"{base_filename}.jsonl"
    with open(jsonl_filename, 'w') as f:
        for invoice in invoices:
            f.write(json.dumps(invoice) + '\n')
    
    print(f"Saved invoices in JSONL format to {jsonl_filename}")

# Main function to generate invoices
def generate_dataset(num_invoices=100, num_merchants=1000, anomaly_rate=0.05, seed=42):
    """
    Generate a complete synthetic invoice dataset
    
    Parameters:
    num_invoices (int): Number of invoices to generate
    anomaly_rate (float): Rate of anomalies to introduce
    seed (int): Random seed for reproducibility
    
    Returns:
    list: Generated invoices
    """
    # Set random seeds
    random.seed(seed)
    np.random.seed(seed)
    Faker.seed(seed)
    
    print(f"Generating {num_invoices} synthetic invoices across a set of {num_merchants} merchants (anomaly rate: {anomaly_rate:.1%})...")
    invoices = generate_synthetic_invoice(num_invoices, num_merchants, anomaly_rate)
    
    # Analyze the generated data
    analyze_synthetic_data(invoices)
    
    # Save the data
    save_synthetic_data(invoices)
    
    return invoices

# %%
# Generate invoices when run directly

generate_dataset(num_invoices=10,num_merchants=100)
# Out:
# Generating 10 synthetic invoices across a set of 100 merchants (anomaly rate: 5.0%)...
# Analysis of 10 invoices:
# - Unique merchants: 8
# - Total line items: 30
# - Average line items per invoice: 3.00
#
# Field frequency:
# - merchant: 10 (100.0%)
# - invoice_date: 10 (100.0%)
# - merchant_branch: 10 (100.0%)
# - merchant_chain: 10 (100.0%)
# - due_date: 10 (100.0%)
# - payment_terms: 10 (100.0%)
# - grand_total: 10 (100.0%)
# - tax: 10 (100.0%)
# - po_number: 10 (100.0%)
# - merchant_address: 10 (100.0%)
# - payment_method: 10 (100.0%)
# - country: 10 (100.0%)
# - currency: 10 (100.0%)
# - label: 10 (100.0%)
# - line_details: 10 (100.0%)
# Generated 10 synthetic invoices and saved to synthetic_invoices3.json
# Saved invoices in JSONL format to synthetic_invoices3.jsonl
# [{'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '01/20/2025'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '03/21/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '378967.88'},
#    {'field': 'tax', 'value': '14574.63'},
#    {'field': 'po_number', 'value': '2503-3344'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'A-6368 Deluxe Structural Component',
#       'line_qty': '100',
#       'line_tax': '14366.87',
#       'line_total': '359171.74'},
#      {'line_count': '2',
#       'line_description': 'FD-0317 Extended Safety Mechanism',
#       'line_qty': '1',
#       'line_tax': '207.76',
#       'line_total': '5194.02'}]}]},
#  {'extractions': [{'field': 'merchant',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'invoice_date', 'value': '12/09/2024'},
#    {'field': 'merchant_branch',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'merchant_chain',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'due_date', 'value': '02/07/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '515.10'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': '80742-619'},
#    {'field': 'merchant_address',
#     'value': '2245 Sims Manor Apt. 417 Port Patricia PW 50796 USA'},
#    {'field': 'payment_method', 'value': 'Net Banking'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 1},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'KXM-22885 Deluxe Hardware',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '515.10'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'invoice_date', 'value': '02/21/2025'},
#    {'field': 'merchant_branch', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'merchant_chain', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'due_date', 'value': '03/23/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '53131.26'},
#    {'field': 'tax', 'value': '3303.58'},
#    {'field': 'po_number', 'value': '209493'},
#    {'field': 'merchant_address',
#     'value': '5744 Gonzalez Knoll Larsonbury NJ 46878 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'LW-78091 Commercial Compressor',
#       'line_qty': '3',
#       'line_tax': '220.98',
#       'line_total': '3332.97'},
#      {'line_count': '2',
#       'line_description': 'S-51718 Advanced Valve',
#       'line_qty': '24',
#       'line_tax': '1538.81',
#       'line_total': '23209.77'},
#      {'line_count': '3',
#       'line_description': 'T-473 Heavy Duty Gauge',
#       'line_qty': '1',
#       'line_tax': '52.68',
#       'line_total': '794.60'},
#      {'line_count': '4',
#       'line_description': 'MZE-456 Industrial Valve',
#       'line_qty': '24',
#       'line_tax': '1437.61',
#       'line_total': '21683.37'},
#      {'line_count': '5',
#       'line_description': 'K-7005 Basic Compressor',
#       'line_qty': '2',
#       'line_tax': '53.50',
#       'line_total': '806.97'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Taylor Automotive Co.'},
#    {'field': 'invoice_date', 'value': '10/31/2024'},
#    {'field': 'merchant_branch', 'value': 'Taylor Automotive Co.'},
#    {'field': 'merchant_chain', 'value': 'Taylor Automotive Co.'},
#    {'field': 'due_date', 'value': '11/30/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '3188.55'},
#    {'field': 'tax', 'value': '137.31'},
#    {'field': 'po_number', 'value': '27878-568'},
#    {'field': 'merchant_address',
#     'value': '82198 Wilson Harbors Suite 932 Millerstad OK 82021 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'NC-83982 Economy Brake System',
#       'line_qty': '1',
#       'line_tax': '2.07',
#       'line_total': '45.95'},
#      {'line_count': '2',
#       'line_description': 'SDU-485 Extended Electrical Component',
#       'line_qty': '4',
#       'line_tax': '135.24',
#       'line_total': '3005.29'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Manage Aerospace Systems'},
#    {'field': 'invoice_date', 'value': '01/16/2025'},
#    {'field': 'merchant_branch', 'value': 'Manage Aerospace Systems'},
#    {'field': 'merchant_chain', 'value': 'Manage Aerospace Systems'},
#    {'field': 'due_date', 'value': '03/02/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '196085.06'},
#    {'field': 'tax', 'value': '8443.86'},
#    {'field': 'po_number', 'value': 'PO-40107'},
#    {'field': 'merchant_address',
#     'value': '116 Joel Vista Suite 990 Susantown OK 95058 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'YYV-82795 Advanced Safety Mechanism',
#       'line_qty': '24',
#       'line_tax': '6194.37',
#       'line_total': '137652.63'},
#      {'line_count': '2',
#       'line_description': 'LQH-6096 Deluxe Cabin Equipment',
#       'line_qty': '10',
#       'line_tax': '376.79',
#       'line_total': '8373.09'},
#      {'line_count': '3',
#       'line_description': 'MCS-68926 Extended Cabin Equipment',
#       'line_qty': '12',
#       'line_tax': '1156.13',
#       'line_total': '25691.71'},
#      {'line_count': '4',
#       'line_description': 'L-8299 Lightweight Structural Component',
#       'line_qty': '1',
#       'line_tax': '173.15',
#       'line_total': '3847.86'},
#      {'line_count': '5',
#       'line_description': 'EW-25188 Deluxe Communication Device',
#       'line_qty': '2',
#       'line_tax': '543.42',
#       'line_total': '12075.91'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '02/25/2025'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '04/26/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '12560.54'},
#    {'field': 'tax', 'value': '481.82'},
#    {'field': 'po_number', 'value': 'Q28169'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'C-9587 Standard Communication Device',
#       'line_qty': '2',
#       'line_tax': '294.00',
#       'line_total': '7349.94'},
#      {'line_count': '2',
#       'line_description': 'Z-768 Premium Communication Device',
#       'line_qty': '1',
#       'line_tax': '187.82',
#       'line_total': '4695.55'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Such LLC'},
#    {'field': 'invoice_date', 'value': '11/21/2024'},
#    {'field': 'merchant_branch', 'value': 'Such LLC'},
#    {'field': 'merchant_chain', 'value': 'Such LLC'},
#    {'field': 'due_date', 'value': '11/21/2024'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '830.19'},
#    {'field': 'tax', 'value': '34.28'},
#    {'field': 'po_number', 'value': '20611-735'},
#    {'field': 'merchant_address',
#     'value': '98751 Ryan Plains East Derrick OK 20437 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'K-253 Heavy Duty Laminator',
#       'line_qty': '10',
#       'line_tax': '34.28',
#       'line_total': '761.74'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Anderson-Perry Inc.'},
#    {'field': 'invoice_date', 'value': '01/30/2025'},
#    {'field': 'merchant_branch', 'value': 'Anderson-Perry Inc.'},
#    {'field': 'merchant_chain', 'value': 'Anderson-Perry Inc.'},
#    {'field': 'due_date', 'value': '03/01/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '8942.03'},
#    {'field': 'tax', 'value': '385.06'},
#    {'field': 'po_number', 'value': '436030'},
#    {'field': 'merchant_address',
#     'value': '213 Holland Shoal Suite 525 Wrightstad OK 87218 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'X-900 Ultimate Gauge',
#       'line_qty': '3',
#       'line_tax': '236.92',
#       'line_total': '5265.00'},
#      {'line_count': '2',
#       'line_description': 'SKQ-96118 Deluxe Conveyor Belt',
#       'line_qty': '5',
#       'line_tax': '148.14',
#       'line_total': '3291.97'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '09/13/2024'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '09/13/2024'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '40124.13'},
#    {'field': 'tax', 'value': '1543.23'},
#    {'field': 'po_number', 'value': '18601-292'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'EW-25188 Deluxe Communication Device',
#       'line_qty': '4',
#       'line_tax': '969.01',
#       'line_total': '24225.27'},
#      {'line_count': '2',
#       'line_description': 'FV-430 Premium Cabin Equipment',
#       'line_qty': '3',
#       'line_tax': '97.69',
#       'line_total': '2442.30'},
#      {'line_count': '3',
#       'line_description': 'N-7223 Commercial Structural Component',
#       'line_qty': '2',
#       'line_tax': '476.53',
#       'line_total': '11913.33'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Martinez'},
#    {'field': 'invoice_date', 'value': '02/04/2025'},
#    {'field': 'merchant_branch', 'value': 'Martinez'},
#    {'field': 'merchant_chain', 'value': 'Martinez'},
#    {'field': 'due_date', 'value': '03/06/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '82165.45'},
#    {'field': 'tax', 'value': '5014.79'},
#    {'field': 'po_number', 'value': 'L95951'},
#    {'field': 'merchant_address',
#     'value': '79463 Patrick Lodge Barnesville KS 32663 USA'},
#    {'field': 'payment_method', 'value': 'Check'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'DEP-422 Commercial Fluid',
#       'line_qty': '2',
#       'line_tax': '40.06',
#       'line_total': '616.27'},
#      {'line_count': '2',
#       'line_description': 'ZJY-7759 Standard Electrical Component',
#       'line_qty': '2',
#       'line_tax': '50.51',
#       'line_total': '777.08'},
#      {'line_count': '3',
#       'line_description': 'SDU-485 Extended Electrical Component',
#       'line_qty': '1',
#       'line_tax': '47.86',
#       'line_total': '736.31'},
#      {'line_count': '4',
#       'line_description': 'LT-29750 Standard Brake System',
#       'line_qty': '4',
#       'line_tax': '133.07',
#       'line_total': '2047.28'},
#      {'line_count': '5',
#       'line_description': 'ZY-5140 Ultimate Engine Component',
#       'line_qty': '1',
#       'line_tax': '56.13',
#       'line_total': '863.49'},
#      {'line_count': '6',
#       'line_description': 'DH-959 Economy Engine Component',
#       'line_qty': '50',
#       'line_tax': '1020.18',
#       'line_total': '15695.13'},
#      {'line_count': '7',
#       'line_description': 'C-475 Ultimate Brake System',
#       'line_qty': '100',
#       'line_tax': '3666.98',
#       'line_total': '56415.10'}]}]}]

# %%
generate_dataset(num_invoices=100,num_merchants=50)
# Out:
# Generating 100 synthetic invoices across a set of 50 merchants (anomaly rate: 5.0%)...
# Analysis of 100 invoices:
# - Unique merchants: 31
# - Total line items: 359
# - Average line items per invoice: 3.59
#
# Field frequency:
# - merchant: 100 (100.0%)
# - invoice_date: 100 (100.0%)
# - merchant_branch: 100 (100.0%)
# - merchant_chain: 100 (100.0%)
# - due_date: 100 (100.0%)
# - payment_terms: 100 (100.0%)
# - grand_total: 100 (100.0%)
# - tax: 100 (100.0%)
# - po_number: 100 (100.0%)
# - merchant_address: 100 (100.0%)
# - payment_method: 100 (100.0%)
# - country: 100 (100.0%)
# - currency: 100 (100.0%)
# - label: 100 (100.0%)
# - line_details: 100 (100.0%)
# Generated 100 synthetic invoices and saved to synthetic_invoices3.json
# Saved invoices in JSONL format to synthetic_invoices3.jsonl
# [{'extractions': [{'field': 'merchant',
#     'value': 'EnterOfficer Technology LLC'},
#    {'field': 'invoice_date', 'value': '03/01/2025'},
#    {'field': 'merchant_branch', 'value': 'EnterOfficer Technology LLC'},
#    {'field': 'merchant_chain', 'value': 'EnterOfficer Technology LLC'},
#    {'field': 'due_date', 'value': '03/01/2025'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '159229.31'},
#    {'field': 'tax', 'value': '6855.90'},
#    {'field': 'po_number', 'value': '612997'},
#    {'field': 'merchant_address',
#     'value': '07878 Paula Points Boydland OK 51912 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'F-90878 Premium Network Device',
#       'line_qty': '10',
#       'line_tax': '1188.90',
#       'line_total': '26419.94'},
#      {'line_count': '2',
#       'line_description': 'TED-099 Lightweight Server',
#       'line_qty': '50',
#       'line_tax': '3749.55',
#       'line_total': '83323.43'},
#      {'line_count': '3',
#       'line_description': 'N-99586 Lightweight Network Device',
#       'line_qty': '1',
#       'line_tax': '19.90',
#       'line_total': '442.23'},
#      {'line_count': '4',
#       'line_description': 'YF-752 Heavy Duty Network Device',
#       'line_qty': '10',
#       'line_tax': '1153.17',
#       'line_total': '25625.93'},
#      {'line_count': '5',
#       'line_description': 'AB-35058 Commercial Cable',
#       'line_qty': '10',
#       'line_tax': '744.38',
#       'line_total': '16541.68'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '12/26/2024'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '01/25/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '2924.97'},
#    {'field': 'tax', 'value': '111.12'},
#    {'field': 'po_number', 'value': 'CUST-73766-4613'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'Net Banking'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'LQH-6096 Deluxe Cabin Equipment',
#       'line_qty': '3',
#       'line_tax': '111.12',
#       'line_total': '2778.07'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'WorryAdult'},
#    {'field': 'invoice_date', 'value': '03/07/2025'},
#    {'field': 'merchant_branch', 'value': 'WorryAdult'},
#    {'field': 'merchant_chain', 'value': 'WorryAdult'},
#    {'field': 'due_date', 'value': '04/21/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '165799.63'},
#    {'field': 'tax', 'value': '10846.70'},
#    {'field': 'po_number', 'value': 'P32026'},
#    {'field': 'merchant_address',
#     'value': '23616 Blackburn Field Sergiochester TN 56955 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'SHH-465 Economy Safety Mechanism',
#       'line_qty': '4',
#       'line_tax': '648.63',
#       'line_total': '9266.18'},
#      {'line_count': '2',
#       'line_description': 'WA-645 Basic Navigation System',
#       'line_qty': '1',
#       'line_tax': '37.15',
#       'line_total': '530.77'},
#      {'line_count': '3',
#       'line_description': 'YYV-82795 Advanced Safety Mechanism',
#       'line_qty': '24',
#       'line_tax': '9933.57',
#       'line_total': '141908.19'},
#      {'line_count': '4',
#       'line_description': 'U-82665 Compact Navigation System',
#       'line_qty': '1',
#       'line_tax': '227.35',
#       'line_total': '3247.79'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'WorryAdult'},
#    {'field': 'invoice_date', 'value': '03/11/2025'},
#    {'field': 'merchant_branch', 'value': 'WorryAdult'},
#    {'field': 'merchant_chain', 'value': 'WorryAdult'},
#    {'field': 'due_date', 'value': '05/10/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '59754.38'},
#    {'field': 'tax', 'value': '3909.16'},
#    {'field': 'po_number', 'value': 'PO-21537'},
#    {'field': 'merchant_address',
#     'value': '23616 Blackburn Field Sergiochester TN 56955 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'NZB-68034 Compact Safety Mechanism',
#       'line_qty': '5',
#       'line_tax': '746.72',
#       'line_total': '10667.49'},
#      {'line_count': '2',
#       'line_description': 'GEK-82629 Advanced Safety Mechanism',
#       'line_qty': '5',
#       'line_tax': '2580.81',
#       'line_total': '36868.66'},
#      {'line_count': '3',
#       'line_description': 'T-9830 Industrial Navigation System',
#       'line_qty': '5',
#       'line_tax': '581.63',
#       'line_total': '8309.07'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Jones & Wilson'},
#    {'field': 'invoice_date', 'value': '12/26/2024'},
#    {'field': 'merchant_branch', 'value': 'Jones & Wilson'},
#    {'field': 'merchant_chain', 'value': 'Jones & Wilson'},
#    {'field': 'due_date', 'value': '01/25/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '14631.12'},
#    {'field': 'tax', 'value': '892.97'},
#    {'field': 'po_number', 'value': 'PO-69394'},
#    {'field': 'merchant_address',
#     'value': '1910 Booth Roads Suite 855 Lake Andrea WA 92917 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'ZVK-04389 Extended Laboratory Supply',
#       'line_qty': '10',
#       'line_tax': '419.04',
#       'line_total': '6446.84'},
#      {'line_count': '2',
#       'line_description': 'MZ-269 Economy Diagnostic Device',
#       'line_qty': '1',
#       'line_tax': '67.42',
#       'line_total': '1037.27'},
#      {'line_count': '3',
#       'line_description': 'PJ-14917 Compact Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '87.00',
#       'line_total': '1338.47'},
#      {'line_count': '4',
#       'line_description': 'E-003 Industrial Sterilization Equipment',
#       'line_qty': '1',
#       'line_tax': '103.00',
#       'line_total': '1584.62'},
#      {'line_count': '5',
#       'line_description': 'THE-603 Extended Diagnostic Device',
#       'line_qty': '2',
#       'line_tax': '216.51',
#       'line_total': '3330.95'}]}]},
#  {'extractions': [{'field': 'merchant',
#     'value': 'EveryoneOther Office Supplies Systems'},
#    {'field': 'invoice_date', 'value': '03/07/2025'},
#    {'field': 'merchant_branch',
#     'value': 'EveryoneOther Office Supplies Systems'},
#    {'field': 'merchant_chain',
#     'value': 'EveryoneOther Office Supplies Systems'},
#    {'field': 'due_date', 'value': '04/06/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '12697.35'},
#    {'field': 'tax', 'value': '369.37'},
#    {'field': 'po_number', 'value': '2503-2820'},
#    {'field': 'merchant_address',
#     'value': '98133 Glover Common North Markborough CO 80347 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 1},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'X-65820 Industrial Paper',
#       'line_qty': '100',
#       'line_tax': '331.70',
#       'line_total': '11438.01'},
#      {'line_count': '2',
#       'line_description': 'BAC-943 Ultimate Ink Cartridge',
#       'line_qty': '2',
#       'line_tax': '1.65',
#       'line_total': '56.77'},
#      {'line_count': '3',
#       'line_description': 'F-7826 Premium Ink Cartridge',
#       'line_qty': '2',
#       'line_tax': '8.31',
#       'line_total': '286.71'},
#      {'line_count': '4',
#       'line_description': 'FMS-132 Commercial Label Maker',
#       'line_qty': '1',
#       'line_tax': '3.98',
#       'line_total': '137.36'},
#      {'line_count': '5',
#       'line_description': 'FMS-132 Commercial Label Maker',
#       'line_qty': '3',
#       'line_tax': '23.73',
#       'line_total': '409.13'}]}]},
#  {'extractions': [{'field': 'merchant',
#     'value': 'Villanueva & Rice Technologies'},
#    {'field': 'invoice_date', 'value': '12/16/2024'},
#    {'field': 'merchant_branch', 'value': 'Villanueva & Rice Technologies'},
#    {'field': 'merchant_chain', 'value': 'Villanueva & Rice Technologies'},
#    {'field': 'due_date', 'value': '12/16/2024'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '563.97'},
#    {'field': 'tax', 'value': '21.69'},
#    {'field': 'po_number', 'value': '2503-7460'},
#    {'field': 'merchant_address',
#     'value': '61116 Jason Lock Apt. 925 Hayeschester GA 10048 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'VE-62229 Ultimate Label Maker',
#       'line_qty': '1',
#       'line_tax': '1.31',
#       'line_total': '32.75'},
#      {'line_count': '2',
#       'line_description': 'D-172 Advanced Binding Equipment',
#       'line_qty': '1',
#       'line_tax': '9.91',
#       'line_total': '247.66'},
#      {'line_count': '3',
#       'line_description': 'L-35841 Professional Toner',
#       'line_qty': '3',
#       'line_tax': '10.47',
#       'line_total': '261.87'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Reyes & King Aerospace'},
#    {'field': 'invoice_date', 'value': '03/13/2025'},
#    {'field': 'merchant_branch', 'value': 'Reyes & King Aerospace'},
#    {'field': 'merchant_chain', 'value': 'Reyes & King Aerospace'},
#    {'field': 'due_date', 'value': '04/12/2025'},
#    {'field': 'payment_terms', 'value': '2/10 NET 30'},
#    {'field': 'grand_total', 'value': '91166.60'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'C60446'},
#    {'field': 'merchant_address',
#     'value': '1209 Solis Ranch Apt. 304 Laurachester PW 15796 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'G-220 Ultimate Structural Component',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '7871.84'},
#      {'line_count': '2',
#       'line_description': 'JHE-6216 Extended Navigation System',
#       'line_qty': '50',
#       'line_tax': '0.00',
#       'line_total': '83294.76'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'invoice_date', 'value': '02/20/2025'},
#    {'field': 'merchant_branch', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'merchant_chain', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'due_date', 'value': '03/22/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '67552.02'},
#    {'field': 'tax', 'value': '4200.22'},
#    {'field': 'po_number', 'value': '245129'},
#    {'field': 'merchant_address',
#     'value': '5744 Gonzalez Knoll Larsonbury NJ 46878 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'NSC-4535 Ultimate Conveyor Belt',
#       'line_qty': '1',
#       'line_tax': '66.37',
#       'line_total': '1001.05'},
#      {'line_count': '2',
#       'line_description': 'P-528 Standard Pump',
#       'line_qty': '1',
#       'line_tax': '39.44',
#       'line_total': '594.86'},
#      {'line_count': '3',
#       'line_description': 'VR-20715 Deluxe Filter',
#       'line_qty': '3',
#       'line_tax': '180.23',
#       'line_total': '2718.47'},
#      {'line_count': '4',
#       'line_description': 'VB-343 Ultimate Filter',
#       'line_qty': '3',
#       'line_tax': '117.15',
#       'line_total': '1767.01'},
#      {'line_count': '5',
#       'line_description': 'XKH-16117 Industrial Filter',
#       'line_qty': '50',
#       'line_tax': '3727.55',
#       'line_total': '56222.47'},
#      {'line_count': '6',
#       'line_description': 'TN-52816 Extended Pump',
#       'line_qty': '2',
#       'line_tax': '69.48',
#       'line_total': '1047.94'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Jones & Wilson'},
#    {'field': 'invoice_date', 'value': '02/11/2025'},
#    {'field': 'merchant_branch', 'value': 'Jones & Wilson'},
#    {'field': 'merchant_chain', 'value': 'Jones & Wilson'},
#    {'field': 'due_date', 'value': '03/13/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '17923.58'},
#    {'field': 'tax', 'value': '1091.23'},
#    {'field': 'po_number', 'value': '407410'},
#    {'field': 'merchant_address',
#     'value': '1910 Booth Roads Suite 855 Lake Andrea WA 92917 USA'},
#    {'field': 'payment_method', 'value': 'Check'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'E-003 Industrial Sterilization Equipment',
#       'line_qty': '1',
#       'line_tax': '104.39',
#       'line_total': '1605.95'},
#      {'line_count': '2',
#       'line_description': 'W-4152 Standard Monitor',
#       'line_qty': '2',
#       'line_tax': '187.91',
#       'line_total': '2890.85'},
#      {'line_count': '3',
#       'line_description': 'H-06174 Ultimate Surgical Instrument',
#       'line_qty': '5',
#       'line_tax': '694.54',
#       'line_total': '10685.26'},
#      {'line_count': '4',
#       'line_description': 'DQ-90421 Standard Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '104.39',
#       'line_total': '1606.06'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'EightTruth Enterprises'},
#    {'field': 'invoice_date', 'value': '03/10/2025'},
#    {'field': 'merchant_branch', 'value': 'EightTruth Enterprises'},
#    {'field': 'merchant_chain', 'value': 'EightTruth Enterprises'},
#    {'field': 'due_date', 'value': '04/09/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '3342.32'},
#    {'field': 'tax', 'value': '159.16'},
#    {'field': 'po_number', 'value': '398196'},
#    {'field': 'merchant_address',
#     'value': '1000 Eileen Plaza Suite 691 West Allen WI 20401 USA'},
#    {'field': 'payment_method', 'value': 'Net Banking'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'UUH-09728 Economy Mold',
#       'line_qty': '5',
#       'line_tax': '117.37',
#       'line_total': '2347.37'},
#      {'line_count': '2',
#       'line_description': 'K-836 Professional Die',
#       'line_qty': '1',
#       'line_tax': '41.79',
#       'line_total': '835.79'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'ChoiceNone'},
#    {'field': 'invoice_date', 'value': '12/05/2024'},
#    {'field': 'merchant_branch', 'value': 'ChoiceNone'},
#    {'field': 'merchant_chain', 'value': 'ChoiceNone'},
#    {'field': 'due_date', 'value': '01/04/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '16594.96'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'PO-51542'},
#    {'field': 'merchant_address',
#     'value': '92349 Brett Drive Apt. 322 Stevenmouth OR 47591 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'ZZT-37346 Compact Battery',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '54.61'},
#      {'line_count': '2',
#       'line_description': 'AKU-66319 Deluxe Sensor',
#       'line_qty': '4',
#       'line_tax': '0.00',
#       'line_total': '2269.57'},
#      {'line_count': '3',
#       'line_description': 'ZL-40139 High Performance Controller',
#       'line_qty': '10',
#       'line_tax': '0.00',
#       'line_total': '7307.33'},
#      {'line_count': '4',
#       'line_description': 'ZHJ-160 Basic Battery',
#       'line_qty': '50',
#       'line_tax': '0.00',
#       'line_total': '6834.69'},
#      {'line_count': '5',
#       'line_description': 'BAH-092 Commercial Sensor',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '128.76'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'invoice_date', 'value': '03/02/2025'},
#    {'field': 'merchant_branch', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'merchant_chain', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'due_date', 'value': '04/01/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '2254.75'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': '94058-299'},
#    {'field': 'merchant_address',
#     'value': '21837 Douglas Cliffs Suite 259 North Melissaport PR 34622 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'ATP-317 Premium Bearing',
#       'line_qty': '4',
#       'line_tax': '0.00',
#       'line_total': '1456.83'},
#      {'line_count': '2',
#       'line_description': 'XSK-0076 Lightweight Valve',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '494.01'},
#      {'line_count': '3',
#       'line_description': 'QYK-61200 Professional Pump',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '284.61'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'invoice_date', 'value': '10/30/2024'},
#    {'field': 'merchant_branch', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'merchant_chain', 'value': 'Martin-Kaiser LLC'},
#    {'field': 'due_date', 'value': '11/29/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '41597.51'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'Z65552'},
#    {'field': 'merchant_address',
#     'value': '21837 Douglas Cliffs Suite 259 North Melissaport PR 34622 USA'},
#    {'field': 'payment_method', 'value': 'Wire Transfer'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'E-73158 Heavy Duty Compressor',
#       'line_qty': '100',
#       'line_tax': '0.00',
#       'line_total': '40877.26'},
#      {'line_count': '2',
#       'line_description': 'ATP-317 Premium Bearing',
#       'line_qty': '2',
#       'line_tax': '0.00',
#       'line_total': '701.60'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'EightTruth Enterprises'},
#    {'field': 'invoice_date', 'value': '02/09/2025'},
#    {'field': 'merchant_branch', 'value': 'EightTruth Enterprises'},
#    {'field': 'merchant_chain', 'value': 'EightTruth Enterprises'},
#    {'field': 'due_date', 'value': '03/26/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '2486.12'},
#    {'field': 'tax', 'value': '116.72'},
#    {'field': 'po_number', 'value': 'CUST-70245-5742'},
#    {'field': 'merchant_address',
#     'value': '1000 Eileen Plaza Suite 691 West Allen WI 20401 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'RQ-592 Heavy Duty Fixture',
#       'line_qty': '1',
#       'line_tax': '19.83',
#       'line_total': '396.59'},
#      {'line_count': '2',
#       'line_description': 'N-49588 Extended Die',
#       'line_qty': '1',
#       'line_tax': '3.95',
#       'line_total': '78.93'},
#      {'line_count': '3',
#       'line_description': 'K-415 Advanced Die',
#       'line_qty': '3',
#       'line_tax': '45.10',
#       'line_total': '901.97'},
#      {'line_count': '4',
#       'line_description': 'HBD-5712 Standard Assembly Kit',
#       'line_qty': '1',
#       'line_tax': '27.18',
#       'line_total': '543.68'},
#      {'line_count': '5',
#       'line_description': 'S-7908 Compact Fixture',
#       'line_qty': '2',
#       'line_tax': '20.66',
#       'line_total': '413.26'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Scott'},
#    {'field': 'invoice_date', 'value': '03/14/2025'},
#    {'field': 'merchant_branch', 'value': 'Scott'},
#    {'field': 'merchant_chain', 'value': 'Scott'},
#    {'field': 'due_date', 'value': '04/13/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '1473.98'},
#    {'field': 'tax', 'value': '83.43'},
#    {'field': 'po_number', 'value': '2503-3675'},
#    {'field': 'merchant_address',
#     'value': '288 Michael Brook Johnland VT 70010 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'X-65820 Industrial Paper',
#       'line_qty': '3',
#       'line_tax': '22.05',
#       'line_total': '367.57'},
#      {'line_count': '2',
#       'line_description': 'VF-45115 Economy Paper',
#       'line_qty': '10',
#       'line_tax': '56.42',
#       'line_total': '940.33'},
#      {'line_count': '3',
#       'line_description': 'U-856 Heavy Duty Binding Equipment',
#       'line_qty': '2',
#       'line_tax': '4.96',
#       'line_total': '82.65'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'EightTruth Enterprises'},
#    {'field': 'invoice_date', 'value': '03/07/2025'},
#    {'field': 'merchant_branch', 'value': 'EightTruth Enterprises'},
#    {'field': 'merchant_chain', 'value': 'EightTruth Enterprises'},
#    {'field': 'due_date', 'value': '03/07/2025'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '3643.87'},
#    {'field': 'tax', 'value': '173.52'},
#    {'field': 'po_number', 'value': 'PO-73556'},
#    {'field': 'merchant_address',
#     'value': '1000 Eileen Plaza Suite 691 West Allen WI 20401 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'A-7868 Lightweight Assembly Kit',
#       'line_qty': '10',
#       'line_tax': '107.12',
#       'line_total': '2142.35'},
#      {'line_count': '2',
#       'line_description': 'K-2265 Advanced Fixture',
#       'line_qty': '1',
#       'line_tax': '24.40',
#       'line_total': '487.99'},
#      {'line_count': '3',
#       'line_description': 'K-836 Professional Die',
#       'line_qty': '1',
#       'line_tax': '42.00',
#       'line_total': '840.01'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'ChoiceNone'},
#    {'field': 'invoice_date', 'value': '02/19/2025'},
#    {'field': 'merchant_branch', 'value': 'ChoiceNone'},
#    {'field': 'merchant_chain', 'value': 'ChoiceNone'},
#    {'field': 'due_date', 'value': '03/21/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '15706.35'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': '39144-231'},
#    {'field': 'merchant_address',
#     'value': '92349 Brett Drive Apt. 322 Stevenmouth OR 47591 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'ZL-40139 High Performance Controller',
#       'line_qty': '10',
#       'line_tax': '0.00',
#       'line_total': '6769.94'},
#      {'line_count': '2',
#       'line_description': 'AKU-66319 Deluxe Sensor',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '575.90'},
#      {'line_count': '3',
#       'line_description': 'Q-046 Heavy Duty Battery',
#       'line_qty': '50',
#       'line_tax': '0.00',
#       'line_total': '8350.66'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '02/15/2025'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '03/17/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '406342.72'},
#    {'field': 'tax', 'value': '15627.12'},
#    {'field': 'po_number', 'value': 'PO-56163'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'KN-251 Compact Communication Device',
#       'line_qty': '50',
#       'line_tax': '5578.58',
#       'line_total': '139464.48'},
#      {'line_count': '2',
#       'line_description': 'JHE-6216 Extended Navigation System',
#       'line_qty': '1',
#       'line_tax': '72.02',
#       'line_total': '1800.42'},
#      {'line_count': '3',
#       'line_description': 'NZB-68034 Compact Safety Mechanism',
#       'line_qty': '100',
#       'line_tax': '7688.92',
#       'line_total': '192222.90'},
#      {'line_count': '4',
#       'line_description': 'Z-33884 Extended Structural Component',
#       'line_qty': '2',
#       'line_tax': '404.58',
#       'line_total': '10114.57'},
#      {'line_count': '5',
#       'line_description': 'WA-645 Basic Navigation System',
#       'line_qty': '2',
#       'line_tax': '42.65',
#       'line_total': '1066.21'},
#      {'line_count': '6',
#       'line_description': 'EQB-352 Ultimate Cabin Equipment',
#       'line_qty': '2',
#       'line_tax': '268.47',
#       'line_total': '6711.84'},
#      {'line_count': '7',
#       'line_description': 'G-220 Ultimate Structural Component',
#       'line_qty': '5',
#       'line_tax': '1571.90',
#       'line_total': '39297.54'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Smith'},
#    {'field': 'invoice_date', 'value': '02/25/2025'},
#    {'field': 'merchant_branch', 'value': 'Smith'},
#    {'field': 'merchant_chain', 'value': 'Smith'},
#    {'field': 'due_date', 'value': '03/27/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '204539.48'},
#    {'field': 'tax', 'value': '12029.60'},
#    {'field': 'po_number', 'value': 'X74441'},
#    {'field': 'merchant_address',
#     'value': '283 Lucas Glen Apt. 830 New Laura TX 83226 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'BAN-11492 Premium Precision Instrument',
#       'line_qty': '100',
#       'line_tax': '11974.35',
#       'line_total': '191589.64'},
#      {'line_count': '2',
#       'line_description': 'TJ-72829 High Performance Precision Instrument',
#       'line_qty': '1',
#       'line_tax': '26.69',
#       'line_total': '427.06'},
#      {'line_count': '3',
#       'line_description': 'AA-25478 Standard Prototyping Material',
#       'line_qty': '1',
#       'line_tax': '28.56',
#       'line_total': '456.90'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Jones & Wilson'},
#    {'field': 'invoice_date', 'value': '03/12/2025'},
#    {'field': 'merchant_branch', 'value': 'Jones & Wilson'},
#    {'field': 'merchant_chain', 'value': 'Jones & Wilson'},
#    {'field': 'due_date', 'value': '03/12/2025'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '20966.08'},
#    {'field': 'tax', 'value': '1279.17'},
#    {'field': 'po_number', 'value': '2503-8938'},
#    {'field': 'merchant_address',
#     'value': '1910 Booth Roads Suite 855 Lake Andrea WA 92917 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'PJ-14917 Compact Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '87.32',
#       'line_total': '1343.43'},
#      {'line_count': '2',
#       'line_description': 'EN-65827 Ultimate Monitor',
#       'line_qty': '5',
#       'line_tax': '1097.50',
#       'line_total': '16884.61'},
#      {'line_count': '3',
#       'line_description': 'W-4152 Standard Monitor',
#       'line_qty': '1',
#       'line_tax': '94.35',
#       'line_total': '1451.49'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Walker'},
#    {'field': 'invoice_date', 'value': '02/23/2025'},
#    {'field': 'merchant_branch', 'value': 'Walker'},
#    {'field': 'merchant_chain', 'value': 'Walker'},
#    {'field': 'due_date', 'value': '03/25/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '70502.20'},
#    {'field': 'tax', 'value': '3738.75'},
#    {'field': 'po_number', 'value': '75260-602'},
#    {'field': 'merchant_address',
#     'value': '421 Robert Glens North Meganburgh AZ 73492 USA'},
#    {'field': 'payment_method', 'value': 'Credit Card'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'BW-727 Advanced Connection Hardware',
#       'line_qty': '24',
#       'line_tax': '2703.60',
#       'line_total': '48278.61'},
#      {'line_count': '2',
#       'line_description': 'DU-75817 Industrial Testing Apparatus',
#       'line_qty': '10',
#       'line_tax': '1035.15',
#       'line_total': '18484.84'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Scott-Butler'},
#    {'field': 'invoice_date', 'value': '02/02/2025'},
#    {'field': 'merchant_branch', 'value': 'Scott-Butler'},
#    {'field': 'merchant_chain', 'value': 'Scott-Butler'},
#    {'field': 'due_date', 'value': '03/19/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '934.70'},
#    {'field': 'tax', 'value': '37.94'},
#    {'field': 'po_number', 'value': '700005'},
#    {'field': 'merchant_address',
#     'value': '33626 Tami Loop Suite 312 Holmestown MO 57935 USA'},
#    {'field': 'payment_method', 'value': 'PayPal'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'H-43320 Standard Memory Module',
#       'line_qty': '2',
#       'line_tax': '13.65',
#       'line_total': '322.62'},
#      {'line_count': '2',
#       'line_description': 'AKU-66319 Deluxe Sensor',
#       'line_qty': '1',
#       'line_tax': '24.29',
#       'line_total': '574.14'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '12/18/2024'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '12/18/2024'},
#    {'field': 'payment_terms', 'value': 'DUE ON RECEIPT'},
#    {'field': 'grand_total', 'value': '28756.54'},
#    {'field': 'tax', 'value': '1105.54'},
#    {'field': 'po_number', 'value': 'PO-55238'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'EQB-352 Ultimate Cabin Equipment',
#       'line_qty': '3',
#       'line_tax': '397.09',
#       'line_total': '9927.21'},
#      {'line_count': '2',
#       'line_description': 'N-7223 Commercial Structural Component',
#       'line_qty': '3',
#       'line_tax': '708.45',
#       'line_total': '17711.15'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '02/15/2025'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '03/02/2025'},
#    {'field': 'payment_terms', 'value': 'NET 15 DAYS'},
#    {'field': 'grand_total', 'value': '93387.72'},
#    {'field': 'tax', 'value': '3591.84'},
#    {'field': 'po_number', 'value': 'CUST-73766-9001'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'N-7223 Commercial Structural Component',
#       'line_qty': '12',
#       'line_tax': '2676.05',
#       'line_total': '66901.19'},
#      {'line_count': '2',
#       'line_description': 'NZB-68034 Compact Safety Mechanism',
#       'line_qty': '1',
#       'line_tax': '87.82',
#       'line_total': '2195.48'},
#      {'line_count': '3',
#       'line_description': 'JHE-6216 Extended Navigation System',
#       'line_qty': '10',
#       'line_tax': '622.96',
#       'line_total': '15574.01'},
#      {'line_count': '4',
#       'line_description': 'Z-33884 Extended Structural Component',
#       'line_qty': '1',
#       'line_tax': '205.01',
#       'line_total': '5125.20'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'invoice_date', 'value': '01/27/2025'},
#    {'field': 'merchant_branch', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'merchant_chain', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'due_date', 'value': '03/28/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '8327.73'},
#    {'field': 'tax', 'value': '517.80'},
#    {'field': 'po_number', 'value': '534439'},
#    {'field': 'merchant_address',
#     'value': '5744 Gonzalez Knoll Larsonbury NJ 46878 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'MP-5125 Lightweight Pump',
#       'line_qty': '24',
#       'line_tax': '461.81',
#       'line_total': '6965.48'},
#      {'line_count': '2',
#       'line_description': 'J-45502 Basic Valve',
#       'line_qty': '2',
#       'line_tax': '55.99',
#       'line_total': '844.45'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Throw GmbH'},
#    {'field': 'invoice_date', 'value': '02/19/2025'},
#    {'field': 'merchant_branch', 'value': 'Throw GmbH'},
#    {'field': 'merchant_chain', 'value': 'Throw GmbH'},
#    {'field': 'due_date', 'value': '02/19/2025'},
#    {'field': 'payment_terms', 'value': 'COD'},
#    {'field': 'grand_total', 'value': '196.81'},
#    {'field': 'tax', 'value': '5.94'},
#    {'field': 'po_number', 'value': 'PO-78454'},
#    {'field': 'merchant_address',
#     'value': '313 Blackburn Isle Suite 095 Seanside AL 15899 USA'},
#    {'field': 'payment_method', 'value': 'ACH'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'UC-517 Compact Document Scanner',
#       'line_qty': '1',
#       'line_tax': '5.94',
#       'line_total': '148.51'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Lee-Richards'},
#    {'field': 'invoice_date', 'value': '01/06/2025'},
#    {'field': 'merchant_branch', 'value': 'Lee-Richards'},
#    {'field': 'merchant_chain', 'value': 'Lee-Richards'},
#    {'field': 'due_date', 'value': '02/05/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '5322.92'},
#    {'field': 'tax', 'value': '204.73'},
#    {'field': 'po_number', 'value': 'PO-63197'},
#    {'field': 'merchant_address',
#     'value': '191 Michael Key Apt. 687 South Kellyberg HI 44887 USA'},
#    {'field': 'payment_method', 'value': 'ACH'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'FX-24172 Deluxe Hardware',
#       'line_qty': '1',
#       'line_tax': '3.35',
#       'line_total': '83.71'},
#      {'line_count': '2',
#       'line_description': 'TMM-414 Standard Tool',
#       'line_qty': '12',
#       'line_tax': '149.83',
#       'line_total': '3745.69'},
#      {'line_count': '3',
#       'line_description': 'KQD-0999 Premium Adhesive',
#       'line_qty': '2',
#       'line_tax': '51.55',
#       'line_total': '1288.79'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'EightTruth Enterprises'},
#    {'field': 'invoice_date', 'value': '01/11/2025'},
#    {'field': 'merchant_branch', 'value': 'EightTruth Enterprises'},
#    {'field': 'merchant_chain', 'value': 'EightTruth Enterprises'},
#    {'field': 'due_date', 'value': '02/10/2025'},
#    {'field': 'payment_terms', 'value': '2/10 NET 30'},
#    {'field': 'grand_total', 'value': '11832.88'},
#    {'field': 'tax', 'value': '563.47'},
#    {'field': 'po_number', 'value': 'PO-98037'},
#    {'field': 'merchant_address',
#     'value': '1000 Eileen Plaza Suite 691 West Allen WI 20401 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'K-2265 Advanced Fixture',
#       'line_qty': '1',
#       'line_tax': '24.98',
#       'line_total': '499.59'},
#      {'line_count': '2',
#       'line_description': 'D-07903 Deluxe Assembly Kit',
#       'line_qty': '12',
#       'line_tax': '466.38',
#       'line_total': '9327.65'},
#      {'line_count': '3',
#       'line_description': 'K-836 Professional Die',
#       'line_qty': '1',
#       'line_tax': '41.44',
#       'line_total': '828.73'},
#      {'line_count': '4',
#       'line_description': 'K-415 Advanced Die',
#       'line_qty': '2',
#       'line_tax': '30.67',
#       'line_total': '613.44'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Election GmbH'},
#    {'field': 'invoice_date', 'value': '09/30/2024'},
#    {'field': 'merchant_branch', 'value': 'Election GmbH'},
#    {'field': 'merchant_chain', 'value': 'Election GmbH'},
#    {'field': 'due_date', 'value': '10/30/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '10693.39'},
#    {'field': 'tax', 'value': '538.22'},
#    {'field': 'po_number', 'value': '2503-5550'},
#    {'field': 'merchant_address',
#     'value': '400 Charles Ville Suite 561 New John VA 87139 USA'},
#    {'field': 'payment_method', 'value': 'ACH'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'GM-97746 Extended Document Scanner',
#       'line_qty': '50',
#       'line_tax': '508.77',
#       'line_total': '9599.47'},
#      {'line_count': '2',
#       'line_description': 'UC-517 Compact Document Scanner',
#       'line_qty': '2',
#       'line_tax': '16.22',
#       'line_total': '306.09'},
#      {'line_count': '3',
#       'line_description': 'D-172 Advanced Binding Equipment',
#       'line_qty': '1',
#       'line_tax': '13.23',
#       'line_total': '249.61'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Jones & Chapman'},
#    {'field': 'invoice_date', 'value': '10/10/2024'},
#    {'field': 'merchant_branch', 'value': 'Jones & Chapman'},
#    {'field': 'merchant_chain', 'value': 'Jones & Chapman'},
#    {'field': 'due_date', 'value': '10/10/2024'},
#    {'field': 'payment_terms', 'value': 'COD'},
#    {'field': 'grand_total', 'value': '32351.01'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'F67520'},
#    {'field': 'merchant_address',
#     'value': '490 Taylor Points Apt. 894 East Christophermouth OR 14553 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'K-86430 Deluxe Chemical',
#       'line_qty': '50',
#       'line_tax': '0.00',
#       'line_total': '12343.26'},
#      {'line_count': '2',
#       'line_description': 'QB-518 Economy Testing Kit',
#       'line_qty': '24',
#       'line_tax': '0.00',
#       'line_total': '20007.75'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'invoice_date', 'value': '12/03/2024'},
#    {'field': 'merchant_branch', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'merchant_chain', 'value': 'Lopez & Johnson Industrial'},
#    {'field': 'due_date', 'value': '01/17/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '12236.99'},
#    {'field': 'tax', 'value': '759.86'},
#    {'field': 'po_number', 'value': 'PO-13584'},
#    {'field': 'merchant_address',
#     'value': '5744 Gonzalez Knoll Larsonbury NJ 46878 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'PFG-858 Extended Actuator',
#       'line_qty': '10',
#       'line_tax': '654.75',
#       'line_total': '9875.57'},
#      {'line_count': '2',
#       'line_description': 'P-528 Standard Pump',
#       'line_qty': '2',
#       'line_tax': '81.69',
#       'line_total': '1232.14'},
#      {'line_count': '3',
#       'line_description': 'ATP-317 Premium Bearing',
#       'line_qty': '1',
#       'line_tax': '23.42',
#       'line_total': '353.19'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Lee-Gonzales Inc.'},
#    {'field': 'invoice_date', 'value': '02/26/2025'},
#    {'field': 'merchant_branch', 'value': 'Lee-Gonzales Inc.'},
#    {'field': 'merchant_chain', 'value': 'Lee-Gonzales Inc.'},
#    {'field': 'due_date', 'value': '03/28/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '5701.94'},
#    {'field': 'tax', 'value': '322.75'},
#    {'field': 'po_number', 'value': '64328-476'},
#    {'field': 'merchant_address',
#     'value': '210 Clarke Stravenue Apt. 838 Newmanhaven IA 10614 USA'},
#    {'field': 'payment_method', 'value': 'PayPal'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'H-8434 Ultimate Fixture',
#       'line_qty': '1',
#       'line_tax': '30.96',
#       'line_total': '515.96'},
#      {'line_count': '2',
#       'line_description': 'RV-74801 Lightweight Raw Material',
#       'line_qty': '1',
#       'line_tax': '18.93',
#       'line_total': '315.52'},
#      {'line_count': '3',
#       'line_description': 'QSY-1910 Basic Tool Set',
#       'line_qty': '10',
#       'line_tax': '53.11',
#       'line_total': '885.18'},
#      {'line_count': '4',
#       'line_description': 'ZBY-838 Heavy Duty Fixture',
#       'line_qty': '1',
#       'line_tax': '60.38',
#       'line_total': '1006.29'},
#      {'line_count': '5',
#       'line_description': 'K-415 Advanced Die',
#       'line_qty': '10',
#       'line_tax': '159.37',
#       'line_total': '2656.24'}]}]},
#  {'extractions': [{'field': 'merchant',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'invoice_date', 'value': '01/13/2025'},
#    {'field': 'merchant_branch',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'merchant_chain',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'due_date', 'value': '01/28/2025'},
#    {'field': 'payment_terms', 'value': 'NET 15 DAYS'},
#    {'field': 'grand_total', 'value': '68275.00'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': '47089-844'},
#    {'field': 'merchant_address',
#     'value': '2245 Sims Manor Apt. 417 Port Patricia PW 50796 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'EW-903 Professional Fastener',
#       'line_qty': '4',
#       'line_tax': '0.00',
#       'line_total': '2361.29'},
#      {'line_count': '2',
#       'line_description': 'TX-9374 Premium Hardware',
#       'line_qty': '100',
#       'line_tax': '0.00',
#       'line_total': '64871.14'},
#      {'line_count': '3',
#       'line_description': 'XDH-475 Professional Tool',
#       'line_qty': '3',
#       'line_tax': '0.00',
#       'line_total': '1042.57'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Gregory-Sanders'},
#    {'field': 'invoice_date', 'value': '10/29/2024'},
#    {'field': 'merchant_branch', 'value': 'Gregory-Sanders'},
#    {'field': 'merchant_chain', 'value': 'Gregory-Sanders'},
#    {'field': 'due_date', 'value': '12/13/2024'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '297994.00'},
#    {'field': 'tax', 'value': '11461.30'},
#    {'field': 'po_number', 'value': 'PO-76131'},
#    {'field': 'merchant_address',
#     'value': '2178 Kathleen Heights Littlemouth GA 73466 USA'},
#    {'field': 'payment_method', 'value': 'PayPal'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'YAB-845 Compact Cabin Equipment',
#       'line_qty': '24',
#       'line_tax': '3114.35',
#       'line_total': '77858.71'},
#      {'line_count': '2',
# ...
#    {'field': 'grand_total', 'value': '15684.74'},
#    {'field': 'tax', 'value': '922.63'},
#    {'field': 'po_number', 'value': '2503-2218'},
#    {'field': 'merchant_address',
#     'value': '78978 Aaron Glens Apt. 396 Port Christinachester MA 29473 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'RV-74801 Lightweight Raw Material',
#       'line_qty': '50',
#       'line_tax': '846.61',
#       'line_total': '13545.75'},
#      {'line_count': '2',
#       'line_description': 'K-415 Advanced Die',
#       'line_qty': '4',
#       'line_tax': '76.02',
#       'line_total': '1216.36'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Jones & Chapman'},
#    {'field': 'invoice_date', 'value': '01/02/2025'},
#    {'field': 'merchant_branch', 'value': 'Jones & Chapman'},
#    {'field': 'merchant_chain', 'value': 'Jones & Chapman'},
#    {'field': 'due_date', 'value': '02/16/2025'},
#    {'field': 'payment_terms', 'value': 'NET 45 DAYS'},
#    {'field': 'grand_total', 'value': '81338.14'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': '59668-126'},
#    {'field': 'merchant_address',
#     'value': '490 Taylor Points Apt. 894 East Christophermouth OR 14553 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'BND-20347 Basic Analysis Equipment',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '137.10'},
#      {'line_count': '2',
#       'line_description': 'QB-518 Economy Testing Kit',
#       'line_qty': '100',
#       'line_tax': '0.00',
#       'line_total': '78409.05'},
#      {'line_count': '3',
#       'line_description': 'BZN-9849 Standard Glassware',
#       'line_qty': '3',
#       'line_tax': '0.00',
#       'line_total': '300.64'},
#      {'line_count': '4',
#       'line_description': 'D-865 Ultimate Sample Container',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '2491.35'}]}]},
#  {'extractions': [{'field': 'merchant',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'invoice_date', 'value': '12/25/2024'},
#    {'field': 'merchant_branch',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'merchant_chain',
#     'value': 'Taylor-Whitehead Construction Enterprises'},
#    {'field': 'due_date', 'value': '02/23/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '589.34'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': '945241'},
#    {'field': 'merchant_address',
#     'value': '2245 Sims Manor Apt. 417 Port Patricia PW 50796 USA'},
#    {'field': 'payment_method', 'value': 'USPS Priority'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'P-29620 Premium Safety Equipment',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '498.07'},
#      {'line_count': '2',
#       'line_description': 'E-616 Commercial Building Material',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '63.16'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Scott-Butler'},
#    {'field': 'invoice_date', 'value': '12/21/2024'},
#    {'field': 'merchant_branch', 'value': 'Scott-Butler'},
#    {'field': 'merchant_chain', 'value': 'Scott-Butler'},
#    {'field': 'due_date', 'value': '02/19/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '15204.84'},
#    {'field': 'tax', 'value': '617.06'},
#    {'field': 'po_number', 'value': '400752'},
#    {'field': 'merchant_address',
#     'value': '33626 Tami Loop Suite 312 Holmestown MO 57935 USA'},
#    {'field': 'payment_method', 'value': 'Wire Transfer'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'BA-2427 Extended Battery',
#       'line_qty': '4',
#       'line_tax': '76.42',
#       'line_total': '1806.64'},
#      {'line_count': '2',
#       'line_description': 'HF-87083 Advanced Sensor',
#       'line_qty': '3',
#       'line_tax': '80.82',
#       'line_total': '1910.61'},
#      {'line_count': '3',
#       'line_description': 'Q-046 Heavy Duty Battery',
#       'line_qty': '12',
#       'line_tax': '83.03',
#       'line_total': '1962.97'},
#      {'line_count': '4',
#       'line_description': 'ZL-40139 High Performance Controller',
#       'line_qty': '1',
#       'line_tax': '32.34',
#       'line_total': '764.50'},
#      {'line_count': '5',
#       'line_description': 'Z-7434 Ultimate Microprocessor',
#       'line_qty': '3',
#       'line_tax': '89.99',
#       'line_total': '2127.34'},
#      {'line_count': '6',
#       'line_description': 'HF-87083 Advanced Sensor',
#       'line_qty': '10',
#       'line_tax': '254.46',
#       'line_total': '6015.72'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'AlthoughArticle Solutions'},
#    {'field': 'invoice_date', 'value': '02/11/2025'},
#    {'field': 'merchant_branch', 'value': 'AlthoughArticle Solutions'},
#    {'field': 'merchant_chain', 'value': 'AlthoughArticle Solutions'},
#    {'field': 'due_date', 'value': '04/12/2025'},
#    {'field': 'payment_terms', 'value': 'NET 60 DAYS'},
#    {'field': 'grand_total', 'value': '23055.50'},
#    {'field': 'tax', 'value': '1404.98'},
#    {'field': 'po_number', 'value': '178771'},
#    {'field': 'merchant_address',
#     'value': '9829 Alyssa Land Apt. 743 Port David KS 96584 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 1},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'N-12275 Advanced Die',
#       'line_qty': '12',
#       'line_tax': '682.82',
#       'line_total': '10504.92'},
#      {'line_count': '2',
#       'line_description': 'UUH-09728 Economy Mold',
#       'line_qty': '1',
#       'line_tax': '29.71',
#       'line_total': '457.08'},
#      {'line_count': '3',
#       'line_description': 'S-4315 Industrial Fixture',
#       'line_qty': '50',
#       'line_tax': '245.70',
#       'line_total': '3779.94'},
#      {'line_count': '4',
#       'line_description': 'D-5585 Ultimate Tool Set',
#       'line_qty': '-50',
#       'line_tax': '446.75',
#       'line_total': '6873.02'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'WorryAdult'},
#    {'field': 'invoice_date', 'value': '10/05/2024'},
#    {'field': 'merchant_branch', 'value': 'WorryAdult'},
#    {'field': 'merchant_chain', 'value': 'WorryAdult'},
#    {'field': 'due_date', 'value': '11/04/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '102989.92'},
#    {'field': 'tax', 'value': '6735.93'},
#    {'field': 'po_number', 'value': '34400-511'},
#    {'field': 'merchant_address',
#     'value': '23616 Blackburn Field Sergiochester TN 56955 USA'},
#    {'field': 'payment_method', 'value': 'FedEx Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'T-9830 Industrial Navigation System',
#       'line_qty': '2',
#       'line_tax': '235.70',
#       'line_total': '3367.15'},
#      {'line_count': '2',
#       'line_description': 'KN-251 Compact Communication Device',
#       'line_qty': '1',
#       'line_tax': '208.39',
#       'line_total': '2977.01'},
#      {'line_count': '3',
#       'line_description': 'EQB-352 Ultimate Cabin Equipment',
#       'line_qty': '1',
#       'line_tax': '238.33',
#       'line_total': '3404.78'},
#      {'line_count': '4',
#       'line_description': 'KN-251 Compact Communication Device',
#       'line_qty': '1',
#       'line_tax': '201.39',
#       'line_total': '2877.07'},
#      {'line_count': '5',
#       'line_description': 'U-82665 Compact Navigation System',
#       'line_qty': '1',
#       'line_tax': '227.58',
#       'line_total': '3251.20'},
#      {'line_count': '6',
#       'line_description': 'LQH-6096 Deluxe Cabin Equipment',
#       'line_qty': '100',
#       'line_tax': '5624.54',
#       'line_total': '80350.60'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Reyes & King Aerospace'},
#    {'field': 'invoice_date', 'value': '12/21/2024'},
#    {'field': 'merchant_branch', 'value': 'Reyes & King Aerospace'},
#    {'field': 'merchant_chain', 'value': 'Reyes & King Aerospace'},
#    {'field': 'due_date', 'value': '01/20/2025'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '77722.92'},
#    {'field': 'tax', 'value': '0.00'},
#    {'field': 'po_number', 'value': 'PO-60967'},
#    {'field': 'merchant_address',
#     'value': '1209 Solis Ranch Apt. 304 Laurachester PW 15796 USA'},
#    {'field': 'payment_method', 'value': 'UPS Ground'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'GEK-82629 Advanced Safety Mechanism',
#       'line_qty': '10',
#       'line_tax': '0.00',
#       'line_total': '64122.71'},
#      {'line_count': '2',
#       'line_description': 'SHH-465 Economy Safety Mechanism',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '2259.25'},
#      {'line_count': '3',
#       'line_description': 'LQH-6096 Deluxe Cabin Equipment',
#       'line_qty': '10',
#       'line_tax': '0.00',
#       'line_total': '8906.44'},
#      {'line_count': '4',
#       'line_description': 'MCS-68926 Extended Cabin Equipment',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '2385.58'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'MatterSouthern'},
#    {'field': 'invoice_date', 'value': '10/26/2024'},
#    {'field': 'merchant_branch', 'value': 'MatterSouthern'},
#    {'field': 'merchant_chain', 'value': 'MatterSouthern'},
#    {'field': 'due_date', 'value': '11/25/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '26260.30'},
#    {'field': 'tax', 'value': '1484.82'},
#    {'field': 'po_number', 'value': 'CUST-36623-4758'},
#    {'field': 'merchant_address',
#     'value': '48515 Jay Islands Apt. 470 West Emily MI 80341 USA'},
#    {'field': 'payment_method', 'value': 'Wire Transfer'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'E-73158 Heavy Duty Compressor',
#       'line_qty': '10',
#       'line_tax': '256.44',
#       'line_total': '4274.08'},
#      {'line_count': '2',
#       'line_description': 'XKH-16117 Industrial Filter',
#       'line_qty': '2',
#       'line_tax': '139.89',
#       'line_total': '2331.44'},
#      {'line_count': '3',
#       'line_description': 'ATP-317 Premium Bearing',
#       'line_qty': '50',
#       'line_tax': '978.93',
#       'line_total': '16315.47'},
#      {'line_count': '4',
#       'line_description': 'VR-20715 Deluxe Filter',
#       'line_qty': '1',
#       'line_tax': '55.56',
#       'line_total': '925.94'},
#      {'line_count': '5',
#       'line_description': 'PB-859 Ultimate Compressor',
#       'line_qty': '1',
#       'line_tax': '54.00',
#       'line_total': '899.93'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Jones & Wilson'},
#    {'field': 'invoice_date', 'value': '10/30/2024'},
#    {'field': 'merchant_branch', 'value': 'Jones & Wilson'},
#    {'field': 'merchant_chain', 'value': 'Jones & Wilson'},
#    {'field': 'due_date', 'value': '11/29/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '3942.46'},
#    {'field': 'tax', 'value': '240.62'},
#    {'field': 'po_number', 'value': 'Z57367'},
#    {'field': 'merchant_address',
#     'value': '1910 Booth Roads Suite 855 Lake Andrea WA 92917 USA'},
#    {'field': 'payment_method', 'value': 'PayPal'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'PJ-14917 Compact Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '85.34',
#       'line_total': '1312.93'},
#      {'line_count': '2',
#       'line_description': 'B-5622 Advanced Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '52.30',
#       'line_total': '804.67'},
#      {'line_count': '3',
#       'line_description': 'DQ-90421 Standard Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '102.98',
#       'line_total': '1584.24'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Curtis Instruments, Inc.'},
#    {'field': 'invoice_date', 'value': '10/24/2024'},
#    {'field': 'merchant_branch', 'value': 'Curtis Instruments, Inc.'},
#    {'field': 'merchant_chain', 'value': 'Curtis Instruments, Inc.'},
#    {'field': 'due_date', 'value': '11/23/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '1376.15'},
#    {'field': 'tax', 'value': '52.93'},
#    {'field': 'po_number', 'value': 'P82154'},
#    {'field': 'merchant_address',
#     'value': '200 Kisco Avenue Mount Kisco NY 10549 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'P-5876 Standard Power Supply',
#       'line_qty': '10',
#       'line_tax': '52.93',
#       'line_total': '1323.22'}]}]},
#  {'extractions': [{'field': 'merchant', 'value': 'Jones & Wilson'},
#    {'field': 'invoice_date', 'value': '09/16/2024'},
#    {'field': 'merchant_branch', 'value': 'Jones & Wilson'},
#    {'field': 'merchant_chain', 'value': 'Jones & Wilson'},
#    {'field': 'due_date', 'value': '10/16/2024'},
#    {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#    {'field': 'grand_total', 'value': '54018.73'},
#    {'field': 'tax', 'value': '3197.95'},
#    {'field': 'po_number', 'value': 'N74884'},
#    {'field': 'merchant_address',
#     'value': '1910 Booth Roads Suite 855 Lake Andrea WA 92917 USA'},
#    {'field': 'payment_method', 'value': 'DHL Express'},
#    {'field': 'country', 'value': 'US'},
#    {'field': 'currency', 'value': 'USD'},
#    {'field': 'label', 'value': 0},
#    {'field': 'line_details',
#     'value': [{'line_count': '1',
#       'line_description': 'VEJ-418 Advanced Laboratory Supply',
#       'line_qty': '1',
#       'line_tax': '162.49',
#       'line_total': '2499.86'},
#      {'line_count': '2',
#       'line_description': 'E-003 Industrial Sterilization Equipment',
#       'line_qty': '10',
#       'line_tax': '926.02',
#       'line_total': '14246.50'},
#      {'line_count': '3',
#       'line_description': 'TR-146 Industrial Sterilization Equipment',
#       'line_qty': '1',
#       'line_tax': '96.53',
#       'line_total': '1485.10'},
#      {'line_count': '4',
#       'line_description': 'NY-55743 Premium Monitor',
#       'line_qty': '1',
#       'line_tax': '92.06',
#       'line_total': '1416.28'},
#      {'line_count': '5',
#       'line_description': 'LNJ-059 Commercial Laboratory Supply',
#       'line_qty': '24',
#       'line_tax': '1362.36',
#       'line_total': '20959.37'},
#      {'line_count': '6',
#       'line_description': 'DQ-90421 Standard Surgical Instrument',
#       'line_qty': '1',
#       'line_tax': '0.00',
#       'line_total': '1608.22'},
#      {'line_count': '7',
#       'line_description': 'H-06174 Ultimate Surgical Instrument',
#       'line_qty': '4',
#       'line_tax': '558.49',
#       'line_total': '8592.17'}]}]}]
