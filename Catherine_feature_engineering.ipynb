# %%
import json
import pandas as pd
import re

# %%
from synthetic_invoice_generator import *

# %%
def json_to_df(filename):
    '''
    converts json string from json file to pd dataframe
    '''
    with open(filename) as file:
        data = json.load(file)

    formatted_data = []
    for item in data:
        row = {entry["field"]: entry["value"] for entry in item["extractions"]}
        formatted_data.append(row)

    df = pd.DataFrame(formatted_data)
    return df

# %%
def string_to_df(json_string):
    '''
    converts json string to pd dataframe
    '''
    formatted_data = []
    for item in json_string:
        row = {entry["field"]: entry["value"] for entry in item["extractions"]}
        formatted_data.append(row)

    df = pd.DataFrame(formatted_data)
    return df

# %%
data = generate_dataset(num_invoices=1000,num_merchants=10000,anomaly_rate=0.4, seed=42)
df = string_to_df(data)
df
# Out:
# Generating 1000 synthetic invoices across a set of 10000 merchants (anomaly rate: 40.0%)...
# Analysis of 1000 invoices:
# - Unique merchants: 914
# - Total line items: 3462
# - Average line items per invoice: 3.46
#
# Field frequency:
# - merchant: 1000 (100.0%)
# - invoice_date: 1000 (100.0%)
# - merchant_branch: 1000 (100.0%)
# - merchant_chain: 1000 (100.0%)
# - due_date: 1000 (100.0%)
# - payment_terms: 1000 (100.0%)
# - grand_total: 1000 (100.0%)
# - tax: 1000 (100.0%)
# - po_number: 1000 (100.0%)
# - merchant_address: 1000 (100.0%)
# - payment_method: 1000 (100.0%)
# - country: 1000 (100.0%)
# - currency: 1000 (100.0%)
# - line_details: 1000 (100.0%)
# Generated 1000 synthetic invoices and saved to synthetic_invoices.json
# Saved invoices in JSONL format to synthetic_invoices.jsonl
#                                               merchant invoice_date  \
# 0                                                Barry   02/08/2025
# 1    Macdonald-Patterson Office Supplies International   02/06/2025
# 2                                    Sawyer Laboratory   02/22/2025
# 3                             Stark-Church Enterprises   03/01/2025
# 4                                           Bond Corp.   12/23/2024
# ..                                                 ...          ...
# 995                            Moore Construction Ltd.   08/29/2024
# 996                         IndustryAssume Electronics   01/31/2025
# 997                           KidEnergy Aerospace Ltd.   11/01/2024
# 998                                 WillRepresent Inc.   02/20/2025
# 999                              Benitez International   11/26/2024
#
#                                        merchant_branch  \
# 0                                                Barry
# 1    Macdonald-Patterson Office Supplies International
# 2                                    Sawyer Laboratory
# 3                             Stark-Church Enterprises
# 4                                           Bond Corp.
# ..                                                 ...
# 995                            Moore Construction Ltd.
# 996                         IndustryAssume Electronics
# 997                           KidEnergy Aerospace Ltd.
# 998                                 WillRepresent Inc.
# 999                              Benitez International
#
#                                         merchant_chain    due_date  \
# 0                                                Barry  02/08/2025
# 1    Macdonald-Patterson Office Supplies International  02/06/2025
# 2                                    Sawyer Laboratory  02/22/2025
# 3                             Stark-Church Enterprises  03/31/2025
# 4                                           Bond Corp.  01/28/2025
# ..                                                 ...         ...
# 995                            Moore Construction Ltd.  08/29/2024
# 996                         IndustryAssume Electronics  03/02/2025
# 997                           KidEnergy Aerospace Ltd.  12/01/2024
# 998                                 WillRepresent Inc.  03/22/2025
# 999                              Benitez International  01/02/2025
#
#       payment_terms grand_total      tax        po_number  \
# 0    DUE ON RECEIPT    14331.45   821.64           K29420
# 1    DUE ON RECEIPT     2553.65    94.63           E51230
# 2    DUE ON RECEIPT     3637.04    44.34           474017
# 3       NET 30 DAYS    96408.56  5636.28         PO-86574
# 4       NET 45 DAYS     8167.53   490.36  CUST-70023-2402
# ..              ...         ...      ...              ...
# 995             COD    48643.69  5671.09           706201
# 996     NET 30 DAYS     3829.68   216.77           881190
# 997     NET 30 DAYS    12752.72     0.00           U72327
# 998     2/10 NET 30      554.91    11.01        2503-5957
# 999     NET 30 DAYS     7675.09   297.60  CUST-86692-1819
#
#                                       merchant_address payment_method country  \
# 0        141 Hodges Mountains Kramerville NM 04216 USA  FedEx Express      US
# 1         57081 Wilkinson Cove East David OR 03013 USA     UPS Ground      US
# 2    193 Ryan Lodge Suite 052 West Sylviachester NC...         PayPal      US
# 3              413 James Roads Bakerville IA 12699 USA  USPS Priority      US
# 4    746 Michael Trafficway Michelleburgh NV 02384 USA  USPS Priority      US
# ..                                                 ...            ...     ...
# 995  10862 Donovan Lights Apt. 433 Port Johnathan N...  USPS Priority      US
# 996          44333 Mark Roads New Patrick DC 31035 USA          Check      US
# 997       4951 Joshua Ports South Timothy PW 89016 USA    DHL Express      US
# 998     29098 Amy Ville South Jeremymouth NY 15844 USA   FedEx Ground      US
# 999  2301 Gonzalez Common Suite 631 Smithberg SD 18...   FedEx Ground      US
#
#     currency                                       line_details
# 0        USD  [{'line_count': '1', 'line_description': 'NN-0...
# 1        USD  [{'line_count': '1', 'line_description': 'DDR-...
# 2        USD  [{'line_count': '1', 'line_description': 'K-38...
# 3        USD  [{'line_count': '1', 'line_description': 'M-80...
# 4        USD  [{'line_count': '1', 'line_description': 'MLF-...
# ..       ...                                                ...
# 995      USD  [{'line_count': '1', 'line_description': 'UW-3...
# 996      USD  [{'line_count': '1', 'line_description': 'B-84...
# 997      USD  [{'line_count': '1', 'line_description': 'D-04...
# 998      USD  [{'line_count': '1', 'line_description': 'GR-9...
# 999      USD  [{'line_count': '1', 'line_description': 'Z-94...
#
# [1000 rows x 14 columns]

# %%
# Convert data types
df["grand_total"] = df["grand_total"].astype(float)
df["tax"] = df["tax"].astype(float)
df["due_date"] = pd.to_datetime(df["due_date"], errors="coerce")
df["invoice_date"] = pd.to_datetime(df["invoice_date"], errors="coerce")

# Derived features
df["cal_invoice_age"] = (df["due_date"] - df["invoice_date"]).dt.days
df["num_line_items"] = df["line_details"].apply(lambda x: len(x) if isinstance(x, list) else 0)
df["avg_line_price"] = df["grand_total"] / df["num_line_items"].replace(0, np.nan)
df["avg_line_price"] = df["avg_line_price"].round(2)

df
# Out:
#                                               merchant invoice_date  \
# 0                                                Barry   2025-02-08
# 1    Macdonald-Patterson Office Supplies International   2025-02-06
# 2                                    Sawyer Laboratory   2025-02-22
# 3                             Stark-Church Enterprises   2025-03-01
# 4                                           Bond Corp.   2024-12-23
# ..                                                 ...          ...
# 995                            Moore Construction Ltd.   2024-08-29
# 996                         IndustryAssume Electronics   2025-01-31
# 997                           KidEnergy Aerospace Ltd.   2024-11-01
# 998                                 WillRepresent Inc.   2025-02-20
# 999                              Benitez International   2024-11-26
#
#                                        merchant_branch  \
# 0                                                Barry
# 1    Macdonald-Patterson Office Supplies International
# 2                                    Sawyer Laboratory
# 3                             Stark-Church Enterprises
# 4                                           Bond Corp.
# ..                                                 ...
# 995                            Moore Construction Ltd.
# 996                         IndustryAssume Electronics
# 997                           KidEnergy Aerospace Ltd.
# 998                                 WillRepresent Inc.
# 999                              Benitez International
#
#                                         merchant_chain   due_date  \
# 0                                                Barry 2025-02-08
# 1    Macdonald-Patterson Office Supplies International 2025-02-06
# 2                                    Sawyer Laboratory 2025-02-22
# 3                             Stark-Church Enterprises 2025-03-31
# 4                                           Bond Corp. 2025-01-28
# ..                                                 ...        ...
# 995                            Moore Construction Ltd. 2024-08-29
# 996                         IndustryAssume Electronics 2025-03-02
# 997                           KidEnergy Aerospace Ltd. 2024-12-01
# 998                                 WillRepresent Inc. 2025-03-22
# 999                              Benitez International 2025-01-02
#
#       payment_terms  grand_total      tax        po_number  \
# 0    DUE ON RECEIPT     14331.45   821.64           K29420
# 1    DUE ON RECEIPT      2553.65    94.63           E51230
# 2    DUE ON RECEIPT      3637.04    44.34           474017
# 3       NET 30 DAYS     96408.56  5636.28         PO-86574
# 4       NET 45 DAYS      8167.53   490.36  CUST-70023-2402
# ..              ...          ...      ...              ...
# 995             COD     48643.69  5671.09           706201
# 996     NET 30 DAYS      3829.68   216.77           881190
# 997     NET 30 DAYS     12752.72     0.00           U72327
# 998     2/10 NET 30       554.91    11.01        2503-5957
# 999     NET 30 DAYS      7675.09   297.60  CUST-86692-1819
#
#                                       merchant_address payment_method country  \
# 0        141 Hodges Mountains Kramerville NM 04216 USA  FedEx Express      US
# 1         57081 Wilkinson Cove East David OR 03013 USA     UPS Ground      US
# 2    193 Ryan Lodge Suite 052 West Sylviachester NC...         PayPal      US
# 3              413 James Roads Bakerville IA 12699 USA  USPS Priority      US
# 4    746 Michael Trafficway Michelleburgh NV 02384 USA  USPS Priority      US
# ..                                                 ...            ...     ...
# 995  10862 Donovan Lights Apt. 433 Port Johnathan N...  USPS Priority      US
# 996          44333 Mark Roads New Patrick DC 31035 USA          Check      US
# 997       4951 Joshua Ports South Timothy PW 89016 USA    DHL Express      US
# 998     29098 Amy Ville South Jeremymouth NY 15844 USA   FedEx Ground      US
# 999  2301 Gonzalez Common Suite 631 Smithberg SD 18...   FedEx Ground      US
#
#     currency                                       line_details  \
# 0        USD  [{'line_count': '1', 'line_description': 'NN-0...
# 1        USD  [{'line_count': '1', 'line_description': 'DDR-...
# 2        USD  [{'line_count': '1', 'line_description': 'K-38...
# 3        USD  [{'line_count': '1', 'line_description': 'M-80...
# 4        USD  [{'line_count': '1', 'line_description': 'MLF-...
# ..       ...                                                ...
# 995      USD  [{'line_count': '1', 'line_description': 'UW-3...
# 996      USD  [{'line_count': '1', 'line_description': 'B-84...
# 997      USD  [{'line_count': '1', 'line_description': 'D-04...
# 998      USD  [{'line_count': '1', 'line_description': 'GR-9...
# 999      USD  [{'line_count': '1', 'line_description': 'Z-94...
#
#      cal_invoice_age  num_line_items  avg_line_price
# 0                  0               3         4777.15
# 1                  0               4          638.41
# 2                  0               2         1818.52
# 3                 30               4        24102.14
# 4                 36               5         1633.51
# ..               ...             ...             ...
# 995                0               6         8107.28
# 996               30               3         1276.56
# 997               30               2         6376.36
# 998               30               2          277.46
# 999               37               2         3837.54
#
# [1000 rows x 17 columns]

# %%
payment_days = {
    "NET 30 DAYS": 30,
    "NET 45 DAYS": 45,
    "NET 60 DAYS": 60,
    "NET 15 DAYS": 15,
    "DUE ON RECEIPT": 0,
    "COD": 0,
    "2/10 NET 30": 30 
}

df["expected_invoice_age"] = df["payment_terms"].map(payment_days)
df["invoice_age_mismatch"] = (df["expected_invoice_age"] != df["cal_invoice_age"]).astype(int)

df[df["invoice_age_mismatch"] == 1]
# Out:
#                                 merchant invoice_date  \
# 4                             Bond Corp.   2024-12-23
# 7                     Weaver Electronics   2024-07-29
# 11     White-Schwartz Telecommunications   2025-02-16
# 14             Robertson & Allen Medical   2025-02-01
# 22   Knight & Jackson Telecommunications   2025-01-25
# ..                                   ...          ...
# 985                        Church-Hansen   2024-11-30
# 986                         Campaign LLC   2025-03-12
# 988                               Mclean   2025-03-07
# 994                             WallShow   2024-10-05
# 999                Benitez International   2024-11-26
#
#                          merchant_branch                       merchant_chain  \
# 4                             Bond Corp.                           Bond Corp.
# 7                     Weaver Electronics                   Weaver Electronics
# 11     White-Schwartz Telecommunications    White-Schwartz Telecommunications
# 14             Robertson & Allen Medical            Robertson & Allen Medical
# 22   Knight & Jackson Telecommunications  Knight & Jackson Telecommunications
# ..                                   ...                                  ...
# 985                        Church-Hansen                        Church-Hansen
# 986                         Campaign LLC                         Campaign LLC
# 988                               Mclean                               Mclean
# 994                             WallShow                             WallShow
# 999                Benitez International                Benitez International
#
#       due_date payment_terms  grand_total      tax        po_number  \
# 4   2025-01-28   NET 45 DAYS      8167.53   490.36  CUST-70023-2402
# 7   2024-08-20   NET 30 DAYS      5122.47   417.95        11898-277
# 11  2025-03-11   2/10 NET 30     53926.97     0.00        2503-9726
# 14  2025-03-28   NET 45 DAYS    126454.54  7157.80        2503-5313
# 22  2025-03-12   NET 60 DAYS      2241.60    94.67  CUST-74497-8745
# ..         ...           ...          ...      ...              ...
# 985 2025-02-13   NET 60 DAYS      8913.05     0.00  CUST-74497-7745
# 986 2025-04-16   NET 30 DAYS      9427.68   401.54        88462-787
# 988 2025-05-03   NET 45 DAYS      2025.18    77.89           U89242
# 994 2024-11-12   NET 30 DAYS       871.70    47.26  CUST-50895-1746
# 999 2025-01-02   NET 30 DAYS      7675.09   297.60  CUST-86692-1819
#
#                                       merchant_address payment_method country  \
# 4    746 Michael Trafficway Michelleburgh NV 02384 USA  USPS Priority      US
# 7    0427 Jefferson Motorway Suite 884 North Wendyp...            ACH      US
# 11         56761 Donald Fields Susanmouth OR 26003 USA    DHL Express      US
# 14        858 Holmes Grove East Julieview PA 08219 USA  USPS Priority      US
# 22   96241 Calderon Islands North Lindseymouth OK 9...   FedEx Ground      US
# ..                                                 ...            ...     ...
# 985            088 David Rest Thomasmouth MT 47899 USA     UPS Ground      US
# 986     715 Lang Shore Apt. 674 Yvetteton MO 93484 USA         PayPal      US
# 988         3414 Tammy Pine West Clifford AL 18649 USA     UPS Ground      US
# 994       61422 Joseph Circles New Isaiah UT 83940 USA  USPS Priority      US
# 999  2301 Gonzalez Common Suite 631 Smithberg SD 18...   FedEx Ground      US
#
#     currency                                       line_details  \
# 4        USD  [{'line_count': '1', 'line_description': 'MLF-...
# 7        USD  [{'line_count': '1', 'line_description': 'B-84...
# 11       USD  [{'line_count': '1', 'line_description': 'GBL-...
# 14       USD  [{'line_count': '1', 'line_description': 'NN-0...
# 22       USD  [{'line_count': '1', 'line_description': 'RGJ-...
# ..       ...                                                ...
# 985      USD  [{'line_count': '1', 'line_description': 'C-03...
# 986      USD  [{'line_count': '1', 'line_description': 'X-84...
# 988      USD  [{'line_count': '1', 'line_description': 'GU-6...
# 994      USD  [{'line_count': '1', 'line_description': 'B-84...
# 999      USD  [{'line_count': '1', 'line_description': 'Z-94...
#
#      cal_invoice_age  num_line_items  avg_line_price  expected_invoice_age  \
# 4                 36               5         1633.51                    45
# 7                 22               3         1707.49                    30
# 11                23               4        13481.74                    30
# 14                55               2        63227.27                    45
# 22                46               1         2241.60                    60
# ..               ...             ...             ...                   ...
# 985               75               3         2971.02                    60
# 986               35               4         2356.92                    30
# 988               57               1         2025.18                    45
# 994               38               4          217.92                    30
# 999               37               2         3837.54                    30
#
#      invoice_age_mismatch
# 4                       1
# 7                       1
# 11                      1
# 14                      1
# 22                      1
# ..                    ...
# 985                     1
# 986                     1
# 988                     1
# 994                     1
# 999                     1
#
# [295 rows x 19 columns]

# %%
with open("synthetic_data_configs.json", "r") as f:
    config = json.load(f)
state_tax_rates = config["tax_rates"]

# Function to extract state from address (format: "Street, City, State ZIP, Country")
def extract_state(address):
    match = re.search(r'\b[A-Z]{2}\b', address)  # Match two-letter state codes
    return match.group(0) if match else None

# Apply state extraction
df["state"] = df["merchant_address"].apply(extract_state)

# Map expected tax rate based on extracted state
df["expected_tax_rate"] = df["state"].map(state_tax_rates)

# State has expected_tax_rate == NaN
df["state_mismatch_flag"] = df["expected_tax_rate"].isna().astype(int)

def compute_subtotal(line_details):
    return sum(float(line["line_total"]) for line in line_details)

df["sub_total"] = df["line_details"].apply(compute_subtotal)
df["cal_tax_rate"] = df["tax"] / df["sub_total"]
df["tax_mismatch_flag"] = (df["cal_tax_rate"].round(4) != df["expected_tax_rate"].round(4)).astype(int)

df
# Out:
#                                               merchant invoice_date  \
# 0                                                Barry   2025-02-08
# 1    Macdonald-Patterson Office Supplies International   2025-02-06
# 2                                    Sawyer Laboratory   2025-02-22
# 3                             Stark-Church Enterprises   2025-03-01
# 4                                           Bond Corp.   2024-12-23
# ..                                                 ...          ...
# 995                            Moore Construction Ltd.   2024-08-29
# 996                         IndustryAssume Electronics   2025-01-31
# 997                           KidEnergy Aerospace Ltd.   2024-11-01
# 998                                 WillRepresent Inc.   2025-02-20
# 999                              Benitez International   2024-11-26
#
#                                        merchant_branch  \
# 0                                                Barry
# 1    Macdonald-Patterson Office Supplies International
# 2                                    Sawyer Laboratory
# 3                             Stark-Church Enterprises
# 4                                           Bond Corp.
# ..                                                 ...
# 995                            Moore Construction Ltd.
# 996                         IndustryAssume Electronics
# 997                           KidEnergy Aerospace Ltd.
# 998                                 WillRepresent Inc.
# 999                              Benitez International
#
#                                         merchant_chain   due_date  \
# 0                                                Barry 2025-02-08
# 1    Macdonald-Patterson Office Supplies International 2025-02-06
# 2                                    Sawyer Laboratory 2025-02-22
# 3                             Stark-Church Enterprises 2025-03-31
# 4                                           Bond Corp. 2025-01-28
# ..                                                 ...        ...
# 995                            Moore Construction Ltd. 2024-08-29
# 996                         IndustryAssume Electronics 2025-03-02
# 997                           KidEnergy Aerospace Ltd. 2024-12-01
# 998                                 WillRepresent Inc. 2025-03-22
# 999                              Benitez International 2025-01-02
#
#       payment_terms  grand_total      tax        po_number  \
# 0    DUE ON RECEIPT     14331.45   821.64           K29420
# 1    DUE ON RECEIPT      2553.65    94.63           E51230
# 2    DUE ON RECEIPT      3637.04    44.34           474017
# 3       NET 30 DAYS     96408.56  5636.28         PO-86574
# 4       NET 45 DAYS      8167.53   490.36  CUST-70023-2402
# ..              ...          ...      ...              ...
# 995             COD     48643.69  5671.09           706201
# 996     NET 30 DAYS      3829.68   216.77           881190
# 997     NET 30 DAYS     12752.72     0.00           U72327
# 998     2/10 NET 30       554.91    11.01        2503-5957
# 999     NET 30 DAYS      7675.09   297.60  CUST-86692-1819
#
#                                       merchant_address  ... num_line_items  \
# 0        141 Hodges Mountains Kramerville NM 04216 USA  ...              3
# 1         57081 Wilkinson Cove East David OR 03013 USA  ...              4
# 2    193 Ryan Lodge Suite 052 West Sylviachester NC...  ...              2
# 3              413 James Roads Bakerville IA 12699 USA  ...              4
# 4    746 Michael Trafficway Michelleburgh NV 02384 USA  ...              5
# ..                                                 ...  ...            ...
# 995  10862 Donovan Lights Apt. 433 Port Johnathan N...  ...              6
# 996          44333 Mark Roads New Patrick DC 31035 USA  ...              3
# 997       4951 Joshua Ports South Timothy PW 89016 USA  ...              2
# 998     29098 Amy Ville South Jeremymouth NY 15844 USA  ...              2
# 999  2301 Gonzalez Common Suite 631 Smithberg SD 18...  ...              2
#
#     avg_line_price expected_invoice_age invoice_age_mismatch  state  \
# 0          4777.15                    0                    0     NM
# 1           638.41                    0                    0     OR
# 2          1818.52                    0                    0     NC
# 3         24102.14                   30                    0     IA
# 4          1633.51                   45                    1     NV
# ..             ...                  ...                  ...    ...
# 995        8107.28                    0                    0     NH
# 996        1276.56                   30                    0     DC
# 997        6376.36                   30                    0     PW
# 998         277.46                   30                    0     NY
# 999        3837.54                   30                    1     SD
#
#      expected_tax_rate  state_mismatch_flag  sub_total  cal_tax_rate  \
# 0               0.0513                    0   13509.81      0.060818
# 1               0.0000                    0    2459.02      0.038483
# 2               0.0475                    0    3592.70      0.012342
# 3               0.0600                    0   90772.28      0.062093
# 4               0.0685                    0    7677.17      0.063872
# ..                 ...                  ...        ...           ...
# 995             0.0000                    0   42934.52      0.132087
# 996             0.0600                    0    3612.91      0.059999
# 997                NaN                    1   12713.11      0.000000
# 998             0.0400                    0     543.90      0.020243
# 999             0.0450                    0    7355.57      0.040459
#
#     tax_mismatch_flag
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ..                ...
# 995                 1
# 996                 0
# 997                 1
# 998                 1
# 999                 1
#
# [1000 rows x 25 columns]
