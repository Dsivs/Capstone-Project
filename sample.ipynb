# %%
import invoice_generator
import preprocess
from sklearn import model_selection

# %% [markdown]
# # 1. Data Generation

# %%
data = invoice_generator.generate_dataset(
    num_invoices=10000,
    num_merchants=1000,
    general_anomaly_rate=0.3,
    line_anomaly_rate=0.05,
    seed=42,
    test=True,
)
# Out:
# Generating 10000 synthetic invoices across a set of 1000 merchants (general anomaly rate: 30.0%, line anomaly rate: 5.0%)...
# Analysis of 10541 invoices:
# - Unique merchants: 912
# - Total line items: 36601
# - Average line items per invoice: 3.47
#
# Field frequency:
# - merchant: 10541 (100.0%)
# - invoice_date: 10541 (100.0%)
# - merchant_branch: 10541 (100.0%)
# - merchant_chain: 10541 (100.0%)
# - due_date: 10541 (100.0%)
# - payment_terms: 10541 (100.0%)
# - grand_total: 10541 (100.0%)
# - tax: 10541 (100.0%)
# - po_number: 10541 (100.0%)
# - merchant_address: 10541 (100.0%)
# - payment_method: 10541 (100.0%)
# - country: 10541 (100.0%)
# - currency: 10541 (100.0%)
# - line_details: 10541 (100.0%)
# Generated 10541 synthetic invoices and saved to synthetic_invoices.json
# Saved invoices in JSONL format to synthetic_invoices.jsonl

# %%
data[0]
# Out:
# {'extractions': [{'field': 'merchant', 'value': 'Write Laboratory'},
#   {'field': 'invoice_date', 'value': '12/10/2024'},
#   {'field': 'merchant_branch', 'value': 'Write Laboratory'},
#   {'field': 'merchant_chain', 'value': 'Write Laboratory'},
#   {'field': 'due_date', 'value': '01/09/2025'},
#   {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#   {'field': 'grand_total', 'value': '105688.50'},
#   {'field': 'tax', 'value': '5979.88'},
#   {'field': 'po_number', 'value': '226656'},
#   {'field': 'merchant_address',
#    'value': '79163 Rebecca Forks Suite 246 West Thomastown VA 02369 USA'},
#   {'field': 'payment_method', 'value': 'Check'},
#   {'field': 'country', 'value': 'US'},
#   {'field': 'currency', 'value': 'USD'},
#   {'field': 'line_details',
#    'value': [{'line_count': '1',
#      'line_description': 'X-6906 Compact Chemical',
#      'line_qty': '50',
#      'line_tax': '3106.62',
#      'line_total': '51776.94',
#      'model': 'X-6906'},
#     {'line_count': '2',
#      'line_description': 'M-26501 Lightweight Glassware',
#      'line_qty': '3',
#      'line_tax': '61.73',
#      'line_total': '1028.80',
#      'model': 'M-26501'},
#     {'line_count': '3',
#      'line_description': 'P-45005 Commercial Sample Container',
#      'line_qty': '24',
#      'line_tax': '1789.35',
#      'line_total': '29822.49',
#      'model': 'P-45005'},
#     {'line_count': '4',
#      'line_description': 'KJ-096 Commercial Measurement Device',
#      'line_qty': '100',
#      'line_tax': '828.38',
#      'line_total': '13806.40',
#      'model': 'KJ-096'},
#     {'line_count': '5',
#      'line_description': 'YD-89239 Economy Chemical',
#      'line_qty': '2',
#      'line_tax': '15.22',
#      'line_total': '253.67',
#      'model': 'YD-89239'},
#     {'line_count': '6',
#      'line_description': 'JDQ-72256 Standard Chemical',
#      'line_qty': '12',
#      'line_tax': '178.58',
#      'line_total': '2976.31',
#      'model': 'JDQ-72256'}]}],
#  'label': 1,
#  'anomaly_types': ['state_tax_mismatch']}

# %% [markdown]
# # 2. Feature Engineering

# %%
train, test = model_selection.train_test_split(data, test_size=0.2, random_state=42)

print(f"Training set size: {len(train)}")
print(f"Test set size: {len(test)}")
# Out:
# Training set size: 8432
# Test set size: 2109

# %%
train_df = preprocess.process_invoice(train, test=True)
test_df = preprocess.process_invoice(test, test=True)

# %%
train_df.head()
# Out:
#   _ANOMALY_TYPES_DROP_BEFORE_TRAINING_  is_anomalous  \
# 0                                   []             0
# 1                   [due_date_anomaly]             1
# 2                    [varied_wordings]             1
# 3                                   []             0
# 4                                   []             0
#
#                              merchant invoice_date  \
# 0                            Espinoza   2025-03-16
# 1                     Norris & Morris   2025-03-30
# 2                    Adams Automotive   2024-11-11
# 3                             SourceA   2024-10-23
# 4  AllowWhile Electronics Enterprises   2025-04-03
#
#                       merchant_branch                      merchant_chain  \
# 0                            Espinoza                            Espinoza
# 1                     Norris & Morris                     Norris & Morris
# 2                    Adams Automotive                    Adams Automotive
# 3                             SourceA                             SourceA
# 4  AllowWhile Electronics Enterprises  AllowWhile Electronics Enterprises
#
#     due_date   payment_terms  grand_total     tax  ... merchant_mismatch_flag  \
# 0 2025-04-15     NET 30 DAYS      1762.16   83.91  ...                  False
# 1 2025-04-21     NET 30 DAYS      3943.87  169.83  ...                  False
# 2 2024-11-11  DUE ON RECEIPT     15527.86    0.00  ...                  False
# 3 2024-10-23  DUE ON RECEIPT     18515.30  881.68  ...                  False
# 4 2025-05-03     NET 30 DAYS      1354.73   76.69  ...                  False
#
#   duplicate_invoice_flag invoice_age actual_tax_rate expected_tax_rate  \
# 0                  False          30        0.049999             0.050
# 1                  False          22        0.045000             0.045
# 2                  False           0        0.000000             0.000
# 3                  False           0        0.050000             0.050
# 4                  False          30        0.060006             0.060
#
#    expected_tax  avg_description_similarity  invoice_similarity  \
# 0       83.9125                    0.021412            0.716714
# 1      169.8318                    0.019552            0.643982
# 2        0.0000                    0.018506            0.645085
# 3      881.6810                    0.018009            0.653890
# 4       76.6824                    0.011894            0.757758
#
#    payment_terms_numeric  state
# 0                     30     ND
# 1                     30     OK
# 2                      0     PR
# 3                      0     WI
# 4                     30     KY
#
# [5 rows x 32 columns]

# %%
test_df.head()
# Out:
#   _ANOMALY_TYPES_DROP_BEFORE_TRAINING_  is_anomalous               merchant  \
# 0                   [due_date_anomaly]             1           EmployeeRole
# 1                                   []             1         FieldEstablish
# 2                   [due_date_anomaly]             1        Gregory-Sanders
# 3                                   []             0     ChildUs Technology
# 4     [phantom_item, due_date_anomaly]             1  Small Automotive Inc.
#
#   invoice_date        merchant_branch         merchant_chain   due_date  \
# 0   2025-01-30           EmployeeRole           EmployeeRole 2025-02-27
# 1   2025-05-10         FieldEstablish         FieldEstablish 2025-05-27
# 2   2025-02-15        Gregory-Sanders        Gregory-Sanders 2025-03-01
# 3   2025-04-01     ChildUs Technology     ChildUs Technology 2025-04-01
# 4   2025-04-02  Small Automotive Inc.  Small Automotive Inc. 2025-05-09
#
#     payment_terms  grand_total       tax  ... merchant_mismatch_flag  \
# 0     NET 30 DAYS     22644.06      0.00  ...                  False
# 1     NET 45 DAYS     33774.79   2016.64  ...                  False
# 2     NET 15 DAYS    974605.56  37483.43  ...                  False
# 3  DUE ON RECEIPT     26746.65   1746.83  ...                  False
# 4     NET 30 DAYS    108371.78   7089.75  ...                  False
#
#   duplicate_invoice_flag invoice_age actual_tax_rate expected_tax_rate  \
# 0                  False          28        0.000000            0.0000
# 1                   True          17        0.063500            0.0635
# 2                  False          14        0.039998            0.0400
# 3                  False           0        0.069874            0.0700
# 4                  False          37        0.070000            0.0700
#
#    expected_tax  avg_description_similarity  invoice_similarity  \
# 0      0.000000                    0.019220            0.669004
# 1   2016.642525                    0.024218            0.994874
# 2  37484.885200                    0.023637            0.673960
# 3   1749.987400                    0.016722            0.572401
# 4   7089.742100                    0.016923            0.630189
#
#    payment_terms_numeric  state
# 0                     30     FM
# 1                     45     CT
# 2                     15     GA
# 3                      0     TN
# 4                     30     TN
#
# [5 rows x 32 columns]

# %%
train_df.to_parquet("train_df.parquet")
test_df.to_parquet("test_df.parquet")
