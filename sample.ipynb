# %%
import pandas as pd
import invoice_generator



import preprocess



from sklearn import model_selection

# %% [markdown]
# # 1. Data Generation

# %%
data = invoice_generator.generate_dataset(
    num_invoices=10000,
    num_merchants=1000,
    general_anomaly_rate=0.3,
    line_anomaly_rate=0.05,
    seed=42,
)
# Out:
# Generating 10000 synthetic invoices across a set of 1000 merchants (general anomaly rate: 30.0%, line anomaly rate: 5.0%)...
# Analysis of 10525 invoices:
# - Unique merchants: 916
# - Total line items: 36267
# - Average line items per invoice: 3.45
#
# Field frequency:
# - merchant: 10525 (100.0%)
# - invoice_date: 10525 (100.0%)
# - merchant_branch: 10525 (100.0%)
# - merchant_chain: 10525 (100.0%)
# - due_date: 10525 (100.0%)
# - payment_terms: 10525 (100.0%)
# - grand_total: 10525 (100.0%)
# - tax: 10525 (100.0%)
# - po_number: 10525 (100.0%)
# - merchant_address: 10525 (100.0%)
# - payment_method: 10525 (100.0%)
# - country: 10525 (100.0%)
# - currency: 10525 (100.0%)
# - line_details: 10525 (100.0%)
# Generated 10525 synthetic invoices and saved to synthetic_invoices.json
# Saved invoices in JSONL format to synthetic_invoices.jsonl

# %%
data[0]
# Out:
# {'extractions': [{'field': 'merchant', 'value': 'Write Laboratory'},
#   {'field': 'invoice_date', 'value': '12/06/2024'},
#   {'field': 'merchant_branch', 'value': 'Write Laboratory'},
#   {'field': 'merchant_chain', 'value': 'Write Laboratory'},
#   {'field': 'due_date', 'value': '01/05/2025'},
#   {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#   {'field': 'grand_total', 'value': '105688.50'},
#   {'field': 'tax', 'value': '5979.88'},
#   {'field': 'po_number', 'value': '226656'},
#   {'field': 'merchant_address',
#    'value': '79163 Rebecca Forks Suite 246 West Thomastown VA 02369 USA'},
#   {'field': 'payment_method', 'value': 'Check'},
#   {'field': 'country', 'value': 'US'},
#   {'field': 'currency', 'value': 'USD'},
#   {'field': 'line_details',
#    'value': [{'line_count': '1',
#      'line_description': 'X-6906 Compact Chemical',
#      'line_qty': '50',
#      'line_tax': '3106.62',
#      'line_total': '51776.94',
#      'model': 'X-6906'},
#     {'line_count': '2',
#      'line_description': 'M-26501 Lightweight Glassware',
#      'line_qty': '3',
#      'line_tax': '61.73',
#      'line_total': '1028.80',
#      'model': 'M-26501'},
#     {'line_count': '3',
#      'line_description': 'P-45005 Commercial Sample Container',
#      'line_qty': '24',
#      'line_tax': '1789.35',
#      'line_total': '29822.49',
#      'model': 'P-45005'},
#     {'line_count': '4',
#      'line_description': 'KJ-096 Commercial Measurement Device',
#      'line_qty': '100',
#      'line_tax': '828.38',
#      'line_total': '13806.40',
#      'model': 'KJ-096'},
#     {'line_count': '5',
#      'line_description': 'YD-89239 Economy Chemical',
#      'line_qty': '2',
#      'line_tax': '15.22',
#      'line_total': '253.67',
#      'model': 'YD-89239'},
#     {'line_count': '6',
#      'line_description': 'JDQ-72256 Standard Chemical',
#      'line_qty': '12',
#      'line_tax': '178.58',
#      'line_total': '2976.31',
#      'model': 'JDQ-72256'}]}],
#  'label': 1}

# %% [markdown]
# # 2. Feature Engineering

# %%
train, test = model_selection.train_test_split(data, test_size=0.2, random_state=42)

print(f"Training set size: {len(train)}")
print(f"Test set size: {len(test)}")
# Out:
# Training set size: 8420
# Test set size: 2105

# %%
train_df = preprocess.process_invoice(train)
test_df = preprocess.process_invoice(test)

# %%
train_df.head()
# Out:
#                merchant       merchant_branch            merchant_chain  \
# 0             Pope GmbH             Pope GmbH                 Pope GmbH
# 1    Gonzalez Solutions    Gonzalez Solutions  Lee & Norton Enterprises
# 2            AcceptWalk            AcceptWalk                AcceptWalk
# 3         DemocraticHit         DemocraticHit              Gonzales Co.
# 4  Harrington-Vang Inc.  Harrington-Vang Inc.      Harrington-Vang Inc.
#
#    po_number payment_method  payment_terms_numeric  invoice_age  \
# 0   PO-39821  USPS Priority                     30           30
# 1   PO-73581  FedEx Express                     30           30
# 2  2504-9921  FedEx Express                     30           30
# 3  2504-8763  FedEx Express                      0          -24
# 4  27850-569          Check                     45           45
#
#    invoice_age_mismatch country currency  ...  duplicate_invoice_flag  \
# 0                 False      US      USD  ...                   False
# 1                 False      US      USD  ...                   False
# 2                 False      US      USD  ...                   False
# 3                  True      US      USD  ...                    True
# 4                 False      US      USD  ...                   False
#
#    avg_description_similarity  invoice_similarity  line_total  line_qty  \
# 0                    0.015204            0.655544     3880.80        41
# 1                    0.014831            0.650988      599.88         3
# 2                    0.017363            0.638144    15571.34         7
# 3                    0.022414            0.993960     6764.13        12
# 4                    0.023669            0.665603   457828.32       166
#
#    invoice_date   due_date                                   merchant_address  \
# 0    2025-03-27 2025-04-26  693 Stephens Unions Suite 040 Halltown DE 4419...
# 1    2025-04-02 2025-05-02            290 Hess Ridges Snyderport VI 80247 USA
# 2    2025-03-05 2025-04-04  35133 Chambers Crossing West Debbieland SC 217...
# 3    2025-03-07 2025-02-11        437 Kathryn Street Janeborough WV 59510 USA
# 4    2025-02-21 2025-04-07             315 Joel Loaf Wolfborough UT 05176 USA
#
#    state  is_anomalous
# 0     DE             0
# 1     VI             1
# 2     SC             1
# 3     WV             1
# 4     UT             1
#
# [5 rows x 30 columns]

# %%
test_df.head()
# Out:
#                        merchant               merchant_branch  \
# 0  American Electronics Systems  American Electronics Systems
# 1               Washington GmbH               Washington GmbH
# 2           Imagine Medical Co.           Imagine Medical Co.
# 3                 Hayes-Bradley                 Hayes-Bradley
# 4                        Gordon                        Gordon
#
#                  merchant_chain  po_number payment_method  \
# 0  American Electronics Systems  2504-3141   FedEx Ground
# 1               Washington GmbH     572867    Net Banking
# 2           Imagine Medical Co.     720486    DHL Express
# 3                 Hayes-Bradley  49944-760  USPS Priority
# 4                        Gordon  2504-3430  FedEx Express
#
#    payment_terms_numeric  invoice_age  invoice_age_mismatch country currency  \
# 0                      0            0                 False      US      USD
# 1                     30           30                 False      US      USD
# 2                     30           30                 False      US      USD
# 3                     30           17                  True      US      USD
# 4                     45           45                 False      US      USD
#
#    ...  duplicate_invoice_flag  avg_description_similarity  \
# 0  ...                   False                    0.013686
# 1  ...                   False                    0.024055
# 2  ...                   False                    0.019909
# 3  ...                   False                    0.013981
# 4  ...                   False                    0.015330
#
#    invoice_similarity  line_total  line_qty  invoice_date   due_date  \
# 0            0.632587      282.05         3    2025-02-07 2025-02-07
# 1            0.656696    12821.61        26    2025-03-25 2025-04-24
# 2            0.667253     3118.67         2    2025-02-04 2025-03-06
# 3            0.578341      895.78        55    2025-03-28 2025-04-14
# 4            0.567970     3070.54         6    2025-01-05 2025-02-19
#
#                                     merchant_address  state  is_anomalous
# 0  626 Abigail Stravenue Suite 394 South Michelle...     WI             1
# 1  138 Perry Station Suite 737 South Jacqueline N...     NJ             0
# 2  0833 Scott Stream Suite 125 Emmamouth VT 01384...     VT             0
# 3         244 Tracy Shoal Griffithmouth MS 42792 USA     MS             1
# 4            094 Price Ranch Thomasstad WV 70869 USA     WV             0
#
# [5 rows x 30 columns]

# %%
train_df.to_parquet("train_df.parquet")
test_df.to_parquet("test_df.parquet")

# %% [markdown]
# # 2.1 Reload Data

# %%
# train_df = pd.read_parquet("train_df.parquet")
# test_df = pd.read_parquet("train_df.parquet")
