# %%
import invoice_generator
import preprocess
from sklearn import model_selection

# %% [markdown]
# # 1. Data Generation

# %%
data = invoice_generator.generate_dataset(
    num_invoices=10000,
    num_merchants=1000,
    general_anomaly_rate=0.3,
    line_anomaly_rate=0.05,
    seed=42,
    test=True,
)
# Out:
# Generating 10000 synthetic invoices across a set of 1000 merchants (general anomaly rate: 30.0%, line anomaly rate: 5.0%)...
# Analysis of 10525 invoices:
# - Unique merchants: 916
# - Total line items: 36267
# - Average line items per invoice: 3.45
#
# Field frequency:
# - merchant: 10525 (100.0%)
# - invoice_date: 10525 (100.0%)
# - merchant_branch: 10525 (100.0%)
# - merchant_chain: 10525 (100.0%)
# - due_date: 10525 (100.0%)
# - payment_terms: 10525 (100.0%)
# - grand_total: 10525 (100.0%)
# - tax: 10525 (100.0%)
# - po_number: 10525 (100.0%)
# - merchant_address: 10525 (100.0%)
# - payment_method: 10525 (100.0%)
# - country: 10525 (100.0%)
# - currency: 10525 (100.0%)
# - line_details: 10525 (100.0%)
# Generated 10525 synthetic invoices and saved to synthetic_invoices.json
# Saved invoices in JSONL format to synthetic_invoices.jsonl

# %%
data[0]
# Out:
# {'extractions': [{'field': 'merchant', 'value': 'Write Laboratory'},
#   {'field': 'invoice_date', 'value': '12/10/2024'},
#   {'field': 'merchant_branch', 'value': 'Write Laboratory'},
#   {'field': 'merchant_chain', 'value': 'Write Laboratory'},
#   {'field': 'due_date', 'value': '01/09/2025'},
#   {'field': 'payment_terms', 'value': 'NET 30 DAYS'},
#   {'field': 'grand_total', 'value': '105688.50'},
#   {'field': 'tax', 'value': '5979.88'},
#   {'field': 'po_number', 'value': '226656'},
#   {'field': 'merchant_address',
#    'value': '79163 Rebecca Forks Suite 246 West Thomastown VA 02369 USA'},
#   {'field': 'payment_method', 'value': 'Check'},
#   {'field': 'country', 'value': 'US'},
#   {'field': 'currency', 'value': 'USD'},
#   {'field': 'line_details',
#    'value': [{'line_count': '1',
#      'line_description': 'X-6906 Compact Chemical',
#      'line_qty': '50',
#      'line_tax': '3106.62',
#      'line_total': '51776.94',
#      'model': 'X-6906'},
#     {'line_count': '2',
#      'line_description': 'M-26501 Lightweight Glassware',
#      'line_qty': '3',
#      'line_tax': '61.73',
#      'line_total': '1028.80',
#      'model': 'M-26501'},
#     {'line_count': '3',
#      'line_description': 'P-45005 Commercial Sample Container',
#      'line_qty': '24',
#      'line_tax': '1789.35',
#      'line_total': '29822.49',
#      'model': 'P-45005'},
#     {'line_count': '4',
#      'line_description': 'KJ-096 Commercial Measurement Device',
#      'line_qty': '100',
#      'line_tax': '828.38',
#      'line_total': '13806.40',
#      'model': 'KJ-096'},
#     {'line_count': '5',
#      'line_description': 'YD-89239 Economy Chemical',
#      'line_qty': '2',
#      'line_tax': '15.22',
#      'line_total': '253.67',
#      'model': 'YD-89239'},
#     {'line_count': '6',
#      'line_description': 'JDQ-72256 Standard Chemical',
#      'line_qty': '12',
#      'line_tax': '178.58',
#      'line_total': '2976.31',
#      'model': 'JDQ-72256'}]}],
#  'label': 1,
#  'anomaly_types': ['state_tax_mismatch']}

# %% [markdown]
# # 2. Feature Engineering

# %%
train, test = model_selection.train_test_split(data, test_size=0.2, random_state=42)

print(f"Training set size: {len(train)}")
print(f"Test set size: {len(test)}")
# Out:
# Training set size: 8420
# Test set size: 2105

# %%
train_df = preprocess.process_invoice(train, test=True)
test_df = preprocess.process_invoice(test, test=True)

# %%
train_df.head()
# Out:
#   _ANOMALY_TYPES_DROP_BEFORE_TRAINING_  is_anomalous              merchant  \
# 0                                   []             0             Pope GmbH
# 1                  [merchant_mismatch]             1    Gonzalez Solutions
# 2                 [state_tax_mismatch]             1            AcceptWalk
# 3                  [merchant_mismatch]             1         DemocraticHit
# 4                           [tax_calc]             1  Harrington-Vang Inc.
#
#   invoice_date       merchant_branch            merchant_chain   due_date  \
# 0   2025-03-31             Pope GmbH                 Pope GmbH 2025-04-30
# 1   2025-04-06    Gonzalez Solutions  Lee & Norton Enterprises 2025-05-06
# 2   2025-03-09            AcceptWalk                AcceptWalk 2025-04-08
# 3   2025-03-11         DemocraticHit              Gonzales Co. 2025-02-15
# 4   2025-02-25  Harrington-Vang Inc.      Harrington-Vang Inc. 2025-04-11
#
#     payment_terms  grand_total       tax  ... merchant_mismatch_flag  \
# 0     NET 30 DAYS      3890.83      0.00  ...                  False
# 1     NET 30 DAYS       599.88      0.00  ...                   True
# 2     NET 30 DAYS     16225.74    622.85  ...                  False
# 3  DUE ON RECEIPT      7191.03    405.85  ...                   True
# 4     NET 45 DAYS    499712.17  41883.85  ...                  False
#
#   duplicate_invoice_flag invoice_age actual_tax_rate expected_tax_rate  \
# 0                  False          30        0.000000             0.000
# 1                  False          30        0.000000             0.000
# 2                  False          30        0.039919             0.060
# 3                   True         -24        0.059814             0.060
# 4                  False          45        0.091484             0.061
#
#    expected_tax  avg_description_similarity  invoice_similarity  \
# 0       0.00000                    0.015204            0.653181
# 1       0.00000                    0.014831            0.636066
# 2     936.17340                    0.017363            0.640247
# 3     407.11080                    0.022414            0.994365
# 4   27927.52752                    0.023669            0.661340
#
#    payment_terms_numeric  state
# 0                     30     DE
# 1                     30     VI
# 2                     30     SC
# 3                      0     WV
# 4                     45     UT
#
# [5 rows x 32 columns]

# %%
test_df.head()
# Out:
#   _ANOMALY_TYPES_DROP_BEFORE_TRAINING_  is_anomalous  \
# 0                 [state_tax_mismatch]             1
# 1                                   []             0
# 2                                   []             0
# 3                                   []             1
# 4                                   []             0
#
#                        merchant invoice_date               merchant_branch  \
# 0  American Electronics Systems   2025-02-11  American Electronics Systems
# 1               Washington GmbH   2025-03-29               Washington GmbH
# 2           Imagine Medical Co.   2025-02-08           Imagine Medical Co.
# 3                 Hayes-Bradley   2025-04-01                 Hayes-Bradley
# 4                        Gordon   2025-01-09                        Gordon
#
#                  merchant_chain   due_date   payment_terms  grand_total  \
# 0  American Electronics Systems 2025-02-11  DUE ON RECEIPT       335.31
# 1               Washington GmbH 2025-04-28     NET 30 DAYS     13671.68
# 2           Imagine Medical Co. 2025-03-10     NET 30 DAYS      3305.79
# 3                 Hayes-Bradley 2025-04-18     NET 30 DAYS       958.49
# 4                        Gordon 2025-02-23     NET 45 DAYS      3297.13
#
#       tax  ... merchant_mismatch_flag duplicate_invoice_flag invoice_age  \
# 0   16.93  ...                  False                  False           0
# 1  850.07  ...                  False                  False          30
# 2  187.12  ...                  False                  False          30
# 3   62.71  ...                  False                  False          17
# 4  184.23  ...                  False                  False          45
#
#   actual_tax_rate expected_tax_rate  expected_tax  avg_description_similarity  \
# 0        0.053175            0.0500     15.919000                    0.013686
# 1        0.066300            0.0663    850.072743                    0.024055
# 2        0.060000            0.0600    187.120200                    0.019909
# 3        0.070006            0.0700     62.704600                    0.013981
# 4        0.059183            0.0600    186.774000                    0.015330
#
#    invoice_similarity  payment_terms_numeric  state
# 0            0.631467                      0     WI
# 1            0.652495                     30     NJ
# 2            0.656128                     30     VT
# 3            0.571268                     30     MS
# 4            0.560855                     45     WV
#
# [5 rows x 32 columns]

# %%
train_df.to_parquet("train_df.parquet")
test_df.to_parquet("test_df.parquet")
